# %%
import pandas as pd
import numpy as np
import json
import os
from tqdm import tqdm
import ast
import random
from concurrent.futures import ProcessPoolExecutor, as_completed
import multiprocessing

# %%
from google.colab import auth
from google.cloud import storage

# 인증
auth.authenticate_user()

# GCP 프로젝트 설정
project_id = 'poised-epigram-454811-q4'  # GCP 프로젝트 ID
bucket_name = 'capteam4stone_real'  # GCP 버킷 이름
file_names = ['rules_f_v12(str).csv','rules_c_v11(str).csv','output_utf8_v11(val).csv','style_dmlp.pth','mlb.pkl']  # 다운로드할 파일 이름

# 버킷에서 데이터 다운로드
client = storage.Client(project=project_id)
bucket = client.get_bucket(bucket_name)

for file_name in file_names:
  blob = bucket.blob(file_name)
  # 로컬로 다운로드
  blob.download_to_filename(file_name)
  print(f"Downloaded {file_name} from bucket {bucket_name}.")
# Out:
# Downloaded rules_f_v12(str).csv from bucket capteam4stone_real.
# Downloaded rules_c_v11(str).csv from bucket capteam4stone_real.
# Downloaded output_utf8_v11(val).csv from bucket capteam4stone_real.
# Downloaded style_dmlp.pth from bucket capteam4stone_real.
# Downloaded mlb.pkl from bucket capteam4stone_real.

# %%
validation=pd.read_csv('output_utf8_v11(val).csv',encoding='utf-8')
validation['ITEMS'] = validation['ITEMS'].apply(lambda x: ast.literal_eval(x))
idxs=[]#한개만 있는것 제거
for idx,row in tqdm(validation.iterrows()):
  tmp_list=[]
  for i in validation.iloc[idx]['ITEMS']:
    tmp_list.append(i.split('_')[0])
  tmp_set=set(tmp_list)
  if len(tmp_set)>1:
    idxs.append(idx)
validation=validation.iloc[idxs]
validation.reset_index(drop=True)
def categorize_items(item_list):
    categories = {'상의': [], '하의': [], '아우터': [], '원피스': []}
    for item in item_list:
        for key in categories:
            if item.startswith(key + '_'):
                categories[key].append(item)
    return categories

validation['ITEMS'] = validation['ITEMS'].apply(categorize_items)
def sample_tpo_items(df, sample_count):
    """
    TPO 기반 패션 데이터셋에서 랜덤으로 sample_count만큼 추출합니다.

    Args:
        df (pd.DataFrame): TPO 데이터프레임 (ID, TPO, ITEMS 컬럼 포함)
        sample_count (int): 추출할 행 개수

    Returns:
        pd.DataFrame: 무작위로 추출된 부분 데이터프레임
    """
    sample_count = min(sample_count, len(df))
    return df.sample(n=sample_count, random_state=None).reset_index(drop=True)
validation=sample_tpo_items(validation,200)
user_clothes={'아우터':[],'상의':[],'원피스':[],'하의':[]}
cat=['아우터','상의','원피스','하의']
for idx in range(len(validation['ITEMS'])):
  items=validation['ITEMS'].iloc[idx]
  for i in cat:
    input_tmp=[]
    if len(items[i])>0:
      input_tmp.append(validation['ID'].iloc[idx])
      for ii in items[i]:
        input_tmp.append(ii)
    if len(input_tmp)>0:
      user_clothes[i].append(input_tmp)
# Out:
# 120523it [00:09, 12426.75it/s]

# %%
color_rule=pd.read_csv('rules_c_v11(str).csv',encoding='utf-8')
feature_rule=pd.read_csv('rules_f_v12(str).csv',encoding='utf-8')

# %%
color_rule['log_lift'] = np.log(color_rule['lift'])
feature_rule['log_lift'] = np.log(feature_rule['lift'])
from sklearn.preprocessing import RobustScaler

metrics = ['confidence', 'log_lift', 'leverage']
scaler = RobustScaler()  # 이상치에 덜 민감
color_rule[metrics] = scaler.fit_transform(color_rule[metrics])
feature_rule[metrics] = scaler.fit_transform(feature_rule[metrics])

color_rule['score'] = (
    0.3 * color_rule['confidence'] +     # 신뢰도
    0.6 * color_rule['log_lift'] + # lift 로그화 (양수/음수 포함)
    0.1 * color_rule['leverage']          # 양수/음수 다 포함됨
)
feature_rule['score'] = (
    0.3 * feature_rule['confidence'] +     # 신뢰도
    0.6 * feature_rule['log_lift'] +       # lift 로그화 (양수/음수 포함)
    0.1 * feature_rule['leverage']      # 양수/음수 다 포함됨
)
color_rule = color_rule[['antecedents', 'consequents', 'score']]
feature_rule = feature_rule[['antecedents', 'consequents', 'score']]

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from collections import defaultdict

df=feature_rule

# 기준 리스트
criteria_list = ['기장', '카테고리', '소재', '핏', '소매기장', '넥라인', '옷깃']

# 가운데 속성 추출 함수
def extract_kinds(row):
    kinds = set()
    for field in ['antecedents', 'consequents']:
        items = row[field]
        if isinstance(items, str):
            items = [item.strip() for item in items.split(',')]
        for item in items:
            parts = item.split('_')
            if len(parts) == 3:
                _, kind, _ = parts
                kinds.add(kind)
    return kinds

# 기준별로 행을 모을 딕셔너리
criterion_rows = defaultdict(list)

# 각 행에서 기준별로 분류
for idx, row in df.iterrows():
    kinds = extract_kinds(row)
    for kind in kinds:
        if kind in criteria_list:
            criterion_rows[kind].append(idx)  # 행 인덱스를 저장

# 결과 누적 리스트
normalized_rows = []

# 기준별 정규화 수행
for kind, indices in criterion_rows.items():
    subset = df.loc[indices].copy()
    scaler = StandardScaler()
    subset['score'] = scaler.fit_transform(subset[['score']])
    subset['기준'] = kind
    normalized_rows.append(subset)

# 최종 합치기
normalized_df = pd.concat(normalized_rows, ignore_index=True)

# 결과 확인

feature_rule=normalized_df[['antecedents', 'consequents', 'score']]

# %%
import pandas as pd
from collections import defaultdict

# 점수화 기준 리스트
criteria_list = ['기장', '카테고리', '소재', '핏', '소매기장', '넥라인', '옷깃']

# 각 행에서 'antecedents'와 'consequents'를 합쳐 가운데 속성(kind) 추출
def extract_kinds(row):
    kinds = set()
    for field in ['antecedents', 'consequents']:
        items = row[field]
        if isinstance(items, str):
            items = [item.strip() for item in items.split(',')]  # 문자열이라면 리스트로 분리
        for item in items:
            parts = item.split('_')
            if len(parts) == 3:
                _, kind, _ = parts
                kinds.add(kind)
    return kinds

# 기준별 score 누적용 딕셔너리
score_dict = defaultdict(list)

# 각 행 처리
for _, row in df.iterrows():
    kinds = extract_kinds(row)
    for kind in kinds:
        if kind in criteria_list:
            score_dict[kind].append(row['score'])

# 평균 계산
mean_scores = {
    kind: sum(scores) / len(scores) if scores else float('nan')
    for kind, scores in score_dict.items()
}

# 결과를 DataFrame으로 정리
mean_scores_df = pd.DataFrame(list(mean_scores.items()), columns=['기준', 'score 평균']).sort_values(by='score 평균', ascending=False)

# 출력
print(mean_scores_df)
# Out:
#      기준  score 평균
# 5    옷깃  5.928946
# 2    소재  0.306526
# 3  카테고리  0.014893
# 0    기장  0.008949
# 1  소매기장 -0.032025
# 4     핏 -0.177341

# %%
from sklearn.preprocessing import StandardScaler

# color_rule 데이터프레임이 있다고 가정
# 예: color_df = pd.read_csv("color_rule.csv")

# 복사본 생성 (안전하게)
color_df_normalized = color_rule.copy()

# 정규화 수행
scaler = StandardScaler()
color_df_normalized['score'] = scaler.fit_transform(color_rule[['score']])

color_rule=color_df_normalized

# %%
#Dict로 rules 데이터 프레임을 변환
def rules_to_dict_sorted_key(rules_df, is_color=False):
    rules = {}
    for _, row in rules_df.iterrows():
        a = str(row['antecedents']).strip()
        b = str(row['consequents']).strip()
        if is_color:
            a = a.split('_')[-1]
            b = b.split('_')[-1]
        key = tuple(sorted([a, b]))
        rules[key] = float(row['score'])
    return rules
color_dict = rules_to_dict_sorted_key(color_rule, is_color=True)
feature_dict = rules_to_dict_sorted_key(feature_rule, is_color=False)

# %%
def score_recommendation_dict_sorted_key(item, cat, color_dict, feature_dict, user_clothes, color_rate=1):
    current_id = item[0]
    current_features = set(item[2:])

    if not current_features:
        return {'input_ID': current_id, 'input_cat': cat, 'recommendation': {}}

    compare_categories = ['상의', '하의', '아우터', '원피스']
    if cat in compare_categories:
        compare_categories.remove(cat)

    recommend_dict = {}

    for category in compare_categories:
        item_scores = {}

        for user_item in user_clothes.get(category, []):
            item_raw_id = user_item[0]
            features = user_item[2:]
            item_id = f"{category}_{item_raw_id}"

            score = 0
            for input_feature in current_features:
                input_type = input_feature.split('_')[1]

                for user_feature in features:
                    user_type = user_feature.split('_')[1]

                    if input_type != user_type:
                        continue

                    if input_type == '색상':
                        color1 = input_feature.split('_')[-1]
                        color2 = user_feature.split('_')[-1]
                        key=[color1,color2]
                        key=tuple(sorted(key))
                        raw_score = color_dict.get(key, 0)
                        score += raw_score * color_rate
                    else:
                        key=[input_feature,user_feature]
                        key=tuple(sorted(key))
                        raw_score = feature_dict.get(key, 0)
                        score += raw_score

            item_scores[item_id] = score

        recommend_dict[category] = dict(sorted(item_scores.items(), key=lambda x: x[1], reverse=True))

    return {
        'input_ID': current_id,
        'input_cat': cat,
        'recommendation': recommend_dict
    }

# %%
from concurrent.futures import ProcessPoolExecutor, as_completed
from tqdm import tqdm
import multiprocessing

def recommend_clothes_parallel_sorted(validation_input_dict, color_dict, feature_dict, user_clothes, color_rate=1):
    args = []

    for cat, items in validation_input_dict.items():
        for item in items:
            args.append((item, cat, color_dict, feature_dict, user_clothes, color_rate))

    results = []

    with ProcessPoolExecutor(max_workers=multiprocessing.cpu_count()) as executor:
        futures = [executor.submit(score_recommendation_dict_sorted_key, *arg) for arg in args]
        for future in tqdm(as_completed(futures), total=len(futures), desc="Processing recommendations"):
            results.append(future.result())

    return pd.DataFrame(results)

# %%
import pickle
with open('mlb.pkl', 'rb') as f:
    mlb = pickle.load(f)

# %%
import pandas as pd
from sklearn.preprocessing import MultiLabelBinarizer
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
label_to_idx={'스트리트': 0,
 '페미닌': 1,
 '모던': 2,
 '클래식': 3,
 '로맨틱': 4,
 '아방가르드': 5,
 '리조트': 6,
 '소피스트케이티드': 7,
 '웨스턴': 8,
 '키치': 9,
 '톰보이': 10,
 '매니시': 11,
 '레트로': 12,
 '컨트리': 13,
 '힙합': 14,
 '스포티': 15,
 '젠더리스': 16,
 '프레피': 17,
 '밀리터리': 18,
 '히피': 19,
 '섹시': 20,
 '펑크': 21,
 '오리엔탈': 22}

class DMLP(nn.Module):
  def __init__(self, input_size, num_classes):
      super(DMLP, self).__init__()
      self.net = nn.Sequential(
          nn.Linear(input_size, 512),
          nn.BatchNorm1d(512),
          nn.ReLU(),
          nn.Dropout(0.3),
          nn.Linear(512, 256),
          nn.BatchNorm1d(256),
          nn.ReLU(),
          nn.Dropout(0.3),
          nn.Linear(256, 128),
          nn.ReLU(),
          nn.Linear(128, num_classes)
      )

  def forward(self, x):
      return self.net(x)

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model=torch.load('/content/style_dmlp.pth',weights_only=False,map_location=device)
def predict_top3_tpo(items, model, mlb, label_to_idx, device='cpu'):
    # 인코딩 및 텐서 변환
    sample_X = mlb.transform([items])
    sample_X = torch.tensor(sample_X, dtype=torch.float32).to(device)

    # 모델 추론
    model.eval()
    with torch.no_grad():
        output = model(sample_X)
        probs = torch.softmax(output, dim=1).cpu().numpy()[0]

    # 상위 3개 인덱스
    top3_indices = probs.argsort()[-3:][::-1]

    # 인덱스를 라벨로 매핑
    idx_to_label = {idx: label for label, idx in label_to_idx.items()}
    top3_labels = {idx_to_label[i]: round(probs[i], 4) for i in top3_indices}

    return top3_labels
for category, clothes_list in user_clothes.items():
    for i, item in enumerate(clothes_list):
        item_features = item[1:]  # 2번째 요소 이후 특징만 추출
        prediction = predict_top3_tpo(
            items=item_features,
            model=model,
            mlb=mlb,
            label_to_idx=label_to_idx,
            device=device
        )
        # 두 번째 위치에 예측 결과 딕셔너리 삽입
        user_clothes[category][i] = [item[0], prediction] + item[1:]

# %%
user_clothes
# Out:
# {'아우터': [[np.int64(1062492),
#    {'스트리트': np.float32(0.7875),
#     '컨트리': np.float32(0.0493),
#     '로맨틱': np.float32(0.0307)},
#    '아우터_기장_노말',
#    '아우터_색상_핑크',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_브이넥',
#    '아우터_핏_노멀'],
#   [np.int64(874966),
#    {'스트리트': np.float32(0.6117),
#     '리조트': np.float32(0.0697),
#     '로맨틱': np.float32(0.0648)},
#    '아우터_기장_하프',
#    '아우터_색상_블랙',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_노멀'],
#   [np.int64(982022),
#    {'스트리트': np.float32(0.8534),
#     '클래식': np.float32(0.0381),
#     '소피스트케이티드': np.float32(0.0352)},
#    '아우터_기장_하프',
#    '아우터_색상_네온',
#    '아우터_카테고리_코트',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_후드',
#    '아우터_핏_노멀'],
#   [np.int64(371876),
#    {'스트리트': np.float32(0.761),
#     '로맨틱': np.float32(0.0496),
#     '리조트': np.float32(0.0348)},
#    '아우터_기장_롱',
#    '아우터_색상_블랙',
#    '아우터_카테고리_코트',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_노멀'],
#   [np.int64(183539),
#    {'스트리트': np.float32(0.6502),
#     '리조트': np.float32(0.0619),
#     '클래식': np.float32(0.0569)},
#    '아우터_기장_하프',
#    '아우터_색상_그레이',
#    '아우터_카테고리_코트',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_루즈'],
#   [np.int64(801799),
#    {'스트리트': np.float32(0.7517),
#     '페미닌': np.float32(0.0687),
#     '모던': np.float32(0.0664)},
#    '아우터_기장_하프',
#    '아우터_색상_베이지',
#    '아우터_카테고리_짚업',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_터틀넥',
#    '아우터_핏_루즈'],
#   [np.int64(1129354),
#    {'스트리트': np.float32(0.7465),
#     '로맨틱': np.float32(0.0443),
#     '페미닌': np.float32(0.0441)},
#    '아우터_기장_롱',
#    '아우터_색상_베이지',
#    '아우터_카테고리_코트',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_루즈'],
#   [np.int64(1223964),
#    {'스트리트': np.float32(0.5467),
#     '소피스트케이티드': np.float32(0.1562),
#     '모던': np.float32(0.1202)},
#    '아우터_기장_노말',
#    '아우터_색상_그레이',
#    '아우터_카테고리_짚업',
#    '아우터_소매기장_캡',
#    '아우터_넥라인_터틀넥',
#    '아우터_핏_노멀'],
#   [np.int64(32894),
#    {'스트리트': np.float32(0.6731),
#     '페미닌': np.float32(0.0566),
#     '소피스트케이티드': np.float32(0.0489)},
#    '아우터_색상_브라운',
#    '아우터_소매기장_긴팔'],
#   [np.int64(665095),
#    {'스트리트': np.float32(0.5693),
#     '리조트': np.float32(0.1219),
#     '페미닌': np.float32(0.094)},
#    '아우터_기장_노말',
#    '아우터_색상_화이트',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_7부소매',
#    '아우터_넥라인_노카라',
#    '아우터_핏_노멀'],
#   [np.int64(925635),
#    {'스트리트': np.float32(0.6744),
#     '모던': np.float32(0.1003),
#     '페미닌': np.float32(0.0817)},
#    '아우터_기장_하프',
#    '아우터_색상_카키',
#    '아우터_카테고리_점퍼',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_노카라',
#    '아우터_핏_오버사이즈'],
#   [np.int64(605389),
#    {'스트리트': np.float32(0.6717),
#     '페미닌': np.float32(0.0556),
#     '로맨틱': np.float32(0.0489)},
#    '아우터_기장_노말',
#    '아우터_카테고리_재킷',
#    '아우터_핏_노멀'],
#   [np.int64(435108),
#    {'스트리트': np.float32(0.6853),
#     '리조트': np.float32(0.0888),
#     '페미닌': np.float32(0.0414)},
#    '아우터_기장_노말',
#    '아우터_색상_카키',
#    '아우터_카테고리_점퍼',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_루즈'],
#   [np.int64(1005223),
#    {'스트리트': np.float32(0.6078),
#     '리조트': np.float32(0.0966),
#     '페미닌': np.float32(0.0658)},
#    '아우터_기장_노말',
#    '아우터_색상_베이지',
#    '아우터_카테고리_가디건',
#    '아우터_소매기장_민소매'],
#   [np.int64(153293),
#    {'스트리트': np.float32(0.5397),
#     '클래식': np.float32(0.1165),
#     '컨트리': np.float32(0.0907)},
#    '아우터_기장_하프',
#    '아우터_색상_블랙',
#    '아우터_카테고리_베스트',
#    '아우터_소매기장_민소매',
#    '아우터_핏_노멀'],
#   [np.int64(819372),
#    {'스트리트': np.float32(0.5095),
#     '스포티': np.float32(0.1813),
#     '로맨틱': np.float32(0.0923)},
#    '아우터_기장_하프',
#    '아우터_색상_핑크',
#    '아우터_카테고리_가디건',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_브이넥',
#    '아우터_핏_루즈'],
#   [np.int64(613978),
#    {'스트리트': np.float32(0.7051),
#     '리조트': np.float32(0.0526),
#     '소피스트케이티드': np.float32(0.0417)},
#    '아우터_기장_롱',
#    '아우터_색상_베이지',
#    '아우터_카테고리_가디건',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_루즈'],
#   [np.int64(1684),
#    {'스트리트': np.float32(0.9309),
#     '로맨틱': np.float32(0.0173),
#     '페미닌': np.float32(0.0137)},
#    '아우터_기장_노말',
#    '아우터_색상_베이지',
#    '아우터_카테고리_코트',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_루즈'],
#   [np.int64(953141),
#    {'스트리트': np.float32(0.7232),
#     '로맨틱': np.float32(0.0497),
#     '페미닌': np.float32(0.045)},
#    '아우터_기장_롱',
#    '아우터_색상_그레이',
#    '아우터_카테고리_코트',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_노멀'],
#   [np.int64(1173062),
#    {'스트리트': np.float32(0.6379),
#     '페미닌': np.float32(0.0614),
#     '로맨틱': np.float32(0.0562)},
#    '아우터_색상_카키',
#    '아우터_소매기장_긴팔'],
#   [np.int64(1107378),
#    {'스트리트': np.float32(0.7289),
#     '페미닌': np.float32(0.0542),
#     '모던': np.float32(0.0412)},
#    '아우터_기장_하프',
#    '아우터_색상_블랙',
#    '아우터_카테고리_점퍼',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_노카라',
#    '아우터_핏_노멀'],
#   [np.int64(894989),
#    {'스트리트': np.float32(0.7947),
#     '리조트': np.float32(0.0435),
#     '로맨틱': np.float32(0.0423)},
#    '아우터_기장_하프',
#    '아우터_색상_베이지',
#    '아우터_카테고리_가디건',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_브이넥',
#    '아우터_핏_루즈'],
#   [np.int64(1054030),
#    {'스트리트': np.float32(0.6615),
#     '클래식': np.float32(0.0596),
#     '리조트': np.float32(0.0546)},
#    '아우터_기장_하프',
#    '아우터_색상_베이지',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_노멀'],
#   [np.int64(1286060),
#    {'스트리트': np.float32(0.7781),
#     '페미닌': np.float32(0.0401),
#     '젠더리스': np.float32(0.0351)},
#    '아우터_기장_하프',
#    '아우터_카테고리_베스트',
#    '아우터_핏_노멀'],
#   [np.int64(705888),
#    {'스트리트': np.float32(0.4458),
#     '컨트리': np.float32(0.1123),
#     '리조트': np.float32(0.1008)},
#    '아우터_색상_베이지',
#    '아우터_소매기장_반팔'],
#   [np.int64(353077),
#    {'스트리트': np.float32(0.6273),
#     '로맨틱': np.float32(0.0772),
#     '페미닌': np.float32(0.0519)},
#    '아우터_기장_하프',
#    '아우터_색상_화이트',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_반팔',
#    '아우터_핏_노멀'],
#   [np.int64(43229),
#    {'스트리트': np.float32(0.5953),
#     '페미닌': np.float32(0.0691),
#     '클래식': np.float32(0.0633)},
#    '아우터_기장_하프',
#    '아우터_색상_그레이',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_루즈'],
#   [np.int64(347382),
#    {'스트리트': np.float32(0.5103),
#     '로맨틱': np.float32(0.0908),
#     '모던': np.float32(0.0879)},
#    '아우터_기장_하프',
#    '아우터_색상_그레이',
#    '아우터_카테고리_가디건',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_노카라',
#    '아우터_핏_노멀'],
#   [np.int64(904555),
#    {'스트리트': np.float32(0.6128),
#     '로맨틱': np.float32(0.0702),
#     '페미닌': np.float32(0.0622)},
#    '아우터_기장_노말',
#    '아우터_색상_화이트',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_7부소매',
#    '아우터_핏_노멀'],
#   [np.int64(199772),
#    {'스트리트': np.float32(0.6795),
#     '리조트': np.float32(0.0744),
#     '컨트리': np.float32(0.0619)},
#    '아우터_기장_노말',
#    '아우터_카테고리_재킷',
#    '아우터_넥라인_브이넥',
#    '아우터_핏_타이트'],
#   [np.int64(1057540),
#    {'스트리트': np.float32(0.5754),
#     '스포티': np.float32(0.2858),
#     '로맨틱': np.float32(0.0411)},
#    '아우터_기장_하프',
#    '아우터_색상_실버',
#    '아우터_카테고리_패딩',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_터틀넥',
#    '아우터_핏_루즈'],
#   [np.int64(1141231),
#    {'스트리트': np.float32(0.8003),
#     '리조트': np.float32(0.0374),
#     '클래식': np.float32(0.0359)},
#    '아우터_기장_하프',
#    '아우터_색상_베이지',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_반팔',
#    '아우터_핏_노멀'],
#   [np.int64(314398),
#    {'스트리트': np.float32(0.7013),
#     '로맨틱': np.float32(0.0525),
#     '클래식': np.float32(0.046)},
#    '아우터_기장_하프',
#    '아우터_색상_베이지',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_라운드넥',
#    '아우터_핏_노멀'],
#   [np.int64(998651),
#    {'스트리트': np.float32(0.788),
#     '페미닌': np.float32(0.0446),
#     '소피스트케이티드': np.float32(0.0272)},
#    '아우터_카테고리_가디건',
#    '아우터_넥라인_브이넥',
#    '아우터_핏_노멀'],
#   [np.int64(41267),
#    {'스트리트': np.float32(0.6733),
#     '로맨틱': np.float32(0.0779),
#     '리조트': np.float32(0.0512)},
#    '아우터_기장_롱',
#    '아우터_색상_블랙',
#    '아우터_카테고리_가디건',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_노멀'],
#   [np.int64(828493),
#    {'스트리트': np.float32(0.6271),
#     '클래식': np.float32(0.065),
#     '페미닌': np.float32(0.0601)},
#    '아우터_기장_노말',
#    '아우터_카테고리_재킷',
#    '아우터_핏_루즈'],
#   [np.int64(322042),
#    {'스트리트': np.float32(0.2649),
#     '리조트': np.float32(0.1716),
#     '페미닌': np.float32(0.1368)},
#    '아우터_색상_베이지',
#    '아우터_소매기장_민소매'],
#   [np.int64(870816),
#    {'스트리트': np.float32(0.6615),
#     '클래식': np.float32(0.0596),
#     '리조트': np.float32(0.0546)},
#    '아우터_기장_하프',
#    '아우터_색상_베이지',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_노멀'],
#   [np.int64(788047),
#    {'스트리트': np.float32(0.5771),
#     '페미닌': np.float32(0.1612),
#     '소피스트케이티드': np.float32(0.1275)},
#    '아우터_기장_맥시',
#    '아우터_색상_골드',
#    '아우터_카테고리_가디건',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_루즈'],
#   [np.int64(1000075),
#    {'스트리트': np.float32(0.5923),
#     '페미닌': np.float32(0.077),
#     '리조트': np.float32(0.0591)},
#    '아우터_기장_롱',
#    '아우터_색상_카키',
#    '아우터_카테고리_가디건',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_노카라',
#    '아우터_핏_루즈'],
#   [np.int64(1061385),
#    {'스트리트': np.float32(0.4874),
#     '모던': np.float32(0.1207),
#     '페미닌': np.float32(0.1083)},
#    '아우터_기장_하프',
#    '아우터_색상_베이지',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_노카라',
#    '아우터_핏_오버사이즈'],
#   [np.int64(964957),
#    {'스트리트': np.float32(0.5434),
#     '페미닌': np.float32(0.1314),
#     '클래식': np.float32(0.0549)},
#    '아우터_기장_노말',
#    '아우터_색상_베이지',
#    '아우터_카테고리_짚업',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_후드',
#    '아우터_핏_루즈'],
#   [np.int64(769528),
#    {'스트리트': np.float32(0.5354),
#     '페미닌': np.float32(0.0954),
#     '리조트': np.float32(0.0736)},
#    '아우터_기장_하프',
#    '아우터_카테고리_재킷',
#    '아우터_핏_루즈'],
#   [np.int64(149126),
#    {'스트리트': np.float32(0.6302),
#     '페미닌': np.float32(0.094),
#     '로맨틱': np.float32(0.052)},
#    '아우터_기장_하프',
#    '아우터_색상_블랙',
#    '아우터_카테고리_점퍼',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_후드',
#    '아우터_핏_루즈'],
#   [np.int64(492805),
#    {'스트리트': np.float32(0.7425),
#     '페미닌': np.float32(0.048),
#     '로맨틱': np.float32(0.0377)},
#    '아우터_기장_노말',
#    '아우터_색상_베이지',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_노멀'],
#   [np.int64(805434),
#    {'스트리트': np.float32(0.7077),
#     '컨트리': np.float32(0.0993),
#     '리조트': np.float32(0.0697)},
#    '아우터_기장_노말',
#    '아우터_색상_오렌지',
#    '아우터_카테고리_베스트',
#    '아우터_소매기장_민소매',
#    '아우터_넥라인_브이넥',
#    '아우터_핏_노멀'],
#   [np.int64(1297962),
#    {'스트리트': np.float32(0.6771),
#     '클래식': np.float32(0.0729),
#     '페미닌': np.float32(0.069)},
#    '아우터_기장_노말',
#    '아우터_색상_베이지',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_반팔',
#    '아우터_넥라인_브이넥',
#    '아우터_핏_루즈'],
#   [np.int64(1221344),
#    {'스트리트': np.float32(0.4974),
#     '페미닌': np.float32(0.0929),
#     '리조트': np.float32(0.0926)},
#    '아우터_기장_롱',
#    '아우터_색상_베이지',
#    '아우터_카테고리_베스트',
#    '아우터_소매기장_민소매',
#    '아우터_넥라인_노카라',
#    '아우터_핏_루즈']],
#  '상의': [[np.int64(1216062),
#    {'스트리트': np.float32(0.6033),
#     '페미닌': np.float32(0.0803),
#     '로맨틱': np.float32(0.0581)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(1202131),
#    {'스트리트': np.float32(0.5728),
#     '페미닌': np.float32(0.0841),
#     '로맨틱': np.float32(0.0673)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(871706),
#    {'스트리트': np.float32(0.6085),
#     '페미닌': np.float32(0.075),
#     '로맨틱': np.float32(0.0614)},
#    '상의_색상_블랙',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(741110),
#    {'스트리트': np.float32(0.6939),
#     '로맨틱': np.float32(0.0499),
#     '페미닌': np.float32(0.0455)},
#    '상의_색상_베이지',
#    '상의_카테고리_셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(505625),
#    {'스트리트': np.float32(0.6273),
#     '페미닌': np.float32(0.0809),
#     '로맨틱': np.float32(0.0542)},
#    '상의_색상_블랙',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(406557),
#    {'스트리트': np.float32(0.5449),
#     '페미닌': np.float32(0.1032),
#     '클래식': np.float32(0.0976)},
#    '상의_색상_그레이',
#    '상의_카테고리_셔츠',
#    '상의_옷깃_셔츠칼라',
#    '상의_소매기장_7부소매',
#    '상의_소재_우븐',
#    '상의_핏_오버사이즈'],
#   [np.int64(874986),
#    {'스트리트': np.float32(0.5698),
#     '페미닌': np.float32(0.1485),
#     '소피스트케이티드': np.float32(0.0532)},
#    '상의_색상_블랙',
#    '상의_카테고리_탑',
#    '상의_소매기장_민소매',
#    '상의_소재_스판덱스',
#    '상의_핏_타이트'],
#   [np.int64(687472),
#    {'스트리트': np.float32(0.6819),
#     '페미닌': np.float32(0.0726),
#     '로맨틱': np.float32(0.0634)},
#    '상의_색상_와인',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(1062492),
#    {'스트리트': np.float32(0.6682),
#     '로맨틱': np.float32(0.092),
#     '컨트리': np.float32(0.0513)},
#    '상의_색상_화이트',
#    '상의_카테고리_탑',
#    '상의_소매기장_없음',
#    '상의_소재_실크',
#    '상의_핏_타이트'],
#   [np.int64(874966),
#    {'스트리트': np.float32(0.5915),
#     '페미닌': np.float32(0.0799),
#     '로맨틱': np.float32(0.0641)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(765219),
#    {'스트리트': np.float32(0.6838),
#     '리조트': np.float32(0.0529),
#     '페미닌': np.float32(0.0478)},
#    '상의_색상_화이트',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(1091376),
#    {'스트리트': np.float32(0.5915),
#     '페미닌': np.float32(0.0799),
#     '로맨틱': np.float32(0.0641)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(1050805),
#    {'스트리트': np.float32(0.5976),
#     '페미닌': np.float32(0.079),
#     '클래식': np.float32(0.0585)},
#    '상의_색상_네이비',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(856474),
#    {'스트리트': np.float32(0.5692),
#     '페미닌': np.float32(0.0903),
#     '로맨틱': np.float32(0.0872)},
#    '상의_색상_레드',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(1144042),
#    {'스트리트': np.float32(0.3473),
#     '클래식': np.float32(0.1147),
#     '페미닌': np.float32(0.1062)},
#    '상의_색상_골드',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(982022),
#    {'스트리트': np.float32(0.5989),
#     '페미닌': np.float32(0.078),
#     '리조트': np.float32(0.0621)},
#    '상의_카테고리_티셔츠',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(813352),
#    {'스트리트': np.float32(0.5889),
#     '페미닌': np.float32(0.0766),
#     '로맨틱': np.float32(0.0597)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(91322),
#    {'스트리트': np.float32(0.4687),
#     '페미닌': np.float32(0.0876),
#     '로맨틱': np.float32(0.084)},
#    '상의_색상_화이트',
#    '상의_카테고리_탑',
#    '상의_소매기장_민소매',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(183539),
#    {'스트리트': np.float32(0.6914),
#     '리조트': np.float32(0.0548),
#     '페미닌': np.float32(0.0529)},
#    '상의_카테고리_니트웨어',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(1129354),
#    {'스트리트': np.float32(0.6657),
#     '로맨틱': np.float32(0.1215),
#     '페미닌': np.float32(0.0461)},
#    '상의_색상_블랙',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_없음',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(346111),
#    {'스트리트': np.float32(0.5889),
#     '페미닌': np.float32(0.0766),
#     '로맨틱': np.float32(0.0597)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(360257),
#    {'스트리트': np.float32(0.567),
#     '페미닌': np.float32(0.0856),
#     '소피스트케이티드': np.float32(0.0665)},
#    '상의_색상_화이트',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(32894),
#    {'스트리트': np.float32(0.6573),
#     '로맨틱': np.float32(0.0801),
#     '페미닌': np.float32(0.0527)},
#    '상의_카테고리_니트웨어',
#    '상의_소재_니트',
#    '상의_핏_루즈'],
#   [np.int64(512576),
#    {'스트리트': np.float32(0.5291),
#     '페미닌': np.float32(0.1728),
#     '리조트': np.float32(0.0615)},
#    '상의_색상_민트',
#    '상의_카테고리_후드티',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(503800),
#    {'스트리트': np.float32(0.6617),
#     '페미닌': np.float32(0.0766),
#     '로맨틱': np.float32(0.0594)},
#    '상의_색상_브라운',
#    '상의_소매기장_민소매'],
#   [np.int64(267942),
#    {'스트리트': np.float32(0.6058),
#     '페미닌': np.float32(0.0636),
#     '모던': np.float32(0.0627)},
#    '상의_색상_그레이',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(816082),
#    {'스트리트': np.float32(0.5691),
#     '페미닌': np.float32(0.0755),
#     '스포티': np.float32(0.0597)},
#    '상의_색상_핑크',
#    '상의_카테고리_탑',
#    '상의_소매기장_민소매',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(617856),
#    {'스트리트': np.float32(0.6559),
#     '모던': np.float32(0.0606),
#     '소피스트케이티드': np.float32(0.0502)},
#    '상의_색상_레드',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_7부소매',
#    '상의_소재_울/캐시미어',
#    '상의_핏_루즈'],
#   [np.int64(876278),
#    {'스트리트': np.float32(0.639),
#     '페미닌': np.float32(0.0712),
#     '로맨틱': np.float32(0.0569)},
#    '상의_색상_화이트',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_반팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(998731),
#    {'스트리트': np.float32(0.6085),
#     '페미닌': np.float32(0.075),
#     '로맨틱': np.float32(0.0614)},
#    '상의_색상_블랙',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(1521),
#    {'스트리트': np.float32(0.572),
#     '로맨틱': np.float32(0.0691),
#     '페미닌': np.float32(0.0588)},
#    '상의_색상_핑크',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(155016),
#    {'스트리트': np.float32(0.5671),
#     '페미닌': np.float32(0.089),
#     '로맨틱': np.float32(0.0595)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(717398),
#    {'스트리트': np.float32(0.5839),
#     '페미닌': np.float32(0.0753),
#     '리조트': np.float32(0.0631)},
#    '상의_색상_베이지',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(605389),
#    {'스트리트': np.float32(0.6155),
#     '리조트': np.float32(0.0725),
#     '로맨틱': np.float32(0.0578)},
#    '상의_색상_블루',
#    '상의_소매기장_긴팔'],
#   [np.int64(1167218),
#    {'스트리트': np.float32(0.5541),
#     '로맨틱': np.float32(0.0934),
#     '페미닌': np.float32(0.0749)},
#    '상의_색상_스카이블루',
#    '상의_카테고리_탑',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(846122),
#    {'스트리트': np.float32(0.6085),
#     '페미닌': np.float32(0.075),
#     '로맨틱': np.float32(0.0614)},
#    '상의_색상_블랙',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(602638),
#    {'스트리트': np.float32(0.6326),
#     '페미닌': np.float32(0.0725),
#     '로맨틱': np.float32(0.0678)},
#    '상의_색상_화이트',
#    '상의_카테고리_블라우스',
#    '상의_옷깃_차이나칼라',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(890683),
#    {'스트리트': np.float32(0.6033),
#     '페미닌': np.float32(0.0803),
#     '로맨틱': np.float32(0.0581)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(435108),
#    {'스트리트': np.float32(0.5989),
#     '페미닌': np.float32(0.078),
#     '리조트': np.float32(0.0621)},
#    '상의_카테고리_티셔츠',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(919475),
#    {'스트리트': np.float32(0.7107),
#     '클래식': np.float32(0.0561),
#     '리조트': np.float32(0.0556)},
#    '상의_색상_와인',
#    '상의_카테고리_블라우스',
#    '상의_옷깃_셔츠칼라',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(902820),
#    {'스트리트': np.float32(0.7356),
#     '소피스트케이티드': np.float32(0.0667),
#     '페미닌': np.float32(0.058)},
#    '상의_색상_라벤더',
#    '상의_카테고리_블라우스',
#    '상의_옷깃_피터팬칼라',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(153293),
#    {'스트리트': np.float32(0.4245),
#     '페미닌': np.float32(0.1255),
#     '로맨틱': np.float32(0.1107)},
#    '상의_카테고리_티셔츠',
#    '상의_소재_저지',
#    '상의_핏_오버사이즈'],
#   [np.int64(939167),
#    {'스트리트': np.float32(0.6632),
#     '페미닌': np.float32(0.1006),
#     '리조트': np.float32(0.0677)},
#    '상의_색상_베이지',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_7부소매',
#    '상의_소재_저지',
#    '상의_소재_레이스',
#    '상의_핏_루즈'],
#   [np.int64(267773),
#    {'스트리트': np.float32(0.413),
#     '페미닌': np.float32(0.14),
#     '로맨틱': np.float32(0.1065)},
#    '상의_색상_그린',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(498182),
#    {'스트리트': np.float32(0.6397),
#     '페미닌': np.float32(0.0649),
#     '리조트': np.float32(0.0581)},
#    '상의_색상_베이지',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(686442),
#    {'스트리트': np.float32(0.5924),
#     '리조트': np.float32(0.0728),
#     '로맨틱': np.float32(0.0507)},
#    '상의_색상_브라운',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_반팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(1289162),
#    {'스트리트': np.float32(0.2624),
#     '스포티': np.float32(0.1245),
#     '모던': np.float32(0.1057)},
#    '상의_색상_스카이블루',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_7부소매',
#    '상의_소재_실크',
#    '상의_핏_노멀'],
#   [np.int64(613978),
#    {'스트리트': np.float32(0.6758),
#     '페미닌': np.float32(0.0557),
#     '로맨틱': np.float32(0.0526)},
#    '상의_카테고리_탑',
#    '상의_소재_저지',
#    '상의_핏_타이트'],
#   [np.int64(431145),
#    {'스트리트': np.float32(0.6024),
#     '페미닌': np.float32(0.0995),
#     '소피스트케이티드': np.float32(0.0756)},
#    '상의_색상_와인',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_울/캐시미어',
#    '상의_핏_루즈'],
#   [np.int64(727025),
#    {'스트리트': np.float32(0.6165),
#     '페미닌': np.float32(0.0841),
#     '리조트': np.float32(0.0498)},
#    '상의_색상_카키',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_7부소매',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(953141),
#    {'스트리트': np.float32(0.5601),
#     '페미닌': np.float32(0.0812),
#     '소피스트케이티드': np.float32(0.0562)},
#    '상의_카테고리_블라우스',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(268454),
#    {'스트리트': np.float32(0.6087),
#     '페미닌': np.float32(0.0743),
#     '로맨틱': np.float32(0.0612)},
#    '상의_색상_화이트',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_7부소매',
#    '상의_소재_우븐'],
#   [np.int64(736620),
#    {'스트리트': np.float32(0.6397),
#     '페미닌': np.float32(0.0649),
#     '리조트': np.float32(0.0581)},
#    '상의_색상_베이지',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(597173),
#    {'스트리트': np.float32(0.6898),
#     '로맨틱': np.float32(0.0708),
#     '페미닌': np.float32(0.0431)},
#    '상의_색상_네이비',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_반팔',
#    '상의_소재_실크',
#    '상의_핏_노멀'],
#   [np.int64(329991),
#    {'스트리트': np.float32(0.705),
#     '클래식': np.float32(0.1195),
#     '페미닌': np.float32(0.0546)},
#    '상의_색상_베이지',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_반팔',
#    '상의_소재_니트',
#    '상의_소재_울/캐시미어',
#    '상의_핏_타이트'],
#   [np.int64(394189),
#    {'스트리트': np.float32(0.4925),
#     '페미닌': np.float32(0.1203),
#     '로맨틱': np.float32(0.0862)},
#    '상의_색상_스카이블루',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(411754),
#    {'스트리트': np.float32(0.5711),
#     '로맨틱': np.float32(0.0759),
#     '페미닌': np.float32(0.0721)},
#    '상의_색상_브라운',
#    '상의_카테고리_셔츠',
#    '상의_옷깃_셔츠칼라',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(1169213),
#    {'스트리트': np.float32(0.587),
#     '로맨틱': np.float32(0.0665),
#     '페미닌': np.float32(0.063)},
#    '상의_색상_그레이',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(49058),
#    {'스트리트': np.float32(0.7377),
#     '로맨틱': np.float32(0.0555),
#     '모던': np.float32(0.0414)},
#    '상의_색상_네이비',
#    '상의_카테고리_셔츠',
#    '상의_옷깃_셔츠칼라',
#    '상의_소매기장_7부소매',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(1169233),
#    {'스트리트': np.float32(0.6196),
#     '페미닌': np.float32(0.0769),
#     '로맨틱': np.float32(0.0559)},
#    '상의_색상_네이비',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(1173062),
#    {'스트리트': np.float32(0.6458),
#     '로맨틱': np.float32(0.1259),
#     '페미닌': np.float32(0.0703)},
#    '상의_색상_옐로우',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_없음',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(1107378),
#    {'스트리트': np.float32(0.6792),
#     '페미닌': np.float32(0.056),
#     '리조트': np.float32(0.0503)},
#    '상의_색상_그레이',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(899340),
#    {'스트리트': np.float32(0.6959),
#     '로맨틱': np.float32(0.0622),
#     '페미닌': np.float32(0.0557)},
#    '상의_색상_베이지',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_루즈'],
#   [np.int64(884830),
#    {'스트리트': np.float32(0.6882),
#     '페미닌': np.float32(0.0558),
#     '모던': np.float32(0.0525)},
#    '상의_색상_블랙',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_타이트'],
#   [np.int64(305108),
#    {'스트리트': np.float32(0.4055),
#     '페미닌': np.float32(0.0957),
#     '소피스트케이티드': np.float32(0.0932)},
#    '상의_색상_카키',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(1102961),
#    {'스트리트': np.float32(0.4915),
#     '페미닌': np.float32(0.0834),
#     '리조트': np.float32(0.0803)},
#    '상의_색상_브라운',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(938387),
#    {'스트리트': np.float32(0.7384),
#     '페미닌': np.float32(0.0476),
#     '리조트': np.float32(0.0441)},
#    '상의_색상_베이지',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_타이트'],
#   [np.int64(1152234),
#    {'스트리트': np.float32(0.5839),
#     '페미닌': np.float32(0.0753),
#     '리조트': np.float32(0.0631)},
#    '상의_색상_베이지',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(1166488),
#    {'스트리트': np.float32(0.6437),
#     '클래식': np.float32(0.065),
#     '페미닌': np.float32(0.0548)},
#    '상의_색상_화이트',
#    '상의_카테고리_셔츠',
#    '상의_옷깃_셔츠칼라',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(217038),
#    {'스트리트': np.float32(0.7041),
#     '페미닌': np.float32(0.0569),
#     '클래식': np.float32(0.043)},
#    '상의_색상_베이지',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_반팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(960617),
#    {'스트리트': np.float32(0.666),
#     '페미닌': np.float32(0.0569),
#     '로맨틱': np.float32(0.0523)},
#    '상의_색상_화이트',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_울/캐시미어',
#    '상의_핏_루즈'],
#   [np.int64(1187768),
#    {'스트리트': np.float32(0.5761),
#     '페미닌': np.float32(0.0807),
#     '로맨틱': np.float32(0.0601)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(1100646),
#    {'스트리트': np.float32(0.5818),
#     '페미닌': np.float32(0.0911),
#     '로맨틱': np.float32(0.0717)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_오버사이즈'],
#   [np.int64(707696),
#    {'스트리트': np.float32(0.5966),
#     '로맨틱': np.float32(0.0804),
#     '페미닌': np.float32(0.0684)},
#    '상의_색상_화이트',
#    '상의_카테고리_탑',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(598401),
#    {'스트리트': np.float32(0.6297),
#     '모던': np.float32(0.0573),
#     '페미닌': np.float32(0.0536)},
#    '상의_색상_블랙',
#    '상의_카테고리_탑',
#    '상의_소매기장_7부소매',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(665208),
#    {'스트리트': np.float32(0.4915),
#     '페미닌': np.float32(0.0834),
#     '리조트': np.float32(0.0803)},
#    '상의_색상_브라운',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(769938),
#    {'스트리트': np.float32(0.4905),
#     '페미닌': np.float32(0.0957),
#     '로맨틱': np.float32(0.0914)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_니트',
#    '상의_핏_오버사이즈'],
#   [np.int64(1237181),
#    {'스트리트': np.float32(0.6554),
#     '페미닌': np.float32(0.0717),
#     '로맨틱': np.float32(0.0595)},
#    '상의_색상_화이트',
#    '상의_소매기장_7부소매'],
#   [np.int64(1259829),
#    {'스트리트': np.float32(0.6338),
#     '로맨틱': np.float32(0.0786),
#     '페미닌': np.float32(0.0746)},
#    '상의_색상_베이지',
#    '상의_카테고리_탑',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(1341201),
#    {'스트리트': np.float32(0.5902),
#     '페미닌': np.float32(0.1035),
#     '로맨틱': np.float32(0.0805)},
#    '상의_색상_스카이블루',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_7부소매',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(874826),
#    {'스트리트': np.float32(0.6722),
#     '페미닌': np.float32(0.0575),
#     '로맨틱': np.float32(0.0373)},
#    '상의_색상_핑크',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_긴팔',
#    '상의_소재_시폰',
#    '상의_핏_노멀'],
#   [np.int64(233908),
#    {'스트리트': np.float32(0.9492),
#     '페미닌': np.float32(0.0143),
#     '클래식': np.float32(0.0108)},
#    '상의_색상_베이지',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_반팔',
#    '상의_소재_스판덱스',
#    '상의_핏_타이트'],
#   [np.int64(523134),
#    {'스트리트': np.float32(0.6033),
#     '페미닌': np.float32(0.0803),
#     '로맨틱': np.float32(0.0581)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(1163508),
#    {'스트리트': np.float32(0.6892),
#     '페미닌': np.float32(0.0618),
#     '로맨틱': np.float32(0.059)},
#    '상의_색상_블랙',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_루즈'],
#   [np.int64(488899),
#    {'스트리트': np.float32(0.6838),
#     '리조트': np.float32(0.0529),
#     '페미닌': np.float32(0.0478)},
#    '상의_색상_화이트',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(161142),
#    {'스트리트': np.float32(0.5359),
#     '페미닌': np.float32(0.1123),
#     '로맨틱': np.float32(0.0952)},
#    '상의_색상_레드',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(665660),
#    {'스트리트': np.float32(0.6676),
#     '리조트': np.float32(0.0579),
#     '페미닌': np.float32(0.0514)},
#    '상의_색상_베이지',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(982112),
#    {'스트리트': np.float32(0.5044),
#     '페미닌': np.float32(0.0961),
#     '컨트리': np.float32(0.0878)},
#    '상의_색상_블루',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(687882),
#    {'스트리트': np.float32(0.7776),
#     '리조트': np.float32(0.0335),
#     '스포티': np.float32(0.0327)},
#    '상의_색상_옐로우',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(1194858),
#    {'스트리트': np.float32(0.5792),
#     '페미닌': np.float32(0.0684),
#     '클래식': np.float32(0.067)},
#    '상의_색상_핑크',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(315725),
#    {'스트리트': np.float32(0.5728),
#     '페미닌': np.float32(0.0841),
#     '로맨틱': np.float32(0.0673)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(1021849),
#    {'스트리트': np.float32(0.5458),
#     '페미닌': np.float32(0.0935),
#     '로맨틱': np.float32(0.0905)},
#    '상의_색상_옐로우',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(146872),
#    {'스트리트': np.float32(0.7688),
#     '페미닌': np.float32(0.0427),
#     '모던': np.float32(0.0333)},
#    '상의_색상_화이트',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_긴팔',
#    '상의_소재_실크',
#    '상의_핏_노멀'],
#   [np.int64(1126240),
#    {'스트리트': np.float32(0.7227),
#     '클래식': np.float32(0.0525),
#     '리조트': np.float32(0.0435)},
#    '상의_색상_브라운',
#    '상의_카테고리_블라우스',
#    '상의_옷깃_셔츠칼라',
#    '상의_소매기장_7부소매',
#    '상의_소재_우븐'],
#   [np.int64(541557),
#    {'스트리트': np.float32(0.5651),
#     '페미닌': np.float32(0.0745),
#     '로맨틱': np.float32(0.0676)},
#    '상의_색상_베이지',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(260784),
#    {'스트리트': np.float32(0.6607),
#     '페미닌': np.float32(0.0669),
#     '리조트': np.float32(0.0389)},
#    '상의_색상_화이트',
#    '상의_카테고리_블라우스',
#    '상의_옷깃_테일러드칼라',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(850003),
#    {'스트리트': np.float32(0.4889),
#     '페미닌': np.float32(0.1139),
#     '소피스트케이티드': np.float32(0.073)},
#    '상의_색상_스카이블루',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(868645),
#    {'스트리트': np.float32(0.6099),
#     '페미닌': np.float32(0.0785),
#     '로맨틱': np.float32(0.054)},
#    '상의_색상_화이트',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_오버사이즈'],
#   [np.int64(857308),
#    {'스트리트': np.float32(0.4272),
#     '로맨틱': np.float32(0.1151),
#     '페미닌': np.float32(0.0702)},
#    '상의_색상_스카이블루',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_반팔',
#    '상의_소재_실크',
#    '상의_핏_루즈'],
#   [np.int64(856856),
#    {'스트리트': np.float32(0.7547),
#     '클래식': np.float32(0.0682),
#     '로맨틱': np.float32(0.0452)},
#    '상의_색상_카키',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_소재_니트',
#    '상의_핏_루즈'],
#   [np.int64(967052),
#    {'스트리트': np.float32(0.6847),
#     '페미닌': np.float32(0.0547),
#     '로맨틱': np.float32(0.039)},
#    '상의_색상_베이지',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(1017769),
#    {'스트리트': np.float32(0.6938),
#     '페미닌': np.float32(0.0529),
#     '모던': np.float32(0.0418)},
#    '상의_색상_핑크',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_긴팔',
#    '상의_소재_실크',
#    '상의_핏_노멀'],
#   [np.int64(43229),
#    {'스트리트': np.float32(0.6758),
#     '페미닌': np.float32(0.0557),
#     '로맨틱': np.float32(0.0526)},
#    '상의_카테고리_탑',
#    '상의_소재_저지',
#    '상의_핏_타이트'],
#   [np.int64(794733),
#    {'스트리트': np.float32(0.6318),
#     '페미닌': np.float32(0.0704),
#     '리조트': np.float32(0.0636)},
#    '상의_색상_블루',
#    '상의_소매기장_반팔'],
#   [np.int64(1135164),
#    {'스트리트': np.float32(0.5904),
#     '페미닌': np.float32(0.0951),
#     '클래식': np.float32(0.0491)},
#    '상의_색상_블랙',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(618746),
#    {'스트리트': np.float32(0.6631),
#     '페미닌': np.float32(0.0604),
#     '로맨틱': np.float32(0.0558)},
#    '상의_색상_레드',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(1299673),
#    {'스트리트': np.float32(0.6079),
#     '페미닌': np.float32(0.1193),
#     '로맨틱': np.float32(0.0572)},
#    '상의_색상_블랙',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_민소매',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(568789),
#    {'스트리트': np.float32(0.5989),
#     '페미닌': np.float32(0.078),
#     '리조트': np.float32(0.0621)},
#    '상의_카테고리_티셔츠',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(504555),
#    {'스트리트': np.float32(0.6281),
#     '로맨틱': np.float32(0.078),
#     '페미닌': np.float32(0.0653)},
#    '상의_색상_옐로우',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(347382),
#    {'스트리트': np.float32(0.6524),
#     '페미닌': np.float32(0.0552),
#     '리조트': np.float32(0.0549)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_없음',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(1175572),
#    {'스트리트': np.float32(0.5856),
#     '로맨틱': np.float32(0.0596),
#     '페미닌': np.float32(0.0561)},
#    '상의_색상_핑크',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_7부소매',
#    '상의_소재_시폰',
#    '상의_핏_노멀'],
#   [np.int64(1007834),
#    {'스트리트': np.float32(0.5728),
#     '페미닌': np.float32(0.0841),
#     '로맨틱': np.float32(0.0673)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(475136),
#    {'스트리트': np.float32(0.4627),
#     '리조트': np.float32(0.1597),
#     '컨트리': np.float32(0.0945)},
#    '상의_카테고리_셔츠',
#    '상의_옷깃_테일러드칼라',
#    '상의_소재_실크',
#    '상의_핏_노멀'],
#   [np.int64(199772),
#    {'스트리트': np.float32(0.6332),
#     '페미닌': np.float32(0.079),
#     '로맨틱': np.float32(0.0521)},
#    '상의_색상_네이비',
#    '상의_소매기장_긴팔'],
#   [np.int64(1191105),
#    {'스트리트': np.float32(0.6033),
#     '페미닌': np.float32(0.0803),
#     '로맨틱': np.float32(0.0581)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(540084),
#    {'스트리트': np.float32(0.4068),
#     '로맨틱': np.float32(0.0971),
#     '페미닌': np.float32(0.0829)},
#    '상의_색상_민트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(1162565),
#    {'스트리트': np.float32(0.606),
#     '리조트': np.float32(0.1038),
#     '로맨틱': np.float32(0.0549)},
#    '상의_색상_와인',
#    '상의_카테고리_셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(10055),
#    {'스트리트': np.float32(0.7175),
#     '컨트리': np.float32(0.0381),
#     '페미닌': np.float32(0.0369)},
#    '상의_색상_블랙',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_핏_타이트'],
#   [np.int64(1123861),
#    {'스트리트': np.float32(0.7512),
#     '컨트리': np.float32(0.0453),
#     '로맨틱': np.float32(0.0411)},
#    '상의_색상_베이지',
#    '상의_카테고리_블라우스',
#    '상의_옷깃_밴드칼라',
#    '상의_소매기장_긴팔',
#    '상의_소재_시폰',
#    '상의_핏_노멀'],
#   [np.int64(854800),
#    {'스트리트': np.float32(0.4272),
#     '로맨틱': np.float32(0.1151),
#     '페미닌': np.float32(0.0702)},
#    '상의_색상_스카이블루',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_반팔',
#    '상의_소재_실크',
#    '상의_핏_루즈'],
#   [np.int64(794322),
#    {'스트리트': np.float32(0.5287),
#     '페미닌': np.float32(0.1862),
#     '모던': np.float32(0.0628)},
#    '상의_색상_핑크',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_캡',
#    '상의_소재_우븐',
#    '상의_핏_타이트'],
#   [np.int64(504032),
#    {'스트리트': np.float32(0.5677),
#     '로맨틱': np.float32(0.0827),
#     '페미닌': np.float32(0.0794)},
#    '상의_색상_브라운',
#    '상의_카테고리_블라우스',
#    '상의_옷깃_보우칼라',
#    '상의_소매기장_긴팔',
#    '상의_소재_시폰',
#    '상의_핏_루즈'],
#   [np.int64(1037532),
#    {'스트리트': np.float32(0.5487),
#     '로맨틱': np.float32(0.1069),
#     '페미닌': np.float32(0.0933)},
#    '상의_색상_화이트',
#    '상의_카테고리_탑',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(1057540),
#    {'스트리트': np.float32(0.592),
#     '페미닌': np.float32(0.0714),
#     '리조트': np.float32(0.0568)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_없음',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(978845),
#    {'스트리트': np.float32(0.5886),
#     '페미닌': np.float32(0.1075),
#     '리조트': np.float32(0.0557)},
#    '상의_색상_블루',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(112019),
#    {'스트리트': np.float32(0.6618),
#     '모던': np.float32(0.0656),
#     '리조트': np.float32(0.0636)},
#    '상의_색상_스카이블루',
#    '상의_카테고리_탑',
#    '상의_소매기장_민소매',
#    '상의_소재_니트',
#    '상의_핏_타이트'],
#   [np.int64(157563),
#    {'스트리트': np.float32(0.614),
#     '페미닌': np.float32(0.079),
#     '로맨틱': np.float32(0.0549)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(723624),
#    {'스트리트': np.float32(0.908),
#     '소피스트케이티드': np.float32(0.0165),
#     '리조트': np.float32(0.0154)},
#    '상의_색상_브라운',
#    '상의_카테고리_블라우스',
#    '상의_옷깃_밴드칼라',
#    '상의_소매기장_긴팔',
#    '상의_소재_스웨이드',
#    '상의_핏_루즈'],
#   [np.int64(498345),
#    {'스트리트': np.float32(0.601),
#     '페미닌': np.float32(0.1096),
#     '로맨틱': np.float32(0.0857)},
#    '상의_색상_옐로우',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(1091726),
#    {'스트리트': np.float32(0.5728),
#     '페미닌': np.float32(0.0841),
#     '로맨틱': np.float32(0.0673)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(524972),
#    {'스트리트': np.float32(0.7961),
#     '페미닌': np.float32(0.0493),
#     '모던': np.float32(0.041)},
#    '상의_색상_옐로우',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_메시',
#    '상의_핏_루즈'],
#   [np.int64(299032),
#    {'스트리트': np.float32(0.598),
#     '페미닌': np.float32(0.0987),
#     '리조트': np.float32(0.0518)},
#    '상의_색상_화이트',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(618516),
#    {'스트리트': np.float32(0.7426),
#     '리조트': np.float32(0.049),
#     '페미닌': np.float32(0.0375)},
#    '상의_색상_민트',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(817331),
#    {'스트리트': np.float32(0.5761),
#     '페미닌': np.float32(0.0807),
#     '로맨틱': np.float32(0.0601)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(1141231),
#    {'스트리트': np.float32(0.6631),
#     '모던': np.float32(0.065),
#     '페미닌': np.float32(0.0602)},
#    '상의_색상_화이트',
#    '상의_카테고리_탑',
#    '상의_소매기장_없음',
#    '상의_소재_니트',
#    '상의_핏_타이트'],
#   [np.int64(314398),
#    {'스트리트': np.float32(0.6372),
#     '페미닌': np.float32(0.0623),
#     '로맨틱': np.float32(0.059)},
#    '상의_색상_화이트',
#    '상의_소매기장_긴팔'],
#   [np.int64(998651),
#    {'스트리트': np.float32(0.6659),
#     '페미닌': np.float32(0.0644),
#     '로맨틱': np.float32(0.0509)},
#    '상의_색상_베이지',
#    '상의_소매기장_긴팔'],
#   [np.int64(159310),
#    {'스트리트': np.float32(0.6554),
#     '페미닌': np.float32(0.0717),
#     '로맨틱': np.float32(0.0595)},
#    '상의_색상_화이트',
#    '상의_소매기장_7부소매'],
#   [np.int64(750461),
#    {'스트리트': np.float32(0.6507),
#     '페미닌': np.float32(0.0663),
#     '로맨틱': np.float32(0.0492)},
#    '상의_색상_화이트',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_긴팔',
#    '상의_소재_시폰',
#    '상의_핏_노멀'],
#   [np.int64(1325561),
#    {'스트리트': np.float32(0.7972),
#     '리조트': np.float32(0.0545),
#     '페미닌': np.float32(0.0311)},
#    '상의_색상_네이비',
#    '상의_카테고리_탑',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_타이트'],
#   [np.int64(1176292),
#    {'스트리트': np.float32(0.5621),
#     '로맨틱': np.float32(0.0809),
#     '페미닌': np.float32(0.0754)},
#    '상의_색상_레드',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(742162),
#    {'스트리트': np.float32(0.5761),
#     '페미닌': np.float32(0.0807),
#     '로맨틱': np.float32(0.0601)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(1234695),
#    {'스트리트': np.float32(0.5889),
#     '페미닌': np.float32(0.0766),
#     '로맨틱': np.float32(0.0597)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(1293677),
#    {'스트리트': np.float32(0.6829),
#     '로맨틱': np.float32(0.0841),
#     '페미닌': np.float32(0.0485)},
#    '상의_색상_베이지',
#    '상의_카테고리_탑',
#    '상의_소매기장_민소매',
#    '상의_소재_린넨',
#    '상의_핏_루즈'],
#   [np.int64(1106578),
#    {'스트리트': np.float32(0.5866),
#     '페미닌': np.float32(0.1244),
#     '로맨틱': np.float32(0.0659)},
#    '상의_색상_그린',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(41267),
#    {'스트리트': np.float32(0.645),
#     '페미닌': np.float32(0.0625),
#     '모던': np.float32(0.056)},
#    '상의_색상_화이트',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_민소매',
#    '상의_소재_니트',
#    '상의_핏_타이트'],
#   [np.int64(1145672),
#    {'스트리트': np.float32(0.6485),
#     '페미닌': np.float32(0.0802),
#     '로맨틱': np.float32(0.0672)},
#    '상의_색상_오렌지',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(411308),
#    {'스트리트': np.float32(0.6804),
#     '리조트': np.float32(0.0581),
#     '클래식': np.float32(0.0458)},
#    '상의_색상_오렌지',
#    '상의_카테고리_셔츠',
#    '상의_옷깃_셔츠칼라',
#    '상의_소매기장_7부소매',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(828493),
#    {'스트리트': np.float32(0.522),
#     '페미닌': np.float32(0.1168),
#     '로맨틱': np.float32(0.1024)},
#    '상의_색상_레드',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_핏_노멀'],
#   [np.int64(256399),
#    {'스트리트': np.float32(0.6613),
#     '로맨틱': np.float32(0.0907),
#     '페미닌': np.float32(0.0565)},
#    '상의_색상_그레이',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(1251295),
#    {'스트리트': np.float32(0.3371),
#     '클래식': np.float32(0.1509),
#     '리조트': np.float32(0.133)},
#    '상의_색상_그레이',
#    '상의_카테고리_셔츠',
#    '상의_옷깃_밴드칼라',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(583599),
#    {'스트리트': np.float32(0.6507),
#     '클래식': np.float32(0.0703),
#     '페미닌': np.float32(0.061)},
#    '상의_색상_블랙',
#    '상의_카테고리_탑',
#    '상의_소매기장_긴팔',
#    '상의_소재_울/캐시미어',
#    '상의_핏_루즈'],
#   [np.int64(970738),
#    {'스트리트': np.float32(0.6311),
#     '페미닌': np.float32(0.0835),
#     '로맨틱': np.float32(0.0717)},
#    '상의_색상_그린',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(814318),
#    {'스트리트': np.float32(0.5837),
#     '페미닌': np.float32(0.0891),
#     '컨트리': np.float32(0.0566)},
#    '상의_색상_라벤더',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_7부소매',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(788047),
#    {'스트리트': np.float32(0.6777),
#     '페미닌': np.float32(0.0842),
#     '로맨틱': np.float32(0.046)},
#    '상의_카테고리_티셔츠',
#    '상의_핏_노멀'],
#   [np.int64(618957),
#    {'스트리트': np.float32(0.6251),
#     '페미닌': np.float32(0.0908),
#     '로맨틱': np.float32(0.0783)},
#    '상의_색상_블랙',
#    '상의_카테고리_블라우스',
#    '상의_옷깃_차이나칼라',
#    '상의_소매기장_긴팔',
#    '상의_소재_시폰',
#    '상의_핏_루즈'],
#   [np.int64(521929),
#    {'스트리트': np.float32(0.5447),
#     '스포티': np.float32(0.0759),
#     '젠더리스': np.float32(0.0619)},
#    '상의_색상_라벤더',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_타이트'],
#   [np.int64(966670),
#    {'스트리트': np.float32(0.6959),
#     '로맨틱': np.float32(0.0622),
#     '페미닌': np.float32(0.0557)},
#    '상의_색상_베이지',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_루즈'],
#   [np.int64(172625),
#    {'스트리트': np.float32(0.6698),
#     '로맨틱': np.float32(0.0612),
#     '클래식': np.float32(0.0432)},
#    '상의_색상_네이비',
#    '상의_카테고리_블라우스',
#    '상의_옷깃_셔츠칼라',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(1061385),
#    {'스트리트': np.float32(0.4931),
#     '컨트리': np.float32(0.1075),
#     '리조트': np.float32(0.1029)},
#    '상의_색상_화이트',
#    '상의_카테고리_탑',
#    '상의_소매기장_없음',
#    '상의_소재_플리스'],
#   [np.int64(596673),
#    {'스트리트': np.float32(0.6182),
#     '로맨틱': np.float32(0.0792),
#     '페미닌': np.float32(0.0704)},
#    '상의_색상_블랙',
#    '상의_카테고리_탑',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(1005633),
#    {'스트리트': np.float32(0.5457),
#     '페미닌': np.float32(0.1817),
#     '로맨틱': np.float32(0.0871)},
#    '상의_색상_옐로우',
#    '상의_카테고리_후드티',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(819482),
#    {'스트리트': np.float32(0.6838),
#     '리조트': np.float32(0.0529),
#     '페미닌': np.float32(0.0478)},
#    '상의_색상_화이트',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(964957),
#    {'스트리트': np.float32(0.592),
#     '페미닌': np.float32(0.0714),
#     '리조트': np.float32(0.0568)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_없음',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(769528),
#    {'스트리트': np.float32(0.6642),
#     '페미닌': np.float32(0.0678),
#     '리조트': np.float32(0.0539)},
#    '상의_카테고리_티셔츠',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(1209326),
#    {'스트리트': np.float32(0.541),
#     '페미닌': np.float32(0.1266),
#     '로맨틱': np.float32(0.0763)},
#    '상의_색상_옐로우',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(684647),
#    {'스트리트': np.float32(0.5636),
#     '페미닌': np.float32(0.086),
#     '로맨틱': np.float32(0.0752)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_오버사이즈'],
#   [np.int64(664064),
#    {'스트리트': np.float32(0.5941),
#     '페미닌': np.float32(0.0889),
#     '모던': np.float32(0.062)},
#    '상의_색상_블랙',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(1183449),
#    {'스트리트': np.float32(0.5359),
#     '페미닌': np.float32(0.1123),
#     '로맨틱': np.float32(0.0952)},
#    '상의_색상_레드',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(149126),
#    {'스트리트': np.float32(0.6857),
#     '페미닌': np.float32(0.0508),
#     '로맨틱': np.float32(0.0507)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_없음',
#    '상의_소재_저지'],
#   [np.int64(1079965),
#    {'스트리트': np.float32(0.5424),
#     '페미닌': np.float32(0.0924),
#     '리조트': np.float32(0.0696)},
#    '상의_색상_와인',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_7부소매',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(802079),
#    {'스트리트': np.float32(0.7757),
#     '페미닌': np.float32(0.0398),
#     '로맨틱': np.float32(0.0359)},
#    '상의_색상_블랙',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(1260881),
#    {'스트리트': np.float32(0.558),
#     '로맨틱': np.float32(0.1148),
#     '페미닌': np.float32(0.0772)},
#    '상의_색상_화이트',
#    '상의_카테고리_탑',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(752133),
#    {'스트리트': np.float32(0.7816),
#     '페미닌': np.float32(0.035),
#     '모던': np.float32(0.0317)},
#    '상의_색상_핑크',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_울/캐시미어',
#    '상의_핏_노멀'],
#   [np.int64(1297962),
#    {'스트리트': np.float32(0.6744),
#     '페미닌': np.float32(0.0668),
#     '리조트': np.float32(0.0484)},
#    '상의_색상_화이트',
#    '상의_소매기장_없음'],
#   [np.int64(1267699),
#    {'스트리트': np.float32(0.6033),
#     '페미닌': np.float32(0.0803),
#     '로맨틱': np.float32(0.0581)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(1132912),
#    {'스트리트': np.float32(0.6854),
#     '페미닌': np.float32(0.0572),
#     '리조트': np.float32(0.0463)},
#    '상의_색상_오렌지',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(300567),
#    {'스트리트': np.float32(0.7108),
#     '페미닌': np.float32(0.0561),
#     '로맨틱': np.float32(0.0519)},
#    '상의_색상_블랙',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_민소매',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(1305430),
#    {'스트리트': np.float32(0.6273),
#     '페미닌': np.float32(0.0809),
#     '로맨틱': np.float32(0.0542)},
#    '상의_색상_블랙',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(273501),
#    {'스트리트': np.float32(0.6668),
#     '리조트': np.float32(0.0702),
#     '페미닌': np.float32(0.0565)},
#    '상의_색상_블랙',
#    '상의_카테고리_셔츠',
#    '상의_옷깃_셔츠칼라',
#    '상의_소매기장_7부소매',
#    '상의_소재_우븐',
#    '상의_핏_노멀']],
#  '원피스': [[np.int64(1202131),
#    {'스트리트': np.float32(0.6083),
#     '페미닌': np.float32(0.0668),
#     '로맨틱': np.float32(0.0615)},
#    '원피스_기장_미니',
#    '원피스_색상_블랙',
#    '원피스_카테고리_드레스',
#    '원피스_소매기장_민소매',
#    '원피스_소재_우븐',
#    '원피스_핏_노멀'],
#   [np.int64(1223964),
#    {'스트리트': np.float32(0.6839),
#     '페미닌': np.float32(0.0556),
#     '클래식': np.float32(0.052)},
#    '원피스_기장_미디',
#    '원피스_색상_그레이',
#    '원피스_카테고리_드레스',
#    '원피스_소매기장_긴팔',
#    '원피스_소재_우븐',
#    '원피스_핏_루즈'],
#   [np.int64(998731),
#    {'리조트': np.float32(0.309),
#     '로맨틱': np.float32(0.2558),
#     '스트리트': np.float32(0.1434)},
#    '원피스_기장_미니',
#    '원피스_색상_브라운',
#    '원피스_카테고리_드레스',
#    '원피스_소매기장_민소매',
#    '원피스_소재_스웨이드',
#    '원피스_핏_노멀'],
#   [np.int64(268454),
#    {'스트리트': np.float32(0.6015),
#     '클래식': np.float32(0.1341),
#     '리조트': np.float32(0.0807)},
#    '원피스_기장_발목',
#    '원피스_색상_스카이블루',
#    '원피스_카테고리_점프수트',
#    '원피스_소매기장_민소매',
#    '원피스_소재_데님',
#    '원피스_핏_루즈'],
#   [np.int64(705888),
#    {'스트리트': np.float32(0.613),
#     '컨트리': np.float32(0.0888),
#     '모던': np.float32(0.067)},
#    '원피스_기장_미니',
#    '원피스_카테고리_드레스',
#    '원피스_옷깃_테일러드칼라',
#    '원피스_소재_우븐',
#    '원피스_핏_타이트'],
#   [np.int64(568789),
#    {'스트리트': np.float32(0.5548),
#     '페미닌': np.float32(0.0928),
#     '로맨틱': np.float32(0.0656)},
#    '원피스_색상_네이비',
#    '원피스_소매기장_긴팔'],
#   [np.int64(475136),
#    {'스트리트': np.float32(0.8144),
#     '페미닌': np.float32(0.0567),
#     '소피스트케이티드': np.float32(0.0457)},
#    '원피스_기장_발목',
#    '원피스_색상_베이지',
#    '원피스_카테고리_드레스',
#    '원피스_소매기장_민소매',
#    '원피스_소재_실크',
#    '원피스_핏_노멀'],
#   [np.int64(904555),
#    {'스트리트': np.float32(0.6835),
#     '클래식': np.float32(0.0493),
#     '컨트리': np.float32(0.045)},
#    '원피스_기장_미니',
#    '원피스_색상_네이비',
#    '원피스_카테고리_드레스',
#    '원피스_소매기장_민소매',
#    '원피스_소재_우븐',
#    '원피스_핏_타이트'],
#   [np.int64(1191105),
#    {'스트리트': np.float32(0.6438),
#     '로맨틱': np.float32(0.0828),
#     '페미닌': np.float32(0.0627)},
#    '원피스_기장_미디',
#    '원피스_색상_핑크',
#    '원피스_카테고리_드레스',
#    '원피스_소매기장_민소매',
#    '원피스_소재_우븐',
#    '원피스_핏_루즈'],
#   [np.int64(322042),
#    {'스트리트': np.float32(0.7283),
#     '로맨틱': np.float32(0.0488),
#     '페미닌': np.float32(0.0471)},
#    '원피스_기장_미디',
#    '원피스_카테고리_드레스',
#    '원피스_소재_우븐',
#    '원피스_핏_루즈'],
#   [np.int64(1221344),
#    {'스트리트': np.float32(0.6318),
#     '페미닌': np.float32(0.058),
#     '로맨틱': np.float32(0.0539)},
#    '원피스_기장_니렝스',
#    '원피스_색상_핑크',
#    '원피스_카테고리_드레스',
#    '원피스_소매기장_반팔',
#    '원피스_소재_우븐',
#    '원피스_핏_노멀']],
#  '하의': [[np.int64(1216062),
#    {'스트리트': np.float32(0.6615),
#     '모던': np.float32(0.0856),
#     '리조트': np.float32(0.0504)},
#    '하의_기장_니렝스',
#    '하의_색상_옐로우',
#    '하의_카테고리_스커트',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(871706),
#    {'스트리트': np.float32(0.6706),
#     '페미닌': np.float32(0.0513),
#     '리조트': np.float32(0.0486)},
#    '하의_기장_발목',
#    '하의_색상_베이지',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(741110),
#    {'스트리트': np.float32(0.6662),
#     '페미닌': np.float32(0.0522),
#     '클래식': np.float32(0.0503)},
#    '하의_기장_미니',
#    '하의_색상_베이지',
#    '하의_카테고리_스커트',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(505625),
#    {'스트리트': np.float32(0.694),
#     '페미닌': np.float32(0.0459),
#     '소피스트케이티드': np.float32(0.0355)},
#    '하의_기장_미디',
#    '하의_색상_민트',
#    '하의_카테고리_스커트',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(406557),
#    {'스트리트': np.float32(0.63),
#     '페미닌': np.float32(0.0715),
#     '로맨틱': np.float32(0.06)},
#    '하의_기장_발목',
#    '하의_색상_블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_스키니'],
#   [np.int64(874986),
#    {'스트리트': np.float32(0.5943),
# ...
#    '하의_기장_발목',
#    '하의_색상_블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_루즈'],
#   [np.int64(260784),
#    {'스트리트': np.float32(0.6438),
#     '페미닌': np.float32(0.0683),
#     '로맨틱': np.float32(0.0561)},
#    '하의_색상_베이지',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐'],
#   [np.int64(850003),
#    {'스트리트': np.float32(0.6307),
#     '페미닌': np.float32(0.0611),
#     '로맨틱': np.float32(0.054)},
#    '하의_기장_발목',
#    '하의_색상_화이트',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(868645),
#    {'스트리트': np.float32(0.6375),
#     '페미닌': np.float32(0.0718),
#     '로맨틱': np.float32(0.0499)},
#    '하의_기장_발목',
#    '하의_색상_스카이블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_스키니'],
#   [np.int64(857308),
#    {'스트리트': np.float32(0.6088),
#     '페미닌': np.float32(0.0725),
#     '리조트': np.float32(0.0552)},
#    '하의_기장_발목',
#    '하의_색상_블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(856856),
#    {'스트리트': np.float32(0.7061),
#     '페미닌': np.float32(0.0535),
#     '클래식': np.float32(0.0506)},
#    '하의_기장_발목',
#    '하의_색상_베이지',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_루즈'],
#   [np.int64(967052),
#    {'스트리트': np.float32(0.6147),
#     '페미닌': np.float32(0.0668),
#     '로맨틱': np.float32(0.0554)},
#    '하의_기장_발목',
#    '하의_색상_네이비',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(1017769),
#    {'스트리트': np.float32(0.6192),
#     '페미닌': np.float32(0.0643),
#     '리조트': np.float32(0.0588)},
#    '하의_기장_맥시',
#    '하의_색상_블랙',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_와이드'],
#   [np.int64(43229),
#    {'스트리트': np.float32(0.6262),
#     '페미닌': np.float32(0.0669),
#     '소피스트케이티드': np.float32(0.0524)},
#    '하의_기장_미니',
#    '하의_카테고리_팬츠',
#    '하의_소재_린넨',
#    '하의_핏_와이드'],
#   [np.int64(794733),
#    {'스트리트': np.float32(0.44),
#     '페미닌': np.float32(0.1002),
#     '로맨틱': np.float32(0.0982)},
#    '하의_기장_미디',
#    '하의_색상_화이트',
#    '하의_카테고리_스커트',
#    '하의_소재_우븐',
#    '하의_핏_와이드'],
#   [np.int64(1135164),
#    {'스트리트': np.float32(0.6878),
#     '리조트': np.float32(0.0471),
#     '페미닌': np.float32(0.047)},
#    '하의_기장_발목',
#    '하의_색상_카키',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(618746),
#    {'스트리트': np.float32(0.3419),
#     '리조트': np.float32(0.176),
#     '페미닌': np.float32(0.109)},
#    '하의_카테고리_청바지'],
#   [np.int64(1299673),
#    {'스트리트': np.float32(0.5613),
#     '페미닌': np.float32(0.0896),
#     '로맨틱': np.float32(0.0622)},
#    '하의_기장_미니',
#    '하의_색상_스카이블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(568789),
#    {'스트리트': np.float32(0.6114),
#     '로맨틱': np.float32(0.0615),
#     '페미닌': np.float32(0.0604)},
#    '하의_기장_발목',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_스키니'],
#   [np.int64(504555),
#    {'스트리트': np.float32(0.6767),
#     '페미닌': np.float32(0.0562),
#     '로맨틱': np.float32(0.0453)},
#    '하의_기장_미니',
#    '하의_색상_블랙',
#    '하의_카테고리_스커트',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(1175572),
#    {'스트리트': np.float32(0.4077),
#     '페미닌': np.float32(0.1491),
#     '소피스트케이티드': np.float32(0.1192)},
#    '하의_기장_발목',
#    '하의_색상_스카이블루',
#    '하의_카테고리_청바지',
#    '하의_소재_린넨',
#    '하의_핏_노멀'],
#   [np.int64(1007834),
#    {'스트리트': np.float32(0.6194),
#     '페미닌': np.float32(0.0696),
#     '로맨틱': np.float32(0.0571)},
#    '하의_기장_발목',
#    '하의_색상_블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_와이드'],
#   [np.int64(540084),
#    {'스트리트': np.float32(0.6136),
#     '페미닌': np.float32(0.0674),
#     '로맨틱': np.float32(0.0536)},
#    '하의_기장_발목',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(1162565),
#    {'스트리트': np.float32(0.4547),
#     '클래식': np.float32(0.107),
#     '페미닌': np.float32(0.0873)},
#    '하의_기장_미니',
#    '하의_색상_브라운',
#    '하의_카테고리_스커트',
#    '하의_소재_코듀로이',
#    '하의_핏_노멀'],
#   [np.int64(10055),
#    {'스트리트': np.float32(0.5954),
#     '페미닌': np.float32(0.0783),
#     '로맨틱': np.float32(0.0627)},
#    '하의_기장_발목',
#    '하의_색상_네이비',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_스키니'],
#   [np.int64(1123861),
#    {'스트리트': np.float32(0.63),
#     '페미닌': np.float32(0.0715),
#     '로맨틱': np.float32(0.06)},
#    '하의_기장_발목',
#    '하의_색상_블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_스키니'],
#   [np.int64(854800),
#    {'스트리트': np.float32(0.5984),
#     '페미닌': np.float32(0.0799),
#     '로맨틱': np.float32(0.0695)},
#    '하의_색상_화이트'],
#   [np.int64(794322),
#    {'스트리트': np.float32(0.425),
#     '페미닌': np.float32(0.1744),
#     '로맨틱': np.float32(0.1068)},
#    '하의_기장_미디',
#    '하의_색상_블루',
#    '하의_카테고리_스커트',
#    '하의_소재_우븐',
#    '하의_핏_와이드'],
#   [np.int64(504032),
#    {'스트리트': np.float32(0.44),
#     '페미닌': np.float32(0.1002),
#     '로맨틱': np.float32(0.0982)},
#    '하의_기장_미디',
#    '하의_색상_화이트',
#    '하의_카테고리_스커트',
#    '하의_소재_우븐',
#    '하의_핏_와이드'],
#   [np.int64(1037532),
#    {'스트리트': np.float32(0.6147),
#     '페미닌': np.float32(0.0668),
#     '로맨틱': np.float32(0.0554)},
#    '하의_기장_발목',
#    '하의_색상_네이비',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(1057540),
#    {'스트리트': np.float32(0.6147),
#     '페미닌': np.float32(0.0668),
#     '로맨틱': np.float32(0.0554)},
#    '하의_기장_발목',
#    '하의_색상_네이비',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(978845),
#    {'스트리트': np.float32(0.6398),
#     '리조트': np.float32(0.0645),
#     '페미닌': np.float32(0.0555)},
#    '하의_기장_발목',
#    '하의_색상_블랙',
#    '하의_카테고리_팬츠',
#    '하의_소재_니트',
#    '하의_핏_노멀'],
#   [np.int64(112019),
#    {'스트리트': np.float32(0.6206),
#     '모던': np.float32(0.0775),
#     '페미닌': np.float32(0.0672)},
#    '하의_기장_니렝스',
#    '하의_색상_스카이블루',
#    '하의_카테고리_스커트',
#    '하의_소재_니트',
#    '하의_핏_스키니'],
#   [np.int64(157563),
#    {'스트리트': np.float32(0.6401),
#     '페미닌': np.float32(0.0558),
#     '로맨틱': np.float32(0.0554)},
#    '하의_기장_미디',
#    '하의_색상_블랙',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(723624),
#    {'스트리트': np.float32(0.5736),
#     '소피스트케이티드': np.float32(0.0723),
#     '모던': np.float32(0.0649)},
#    '하의_기장_미니',
#    '하의_색상_그레이',
#    '하의_카테고리_스커트',
#    '하의_소재_트위드',
#    '하의_핏_노멀'],
#   [np.int64(498345),
#    {'스트리트': np.float32(0.6113),
#     '페미닌': np.float32(0.0653),
#     '로맨틱': np.float32(0.0582)},
#    '하의_기장_발목',
#    '하의_색상_스카이블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(1091726),
#    {'스트리트': np.float32(0.6469),
#     '페미닌': np.float32(0.0585),
#     '로맨틱': np.float32(0.0526)},
#    '하의_기장_발목',
#    '하의_색상_블랙',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_와이드'],
#   [np.int64(524972),
#    {'스트리트': np.float32(0.5613),
#     '페미닌': np.float32(0.0896),
#     '로맨틱': np.float32(0.0622)},
#    '하의_기장_미니',
#    '하의_색상_스카이블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(299032),
#    {'스트리트': np.float32(0.576),
#     '로맨틱': np.float32(0.0626),
#     '리조트': np.float32(0.059)},
#    '하의_기장_미디',
#    '하의_색상_핑크',
#    '하의_카테고리_스커트',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(618516),
#    {'스트리트': np.float32(0.7007),
#     '페미닌': np.float32(0.0529),
#     '로맨틱': np.float32(0.0425)},
#    '하의_기장_발목',
#    '하의_색상_블랙',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(817331),
#    {'로맨틱': np.float32(0.3803),
#     '스트리트': np.float32(0.2786),
#     '페미닌': np.float32(0.1032)},
#    '하의_기장_니렝스',
#    '하의_색상_블루',
#    '하의_카테고리_스커트',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(1141231),
#    {'스트리트': np.float32(0.619),
#     '페미닌': np.float32(0.1151),
#     '로맨틱': np.float32(0.0364)},
#    '하의_기장_미니',
#    '하의_색상_베이지',
#    '하의_카테고리_스커트',
#    '하의_소재_니트',
#    '하의_핏_노멀'],
#   [np.int64(314398),
#    {'스트리트': np.float32(0.6134),
#     '페미닌': np.float32(0.075),
#     '로맨틱': np.float32(0.0579)},
#    '하의_색상_블랙'],
#   [np.int64(998651),
#    {'스트리트': np.float32(0.5908),
#     '페미닌': np.float32(0.0877),
#     '모던': np.float32(0.0866)},
#    '하의_기장_미니',
#    '하의_색상_블랙',
#    '하의_카테고리_스커트',
#    '하의_소재_가죽',
#    '하의_핏_노멀'],
#   [np.int64(159310),
#    {'스트리트': np.float32(0.6033),
#     '로맨틱': np.float32(0.0912),
#     '리조트': np.float32(0.0879)},
#    '하의_기장_미디',
#    '하의_색상_그레이',
#    '하의_카테고리_팬츠',
#    '하의_소재_린넨',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(750461),
#    {'스트리트': np.float32(0.6304),
#     '페미닌': np.float32(0.0692),
#     '리조트': np.float32(0.0524)},
#    '하의_기장_발목',
#    '하의_색상_스카이블루',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_와이드'],
#   [np.int64(1325561),
#    {'스트리트': np.float32(0.5806),
#     '페미닌': np.float32(0.0839),
#     '로맨틱': np.float32(0.0769)},
#    '하의_색상_베이지'],
#   [np.int64(1176292),
#    {'스트리트': np.float32(0.693),
#     '페미닌': np.float32(0.0491),
#     '로맨틱': np.float32(0.0489)},
#    '하의_기장_미니',
#    '하의_색상_스카이블루',
#    '하의_카테고리_스커트',
#    '하의_소재_데님',
#    '하의_핏_스키니'],
#   [np.int64(742162),
#    {'스트리트': np.float32(0.651),
#     '페미닌': np.float32(0.0707),
#     '클래식': np.float32(0.0703)},
#    '하의_기장_발목',
#    '하의_색상_카키',
#    '하의_카테고리_팬츠',
#    '하의_소재_울/캐시미어',
#    '하의_핏_노멀'],
#   [np.int64(1234695),
#    {'스트리트': np.float32(0.6077),
#     '로맨틱': np.float32(0.0963),
#     '페미닌': np.float32(0.0758)},
#    '하의_기장_미니',
#    '하의_색상_블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_루즈'],
#   [np.int64(1293677),
#    {'스트리트': np.float32(0.5311),
#     '클래식': np.float32(0.0823),
#     '페미닌': np.float32(0.0771)},
#    '하의_기장_미니',
#    '하의_색상_브라운',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_와이드'],
#   [np.int64(1106578),
#    {'스트리트': np.float32(0.6544),
#     '페미닌': np.float32(0.059),
#     '리조트': np.float32(0.0513)},
#    '하의_기장_발목',
#    '하의_색상_블랙',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(41267),
#    {'스트리트': np.float32(0.5613),
#     '페미닌': np.float32(0.0896),
#     '로맨틱': np.float32(0.0622)},
#    '하의_기장_미니',
#    '하의_색상_스카이블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(1145672),
#    {'스트리트': np.float32(0.6077),
#     '로맨틱': np.float32(0.0963),
#     '페미닌': np.float32(0.0758)},
#    '하의_기장_미니',
#    '하의_색상_블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_루즈'],
#   [np.int64(411308),
#    {'스트리트': np.float32(0.6147),
#     '페미닌': np.float32(0.0668),
#     '로맨틱': np.float32(0.0554)},
#    '하의_기장_발목',
#    '하의_색상_네이비',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(828493),
#    {'스트리트': np.float32(0.6544),
#     '페미닌': np.float32(0.0588),
#     '로맨틱': np.float32(0.0587)},
#    '하의_기장_미니',
#    '하의_색상_베이지',
#    '하의_카테고리_스커트'],
#   [np.int64(256399),
#    {'스트리트': np.float32(0.6561),
#     '로맨틱': np.float32(0.0555),
#     '모던': np.float32(0.0442)},
#    '하의_기장_발목',
#    '하의_카테고리_팬츠',
#    '하의_소재_스판덱스',
#    '하의_핏_스키니'],
#   [np.int64(1251295),
#    {'스트리트': np.float32(0.5806),
#     '페미닌': np.float32(0.0839),
#     '로맨틱': np.float32(0.0769)},
#    '하의_색상_베이지'],
#   [np.int64(583599),
#    {'스트리트': np.float32(0.6615),
#     '페미닌': np.float32(0.0549),
#     '클래식': np.float32(0.0512)},
#    '하의_기장_발목',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_루즈'],
#   [np.int64(870816),
#    {'스트리트': np.float32(0.5473),
#     '로맨틱': np.float32(0.0927),
#     '페미닌': np.float32(0.0731)},
#    '하의_기장_미디',
#    '하의_색상_베이지',
#    '하의_카테고리_스커트',
#    '하의_소재_시폰',
#    '하의_핏_루즈'],
#   [np.int64(970738),
#    {'스트리트': np.float32(0.5972),
#     '페미닌': np.float32(0.0807),
#     '로맨틱': np.float32(0.064)},
#    '하의_기장_미니',
#    '하의_색상_화이트',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(814318),
#    {'스트리트': np.float32(0.63),
#     '페미닌': np.float32(0.0715),
#     '로맨틱': np.float32(0.06)},
#    '하의_기장_발목',
#    '하의_색상_블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_스키니'],
#   [np.int64(788047),
#    {'스트리트': np.float32(0.5613),
#     '페미닌': np.float32(0.0896),
#     '로맨틱': np.float32(0.0622)},
#    '하의_기장_미니',
#    '하의_색상_스카이블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(618957),
#    {'스트리트': np.float32(0.6228),
#     '페미닌': np.float32(0.0676),
#     '로맨틱': np.float32(0.0539)},
#    '하의_기장_미니',
#    '하의_카테고리_스커트',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(521929),
#    {'스트리트': np.float32(0.8321),
#     '클래식': np.float32(0.0446),
#     '리조트': np.float32(0.039)},
#    '하의_기장_맥시',
#    '하의_색상_라벤더',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_와이드'],
#   [np.int64(966670),
#    {'스트리트': np.float32(0.6088),
#     '페미닌': np.float32(0.0725),
#     '리조트': np.float32(0.0552)},
#    '하의_기장_발목',
#    '하의_색상_블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(1000075),
#    {'스트리트': np.float32(0.7007),
#     '페미닌': np.float32(0.0529),
#     '로맨틱': np.float32(0.0425)},
#    '하의_기장_발목',
#    '하의_색상_블랙',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(172625),
#    {'스트리트': np.float32(0.583),
#     '페미닌': np.float32(0.0963),
#     '로맨틱': np.float32(0.0905)},
#    '하의_색상_화이트',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐'],
#   [np.int64(1061385),
#    {'스트리트': np.float32(0.6205),
#     '페미닌': np.float32(0.0619),
#     '로맨틱': np.float32(0.056)},
#    '하의_기장_발목',
#    '하의_색상_블랙',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_스키니'],
#   [np.int64(596673),
#    {'스트리트': np.float32(0.6615),
#     '페미닌': np.float32(0.0549),
#     '클래식': np.float32(0.0512)},
#    '하의_기장_발목',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_루즈'],
#   [np.int64(1005633),
#    {'스트리트': np.float32(0.6654),
#     '페미닌': np.float32(0.0595),
#     '로맨틱': np.float32(0.0539)},
#    '하의_기장_발목',
#    '하의_색상_블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_루즈'],
#   [np.int64(819482),
#    {'스트리트': np.float32(0.8394),
#     '리조트': np.float32(0.0239),
#     '페미닌': np.float32(0.0191)},
#    '하의_기장_미디',
#    '하의_색상_카키',
#    '하의_카테고리_스커트',
#    '하의_소재_니트',
#    '하의_핏_노멀'],
#   [np.int64(964957),
#    {'스트리트': np.float32(0.6088),
#     '페미닌': np.float32(0.0725),
#     '리조트': np.float32(0.0552)},
#    '하의_기장_발목',
#    '하의_색상_블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(769528),
#    {'스트리트': np.float32(0.5362),
#     '페미닌': np.float32(0.088),
#     '클래식': np.float32(0.0703)},
#    '하의_기장_미디',
#    '하의_카테고리_스커트',
#    '하의_소재_저지',
#    '하의_핏_노멀'],
#   [np.int64(1209326),
#    {'스트리트': np.float32(0.6147),
#     '페미닌': np.float32(0.0668),
#     '로맨틱': np.float32(0.0554)},
#    '하의_기장_발목',
#    '하의_색상_네이비',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(684647),
#    {'스트리트': np.float32(0.5854),
#     '페미닌': np.float32(0.1016),
#     '로맨틱': np.float32(0.08)},
#    '하의_기장_미니',
#    '하의_색상_화이트',
#    '하의_카테고리_팬츠',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(664064),
#    {'스트리트': np.float32(0.6578),
#     '클래식': np.float32(0.0639),
#     '리조트': np.float32(0.0561)},
#    '하의_기장_발목',
#    '하의_색상_핑크',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_와이드'],
#   [np.int64(1183449),
#    {'스트리트': np.float32(0.7007),
#     '페미닌': np.float32(0.0529),
#     '로맨틱': np.float32(0.0425)},
#    '하의_기장_발목',
#    '하의_색상_블랙',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(149126),
#    {'스트리트': np.float32(0.5806),
#     '페미닌': np.float32(0.0839),
#     '로맨틱': np.float32(0.0769)},
#    '하의_색상_베이지'],
#   [np.int64(492805),
#    {'스트리트': np.float32(0.6495),
#     '클래식': np.float32(0.0553),
#     '리조트': np.float32(0.0532)},
#    '하의_기장_발목',
#    '하의_색상_베이지',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_와이드'],
#   [np.int64(805434),
#    {'스트리트': np.float32(0.6113),
#     '페미닌': np.float32(0.0653),
#     '로맨틱': np.float32(0.0582)},
#    '하의_기장_발목',
#    '하의_색상_스카이블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(1079965),
#    {'스트리트': np.float32(0.659),
#     '페미닌': np.float32(0.0623),
#     '리조트': np.float32(0.0505)},
#    '하의_기장_발목',
#    '하의_색상_블랙',
#    '하의_카테고리_팬츠',
#    '하의_핏_노멀'],
#   [np.int64(802079),
#    {'스트리트': np.float32(0.7249),
#     '로맨틱': np.float32(0.045),
#     '페미닌': np.float32(0.0445)},
#    '하의_기장_미디',
#    '하의_색상_블랙',
#    '하의_카테고리_스커트',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(1260881),
#    {'스트리트': np.float32(0.6898),
#     '페미닌': np.float32(0.0617),
#     '클래식': np.float32(0.0455)},
#    '하의_기장_발목',
#    '하의_색상_블랙',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_루즈'],
#   [np.int64(752133),
#    {'스트리트': np.float32(0.6134),
#     '페미닌': np.float32(0.075),
#     '로맨틱': np.float32(0.0579)},
#    '하의_색상_블랙'],
#   [np.int64(1297962),
#    {'스트리트': np.float32(0.6117),
#     '페미닌': np.float32(0.0808),
#     '로맨틱': np.float32(0.0651)},
#    '하의_기장_미니',
#    '하의_색상_블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(1267699),
#    {'스트리트': np.float32(0.6321),
#     '로맨틱': np.float32(0.0739),
#     '페미닌': np.float32(0.0529)},
#    '하의_기장_발목',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_벨보텀'],
#   [np.int64(1132912),
#    {'스트리트': np.float32(0.5726),
#     '페미닌': np.float32(0.0894),
#     '로맨틱': np.float32(0.0632)},
#    '하의_기장_발목',
#    '하의_색상_블랙',
#    '하의_카테고리_조거팬츠',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(300567),
#    {'스트리트': np.float32(0.7095),
#     '리조트': np.float32(0.062),
#     '페미닌': np.float32(0.0414)},
#    '하의_기장_발목',
#    '하의_카테고리_스커트',
#    '하의_소재_니트',
#    '하의_핏_노멀'],
#   [np.int64(1305430),
#    {'스트리트': np.float32(0.5365),
#     '페미닌': np.float32(0.1031),
#     '로맨틱': np.float32(0.0839)},
#    '하의_기장_미니',
#    '하의_색상_스카이블루',
#    '하의_카테고리_스커트',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(273501),
#    {'스트리트': np.float32(0.6578),
#     '클래식': np.float32(0.0639),
#     '리조트': np.float32(0.0561)},
#    '하의_기장_발목',
#    '하의_색상_핑크',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_와이드']]}

# %%
tpo_score_table = {'데일리': {'스트리트': np.float32(0.52858794),
  '클래식': np.float32(0.29832992),
  '로맨틱': np.float32(0.530706),
  '펑크': np.float32(0.25430354),
  '페미닌': np.float32(0.4762796),
  '스포티': np.float32(0.46903458),
  '힙합': np.float32(0.32017642),
  '모던': np.float32(0.61891097),
  '프레피': np.float32(0.59357345),
  '톰보이': np.float32(0.4324854),
  '레트로': np.float32(0.56764644),
  '키치': np.float32(0.47647268),
  '아방가르드': np.float32(0.22979008),
  '오리엔탈': np.float32(0.32786918),
  '웨스턴': np.float32(0.23968673),
  '히피': np.float32(0.44711334),
  '젠더리스': np.float32(0.35417756),
  '밀리터리': np.float32(0.17381348),
  '매니시': np.float32(0.5283391),
  '컨트리': np.float32(0.3614927),
  '리조트': np.float32(0.32551143),
  '소피스트케이티드': np.float32(0.5927358),
  '섹시': np.float32(0.5265901)},
 '직장': {'스트리트': np.float32(0.2307991),
  '클래식': np.float32(0.277169),
  '로맨틱': np.float32(0.373245),
  '펑크': np.float32(0.110792525),
  '페미닌': np.float32(0.34261927),
  '스포티': np.float32(0.19779),
  '힙합': np.float32(0.15050335),
  '모던': np.float32(0.47148114),
  '프레피': np.float32(0.30647242),
  '톰보이': np.float32(0.19858037),
  '레트로': np.float32(0.32886535),
  '키치': np.float32(0.3238792),
  '아방가르드': np.float32(0.1940976),
  '오리엔탈': np.float32(0.28934458),
  '웨스턴': np.float32(0.15596609),
  '히피': np.float32(0.2015844),
  '젠더리스': np.float32(0.28316513),
  '밀리터리': np.float32(0.07486073),
  '매니시': np.float32(0.4094499),
  '컨트리': np.float32(0.22943243),
  '리조트': np.float32(0.16133589),
  '소피스트케이티드': np.float32(0.47308594),
  '섹시': np.float32(0.31044325)},
 '데이트': {'스트리트': np.float32(0.35422868),
  '클래식': np.float32(0.24003245),
  '로맨틱': np.float32(0.69649774),
  '펑크': np.float32(0.21289736),
  '페미닌': np.float32(0.5060767),
  '스포티': np.float32(0.35738122),
  '힙합': np.float32(0.26824525),
  '모던': np.float32(0.4868198),
  '프레피': np.float32(0.53625184),
  '톰보이': np.float32(0.38813046),
  '레트로': np.float32(0.46007064),
  '키치': np.float32(0.5099761),
  '아방가르드': np.float32(0.24406748),
  '오리엔탈': np.float32(0.26468188),
  '웨스턴': np.float32(0.14807768),
  '히피': np.float32(0.3811553),
  '젠더리스': np.float32(0.352549),
  '밀리터리': np.float32(0.050598018),
  '매니시': np.float32(0.4704031),
  '컨트리': np.float32(0.30839613),
  '리조트': np.float32(0.2530147),
  '소피스트케이티드': np.float32(0.65943706),
  '섹시': np.float32(0.5963634)},
 '경조사': {'스트리트': np.float32(0.36375412),
  '클래식': np.float32(0.30381358),
  '로맨틱': np.float32(0.52054816),
  '펑크': np.float32(0.14737882),
  '페미닌': np.float32(0.36699504),
  '스포티': np.float32(0.37927377),
  '힙합': np.float32(0.18956085),
  '모던': np.float32(0.5019663),
  '프레피': np.float32(0.40365452),
  '톰보이': np.float32(0.26966545),
  '레트로': np.float32(0.52741235),
  '키치': np.float32(0.4126282),
  '아방가르드': np.float32(0.1792833),
  '오리엔탈': np.float32(0.3156517),
  '웨스턴': np.float32(0.23063555),
  '히피': np.float32(0.3652409),
  '젠더리스': np.float32(0.26723626),
  '밀리터리': np.float32(0.0898062),
  '매니시': np.float32(0.3378259),
  '컨트리': np.float32(0.3745199),
  '리조트': np.float32(0.3581507),
  '소피스트케이티드': np.float32(0.51044554),
  '섹시': np.float32(0.39378038)},
 '여행': {'스트리트': np.float32(0.5842646),
  '클래식': np.float32(0.15974745),
  '로맨틱': np.float32(0.39738858),
  '펑크': np.float32(0.3726854),
  '페미닌': np.float32(0.28424317),
  '스포티': np.float32(0.5145872),
  '힙합': np.float32(0.41938052),
  '모던': np.float32(0.44138741),
  '프레피': np.float32(0.5156857),
  '톰보이': np.float32(0.39823353),
  '레트로': np.float32(0.56900585),
  '키치': np.float32(0.4954515),
  '아방가르드': np.float32(0.3834904),
  '오리엔탈': np.float32(0.408062),
  '웨스턴': np.float32(0.41594252),
  '히피': np.float32(0.5748364),
  '젠더리스': np.float32(0.27390137),
  '밀리터리': np.float32(0.16488421),
  '매니시': np.float32(0.37509647),
  '컨트리': np.float32(0.46930322),
  '리조트': np.float32(0.70026326),
  '소피스트케이티드': np.float32(0.48646387),
  '섹시': np.float32(0.4108982)},
 '파티': {'스트리트': np.float32(0.4990375),
  '클래식': np.float32(0.22124353),
  '로맨틱': np.float32(0.4567237),
  '펑크': np.float32(0.446158),
  '페미닌': np.float32(0.42028332),
  '스포티': np.float32(0.51005644),
  '힙합': np.float32(0.4711032),
  '모던': np.float32(0.4456517),
  '프레피': np.float32(0.5910596),
  '톰보이': np.float32(0.45082673),
  '레트로': np.float32(0.58568376),
  '키치': np.float32(0.55756074),
  '아방가르드': np.float32(0.40107894),
  '오리엔탈': np.float32(0.3259839),
  '웨스턴': np.float32(0.19204624),
  '히피': np.float32(0.5364033),
  '젠더리스': np.float32(0.3558746),
  '밀리터리': np.float32(0.098348536),
  '매니시': np.float32(0.44707882),
  '컨트리': np.float32(0.40599796),
  '리조트': np.float32(0.42181265),
  '소피스트케이티드': np.float32(0.65604776),
  '섹시': np.float32(0.56462836)},
 '운동': {'스트리트': np.float32(0.379994),
  '클래식': np.float32(0.043412022),
  '로맨틱': np.float32(0.16206),
  '펑크': np.float32(0.24390033),
  '페미닌': np.float32(0.1992781),
  '스포티': np.float32(0.62818235),
  '힙합': np.float32(0.5319789),
  '모던': np.float32(0.29742286),
  '프레피': np.float32(0.3966062),
  '톰보이': np.float32(0.6161824),
  '레트로': np.float32(0.314254),
  '키치': np.float32(0.2673113),
  '아방가르드': np.float32(0.2065803),
  '오리엔탈': np.float32(0.25593814),
  '웨스턴': np.float32(0.12673365),
  '히피': np.float32(0.3309636),
  '젠더리스': np.float32(0.1496136),
  '밀리터리': np.float32(0.124842584),
  '매니시': np.float32(0.34297353),
  '컨트리': np.float32(0.2250949),
  '리조트': np.float32(0.28023916),
  '소피스트케이티드': np.float32(0.27504063),
  '섹시': np.float32(0.3095897)}}

# %%
selected_tpo = '데이트'

# %%
def calculate_tpo_scores(user_clothes, tpo_score_table, selected_tpo):
    final_scores = {} # 최종결과 저장할 딕셔너리
    style_score_table = tpo_score_table[selected_tpo] # 선택된 TPO에 해당하는 스타일 유사도 점수표 ? 추출

    for category, items in user_clothes.items(): # 아우터, 상의, 하의별로
        category_scores = {} # 카테고리별 점수 저장 딕셔너리
        for item in items: # 모든 아이템 훑기
            item_id = item[0] # 아이템 ID
            style_probs = item[1] # 추정값 딕셔너리

            score = 0 # 초기 점수

            for style, prob in style_probs.items(): # 스타일별로 점수계산
                score += float(prob) * float(style_score_table[style]) # 추정값 X 스타일점수

            key = f"{category}_{item_id}" # 카테고리_ID 형태의 키 생성
            category_scores[key] = score # 점수저장

        final_scores[category] = category_scores # 카테고리별 점수를 최종 딕셔너리에 저장

    return final_scores # 계산결과 반환

# %%
result_tpo = calculate_tpo_scores(user_clothes, tpo_score_table, selected_tpo)

# %%
result_tpo
# Out:
# {'아우터': {'아우터_1062492': 0.3155415001360399,
#   '아우터_874966': 0.27944986097164604,
#   '아우터_982022': 0.3346561695517733,
#   '아우터_371876': 0.31291921498364417,
#   '아우터_183539': 0.2596389450280489,
#   '아우터_801799': 0.33336599326402316,
#   '아우터_1129354': 0.31760454507203817,
#   '아우터_1223964': 0.35517663102413577,
#   '아우터_32894': 0.2993217334563929,
#   '아우터_665095': 0.2800760844936756,
#   '아우터_925635': 0.3290662990557598,
#   '아우터_605389': 0.3001320049360814,
#   '아우터_435108': 0.28617219003114647,
#   '아우터_1005223': 0.2730412618526332,
#   '아우터_153293': 0.2471125150798651,
#   '아우터_819372': 0.3095594750764139,
#   '아우터_613978': 0.29057373951923193,
#   '아우터_1684': 0.3487341278616194,
#   '아우터_953141': 0.31356757552040415,
#   '아우터_1173062': 0.29617875304065033,
#   '아우터_1107378': 0.30568362053824516,
#   '아우터_894989': 0.32197353230663395,
#   '아우터_1054030': 0.2624427979249431,
#   '아우터_1286060': 0.30829348306295146,
#   '아우터_705888': 0.2180519147212956,
#   '아우터_353077': 0.3022426641194458,
#   '아우터_43229': 0.26103629032382325,
#   '아우터_347382': 0.2867963420591355,
#   '아우터_904555': 0.29744344645884446,
#   '아우터_199772': 0.27861239473445665,
#   '아우터_1057540': 0.33458879196236535,
#   '아우터_1141231': 0.3015691249208368,
#   '아우터_314398': 0.2960282016991986,
#   '아우터_998651': 0.31963989997099707,
#   '아우터_41267': 0.3057137037533594,
#   '아우터_828493': 0.26815411717444837,
#   '아우터_322042': 0.20648379504979397,
#   '아우터_870816': 0.2624427979249431,
#   '아우터_788047': 0.37008314863767744,
#   '아우터_1000075': 0.2637307179786047,
#   '아우터_1061385': 0.2862183119888684,
#   '아우터_964957': 0.2721641199674158,
#   '아우터_769528': 0.2565556223102876,
#   '아우터_149126': 0.30702401198774876,
#   '아우터_492805': 0.31356444103076364,
#   '아우터_805434': 0.2989464996556448,
#   '아우터_1297962': 0.29226589294358973,
#   '아우터_1221344': 0.24663702638447615},
#  '상의': {'상의_1216062': 0.29481062990358087,
#   '상의_1202131': 0.292337525903283,
#   '상의_871706': 0.29626886497402904,
#   '상의_741110': 0.30358099955738704,
#   '상의_505625': 0.3008994384988779,
#   '상의_406557': 0.2686734883927733,
#   '상의_874986': 0.31207394371879094,
#   '상의_687472': 0.3224476669759957,
#   '상의_1062492': 0.31659412024154754,
#   '상의_874966': 0.2946072850923809,
#   '상의_765219': 0.27979650689937685,
#   '상의_1091376': 0.2946072850923809,
#   '상의_1050805': 0.26570900921252527,
#   '상의_856474': 0.3080602841223907,
#   '상의_1144042': 0.20430068364554688,
#   '상의_982022': 0.2673337575963759,
#   '상의_813352': 0.28895166798474414,
#   '상의_91322': 0.26886510489455295,
#   '상의_183539': 0.28555036725272875,
#   '상의_1129354': 0.3437646476445493,
#   '상의_346111': 0.28895166798474414,
#   '상의_360257': 0.288020380701119,
#   '상의_32894': 0.31529421810560754,
#   '상의_512576': 0.290432852662729,
#   '상의_503800': 0.31453055842973976,
#   '상의_267942': 0.27730180490826406,
#   '상의_816082': 0.2611359951468386,
#   '상의_617856': 0.29494361017946,
#   '상의_876278': 0.3020155029051772,
#   '상의_998731': 0.29626886497402904,
#   '상의_1521': 0.2805041153965977,
#   '상의_155016': 0.28736552060835185,
#   '상의_717398': 0.26090691906646835,
#   '상의_605389': 0.27662887478280895,
#   '상의_1167218': 0.299236135701598,
#   '상의_846122': 0.29626886497402904,
#   '상의_602638': 0.3079981694828824,
#   '상의_890683': 0.29481062990358087,
#   '상의_435108': 0.2673337575963759,
#   '상의_919475': 0.2792837489754187,
#   '상의_902820': 0.33390750876493236,
#   '상의_153293': 0.29098498751557766,
#   '상의_939167': 0.3029648743452569,
#   '상의_267773': 0.2913241849002368,
#   '상의_498182': 0.2741446160231322,
#   '상의_686442': 0.2635769806122561,
#   '상의_1289162': 0.18890042077470248,
#   '상의_613978': 0.30421200092682965,
#   '상의_431145': 0.3135954276105366,
#   '상의_727025': 0.2735431686748757,
#   '상의_953141': 0.27655728085164766,
#   '상의_268454': 0.29584614612886595,
#   '상의_736620': 0.2741446160231322,
#   '상의_597173': 0.3154708931189183,
#   '상의_329991': 0.3060468746929079,
#   '상의_394189': 0.2953767568456511,
#   '상의_411754': 0.2916523048268731,
#   '상의_1169213': 0.2861321690943446,
#   '상의_49058': 0.3201244537537926,
#   '상의_1169233': 0.29733160681132675,
#   '상의_1173062': 0.35202713258960827,
#   '상의_1107378': 0.28165904943618825,
#   '상의_899340': 0.31801837373187314,
#   '상의_884830': 0.2975772908632168,
#   '상의_305108': 0.2535307999956826,
#   '상의_1102961': 0.23662727087683422,
#   '상의_938387': 0.2968096480757265,
#   '상의_1152234': 0.26090691906646835,
#   '상의_1166488': 0.27135211107969637,
#   '상의_217038': 0.28852957354532976,
#   '상의_960617': 0.3011388946655833,
#   '상의_1187768': 0.28677104178271473,
#   '상의_1100646': 0.30213271168889166,
#   '상의_707696': 0.30194689014763076,
#   '상의_598401': 0.27807828403503265,
#   '상의_665208': 0.23662727087683422,
#   '상의_769938': 0.2858405990848132,
#   '상의_1237181': 0.30988878104424034,
#   '상의_1259829': 0.31700818822790877,
#   '상의_1341201': 0.31751277241914844,
#   '상의_874826': 0.2931913014489764,
#   '상의_233908': 0.3460630968358375,
#   '상의_523134': 0.29481062990358087,
#   '상의_1163508': 0.31650330355229483,
#   '상의_488899': 0.27979650689937685,
#   '상의_161142': 0.3129701454324527,
#   '상의_665660': 0.2771449484210403,
#   '상의_982112': 0.2543841020428286,
#   '상의_687882': 0.29561057316447226,
#   '상의_1194858': 0.25586708104862455,
#   '상의_315725': 0.292337525903283,
#   '상의_1021849': 0.3036892164130425,
#   '상의_146872': 0.3101515876862797,
#   '상의_1126240': 0.2796089065389196,
#   '상의_541557': 0.2849605891173699,
#   '상의_260784': 0.27773769693981165,
#   '상의_850003': 0.2789634407124728,
#   '상의_868645': 0.2933819689114505,
#   '상의_857308': 0.2670199592954168,
#   '상의_856856': 0.3151882948294452,
#   '상의_967052': 0.2973861850041406,
#   '상의_1017769': 0.2928843707242561,
#   '상의_43229': 0.30421200092682965,
#   '상의_794733': 0.2755212113963541,
#   '상의_1135164': 0.26905009021532705,
#   '상의_618746': 0.30432064191990227,
#   '상의_1299673': 0.31555024020912015,
#   '상의_568789': 0.2673337575963759,
#   '상의_504555': 0.3098646573577635,
#   '상의_347382': 0.27292473512581006,
#   '상의_1175572': 0.277338485946683,
#   '상의_1007834': 0.292337525903283,
#   '상의_475136': 0.23345149641325125,
#   '상의_199772': 0.300565185756273,
#   '상의_1191105': 0.29481062990358087,
#   '상의_540084': 0.2536839133839064,
#   '상의_1162565': 0.2791632334616876,
#   '상의_10055': 0.284583186544931,
#   '상의_1123861': 0.3086929890949568,
#   '상의_854800': 0.2670199592954168,
#   '상의_794322': 0.3120844578302351,
#   '상의_504032': 0.29887848244928517,
#   '상의_1037532': 0.3160378283360159,
#   '상의_1057540': 0.26020849109158983,
#   '상의_978845': 0.27699515629045324,
#   '상의_112019': 0.2824556628850057,
#   '상의_157563': 0.29571420228652623,
#   '상의_723624': 0.3364167725333782,
#   '상의_498345': 0.32804729810794386,
#   '상의_1091726': 0.292337525903283,
#   '상의_524972': 0.3269106492188434,
#   '상의_299032': 0.27488467742044886,
#   '상의_618516': 0.294425820138264,
#   '상의_817331': 0.28677104178271473,
#   '상의_1141231': 0.2969981383021798,
#   '상의_314398': 0.2983364561912283,
#   '상의_998651': 0.30392394798033906,
#   '상의_159310': 0.30988878104424034,
#   '상의_750461': 0.2983171605318171,
#   '상의_1325561': 0.3119193949300929,
#   '상의_1176292': 0.2936167859017633,
#   '상의_742162': 0.28677104178271473,
#   '상의_1234695': 0.28895166798474414,
#   '상의_1293677': 0.32502294704148715,
#   '상의_1106578': 0.3166456817986836,
#   '상의_41267': 0.2873691920497774,
#   '상의_1145672': 0.3171093029055956,
#   '상의_411308': 0.26671083679659713,
#   '상의_828493': 0.3153384995819004,
#   '상의_256399': 0.3260171021908076,
#   '상의_1251295': 0.18928234152920487,
#   '상의_583599': 0.2782415488787755,
#   '상의_970738': 0.31575000680980336,
#   '상의_814318': 0.26930993450691953,
#   '상의_788047': 0.31471132207851915,
#   '상의_618957': 0.32191588812638194,
#   '상의_521929': 0.24189638763129107,
#   '상의_966670': 0.31801837373187314,
#   '상의_172625': 0.2902574248255372,
#   '상의_1061385': 0.23385795363342554,
#   '상의_596673': 0.30977458817465653,
#   '상의_1005633': 0.34592168374060606,
#   '상의_819482': 0.27979650689937685,
#   '상의_964957': 0.26020849109158983,
#   '상의_769528': 0.28322818194528787,
#   '상의_1209326': 0.308849803710999,
#   '상의_684647': 0.2955425090447288,
#   '상의_664064': 0.28562030081398637,
#   '상의_1183449': 0.3129701454324527,
#   '상의_149126': 0.3039157345054564,
#   '상의_1079965': 0.2565049449345058,
#   '상의_802079': 0.3199212952200854,
#   '상의_1260881': 0.3166866725215258,
#   '상의_752133': 0.31001000433325965,
#   '상의_1297962': 0.28494364306226716,
#   '상의_1267699': 0.29481062990358087,
#   '상의_1132912': 0.2834505056530763,
#   '상의_300567': 0.3163248741885343,
#   '상의_1305430': 0.3008994384988779,
#   '상의_273501': 0.282554655079587},
#  '원피스': {'원피스_1202131': 0.29211782717175994,
#   '원피스_1223964': 0.2828765417278747,
#   '원피스_998731': 0.30714206191573723,
#   '원피스_268454': 0.2656751799895063,
#   '원피스_705888': 0.2771446728948983,
#   '원피스_568789': 0.28918022829375767,
#   '원피스_475136': 0.3473146600109134,
#   '원피스_904555': 0.2678267229491367,
#   '원피스_1191105': 0.31745345212735465,
#   '원피스_322042': 0.315810036836758,
#   '원피스_1221344': 0.2906953509179402},
#  '하의': {'하의_1216062': 0.2887459791754735,
#   '하의_871706': 0.27580399815830725,
#   '하의_741110': 0.274477972797253,
#   '하의_505625': 0.29247363856145814,
#   '하의_406557': 0.3011384124356986,
#   '하의_874986': 0.30693559353058464,
#   '하의_687472': 0.3366748281220553,
#   '하의_874966': 0.3006563425270872,
#   '하의_765219': 0.29969940122137917,
#   '하의_1091376': 0.3133039487676895,
#   '하의_1050805': 0.282235239896461,
#   '하의_856474': 0.30291467767743807,
#   '하의_1144042': 0.29420396000294424,
#   '하의_813352': 0.2909052896932858,
#   '하의_91322': 0.2909052896932858,
#   '하의_371876': 0.2705786079820547,
#   '하의_183539': 0.3077463275680292,
#   '하의_801799': 0.28049351916034115,
#   '하의_346111': 0.3015840582855118,
#   '하의_360257': 0.28284397416896423,
#   '하의_32894': 0.3101810041071922,
#   '하의_665095': 0.3074425442124673,
#   '하의_512576': 0.2663113866850023,
#   '하의_503800': 0.2564245958160154,
#   '하의_267942': 0.303166606227784,
#   '하의_816082': 0.30996232488875536,
#   '하의_617856': 0.30156213804691445,
#   '하의_876278': 0.2587655913862764,
#   '하의_925635': 0.3033565624409691,
#   '하의_1521': 0.2675613576730833,
#   '하의_155016': 0.2842712167694976,
#   '하의_717398': 0.29012296529760384,
#   '하의_605389': 0.2983685001566466,
#   '하의_1167218': 0.30081255655986716,
#   '하의_846122': 0.30204703541600564,
#   '하의_602638': 0.26626815658017944,
#   '하의_890683': 0.25778715385955,
#   '하의_1005223': 0.26675638974224747,
#   '하의_919475': 0.3063464109847853,
#   '하의_902820': 0.2918404879434575,
#   '하의_939167': 0.30518982341425405,
#   '하의_267773': 0.34450798192072796,
#   '하의_498182': 0.29440221059444593,
#   '하의_819372': 0.2995131217691511,
#   '하의_686442': 0.2528026783700557,
#   '하의_1289162': 0.2663113866850023,
#   '하의_613978': 0.296912319891357,
#   '하의_431145': 0.29237923301611457,
#   '하의_1684': 0.29969940122137917,
#   '하의_727025': 0.2663113866850023,
#   '하의_736620': 0.2710155095629118,
#   '하의_597173': 0.290128925427692,
#   '하의_329991': 0.296546458485464,
#   '하의_394189': 0.30512653658070477,
#   '하의_411754': 0.2619170482343529,
#   '하의_1169213': 0.28641091567811516,
#   '하의_49058': 0.2878661997522114,
#   '하의_1169233': 0.29593276956165004,
#   '하의_1173062': 0.2920228275023744,
#   '하의_1107378': 0.27560650511513707,
#   '하의_899340': 0.29263740407021865,
#   '하의_884830': 0.3230252395233867,
#   '하의_305108': 0.2746454219881097,
#   '하의_1102961': 0.2948521469803378,
#   '하의_938387': 0.2746454219881097,
#   '하의_894989': 0.2953917967672022,
#   '하의_1152234': 0.29648560343450825,
#   '하의_1054030': 0.2782095965693281,
#   '하의_1166488': 0.3011384124356986,
#   '하의_217038': 0.30649716346137756,
#   '하의_960617': 0.29245072545569695,
#   '하의_1187768': 0.2864933576833038,
#   '하의_1100646': 0.2741308883199621,
#   '하의_707696': 0.30326833254563357,
#   '하의_598401': 0.2864933576833038,
#   '하의_665208': 0.268537343332115,
#   '하의_769938': 0.29440221059444593,
#   '하의_1237181': 0.29550430121785354,
#   '하의_1259829': 0.27580399815830725,
#   '하의_1341201': 0.2675613576730833,
#   '하의_1286060': 0.2918404879434575,
#   '하의_874826': 0.2918404879434575,
#   '하의_233908': 0.3049888761200401,
#   '하의_353077': 0.26807123316413284,
#   '하의_523134': 0.25499128696202233,
#   '하의_1163508': 0.2991654234295622,
#   '하의_488899': 0.3033565624409691,
#   '하의_161142': 0.3129973293212842,
#   '하의_665660': 0.2567877100591458,
#   '하의_982112': 0.2919441869232393,
#   '하의_687882': 0.2668221326953183,
#   '하의_1194858': 0.3206981078973725,
#   '하의_315725': 0.2955668360810011,
#   '하의_1021849': 0.297681637425975,
#   '하의_146872': 0.30784451863901685,
#   '하의_1126240': 0.2663113866850023,
#   '하의_541557': 0.3033565624409691,
#   '하의_260784': 0.30169099011046474,
#   '하의_850003': 0.2919441869232393,
#   '하의_868645': 0.296912319891357,
#   '하의_857308': 0.2663113866850023,
#   '하의_856856': 0.2893416082534307,
#   '하의_967052': 0.2901362698886336,
#   '하의_1017769': 0.26675638974224747,
#   '하의_43229': 0.2902290367168776,
#   '하의_794733': 0.2749655781853204,
#   '하의_1135164': 0.2793410762466946,
#   '하의_618746': 0.22080372853925212,
#   '하의_1299673': 0.2874951767946874,
#   '하의_568789': 0.28997706026827363,
#   '하의_504555': 0.29969940122137917,
#   '하의_1175572': 0.29847996629892304,
#   '하의_1007834': 0.29440221059444593,
#   '하의_540084': 0.2887965680198157,
#   '하의_1162565': 0.23093174517308424,
#   '하의_10055': 0.29420396000294424,
#   '하의_1123861': 0.3011384124356986,
#   '하의_854800': 0.30081255655986716,
#   '하의_794322': 0.31319292413705613,
#   '하의_504032': 0.2749655781853204,
#   '하의_1037532': 0.2901362698886336,
#   '하의_1057540': 0.2901362698886336,
#   '하의_978845': 0.2710422158050745,
#   '하의_112019': 0.29157119833281264,
#   '하의_157563': 0.2935668285972408,
#   '하의_723624': 0.28245747380105213,
#   '하의_498345': 0.29012296529760384,
#   '하의_1091726': 0.2953917967672022,
#   '하의_524972': 0.2874951767946874,
#   '하의_299032': 0.26256433601614804,
#   '하의_618516': 0.30458063951640724,
#   '하의_817331': 0.4157933078236731,
#   '하의_1141231': 0.30286950058695417,
#   '하의_314398': 0.2955668360810011,
#   '하의_998651': 0.29581981800894086,
#   '하의_159310': 0.29946673871185236,
#   '하의_750461': 0.27158423677926735,
#   '하의_1325561': 0.30168568492810843,
#   '하의_1176292': 0.3043875844053714,
#   '하의_742162': 0.2832567773023211,
#   '하의_1234695': 0.3206981078973725,
#   '하의_1293677': 0.2469040249435358,
#   '하의_1106578': 0.2746454219881097,
#   '하의_41267': 0.2874951767946874,
#   '하의_1145672': 0.3206981078973725,
#   '하의_411308': 0.2901362698886336,
#   '하의_828493': 0.3024489684649463,
#   '하의_256399': 0.2925824851101593,
#   '하의_1251295': 0.30168568492810843,
#   '하의_583599': 0.27439553309645154,
#   '하의_870816': 0.2954288922949053,
#   '하의_970738': 0.29696160444595643,
#   '하의_814318': 0.3011384124356986,
#   '하의_788047': 0.2874951767946874,
#   '하의_618957': 0.29236562720333725,
#   '하의_521929': 0.3153266925875819,
#   '하의_966670': 0.2663113866850023,
#   '하의_1000075': 0.30458063951640724,
#   '하의_172625': 0.3182835473964092,
#   '하의_1061385': 0.290128925427692,
#   '하의_596673': 0.27439553309645154,
#   '하의_1005633': 0.3033565624409691,
#   '하의_819482': 0.3130526639711972,
#   '하의_964957': 0.2663113866850023,
#   '하의_769528': 0.25134644058503697,
#   '하의_1209326': 0.2901362698886336,
#   '하의_684647': 0.3145026706217493,
#   '하의_664064': 0.26254382850004654,
#   '하의_1183449': 0.30458063951640724,
#   '하의_149126': 0.30168568492810843,
#   '하의_492805': 0.2568057062598646,
#   '하의_805434': 0.29012296529760384,
#   '하의_1079965': 0.2777425114598219,
#   '하의_802079': 0.31064318206597186,
#   '하의_1260881': 0.2864933576833038,
#   '하의_752133': 0.2955668360810011,
#   '하의_1297962': 0.30291467767743807,
#   '하의_1267699': 0.3021505809163463,
#   '하의_1132912': 0.2920932537954277,
#   '하의_300567': 0.2879637377317932,
#   '하의_1305430': 0.3006563425270872,
#   '하의_273501': 0.26254382850004654}}

# %%
user_clothes
# Out:
# {'아우터': [[np.int64(1062492),
#    {'스트리트': np.float32(0.7875),
#     '컨트리': np.float32(0.0493),
#     '로맨틱': np.float32(0.0307)},
#    '아우터_기장_노말',
#    '아우터_색상_핑크',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_브이넥',
#    '아우터_핏_노멀'],
#   [np.int64(874966),
#    {'스트리트': np.float32(0.6117),
#     '리조트': np.float32(0.0697),
#     '로맨틱': np.float32(0.0648)},
#    '아우터_기장_하프',
#    '아우터_색상_블랙',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_노멀'],
#   [np.int64(982022),
#    {'스트리트': np.float32(0.8534),
#     '클래식': np.float32(0.0381),
#     '소피스트케이티드': np.float32(0.0352)},
#    '아우터_기장_하프',
#    '아우터_색상_네온',
#    '아우터_카테고리_코트',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_후드',
#    '아우터_핏_노멀'],
#   [np.int64(371876),
#    {'스트리트': np.float32(0.761),
#     '로맨틱': np.float32(0.0496),
#     '리조트': np.float32(0.0348)},
#    '아우터_기장_롱',
#    '아우터_색상_블랙',
#    '아우터_카테고리_코트',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_노멀'],
#   [np.int64(183539),
#    {'스트리트': np.float32(0.6502),
#     '리조트': np.float32(0.0619),
#     '클래식': np.float32(0.0569)},
#    '아우터_기장_하프',
#    '아우터_색상_그레이',
#    '아우터_카테고리_코트',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_루즈'],
#   [np.int64(801799),
#    {'스트리트': np.float32(0.7517),
#     '페미닌': np.float32(0.0687),
#     '모던': np.float32(0.0664)},
#    '아우터_기장_하프',
#    '아우터_색상_베이지',
#    '아우터_카테고리_짚업',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_터틀넥',
#    '아우터_핏_루즈'],
#   [np.int64(1129354),
#    {'스트리트': np.float32(0.7465),
#     '로맨틱': np.float32(0.0443),
#     '페미닌': np.float32(0.0441)},
#    '아우터_기장_롱',
#    '아우터_색상_베이지',
#    '아우터_카테고리_코트',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_루즈'],
#   [np.int64(1223964),
#    {'스트리트': np.float32(0.5467),
#     '소피스트케이티드': np.float32(0.1562),
#     '모던': np.float32(0.1202)},
#    '아우터_기장_노말',
#    '아우터_색상_그레이',
#    '아우터_카테고리_짚업',
#    '아우터_소매기장_캡',
#    '아우터_넥라인_터틀넥',
#    '아우터_핏_노멀'],
#   [np.int64(32894),
#    {'스트리트': np.float32(0.6731),
#     '페미닌': np.float32(0.0566),
#     '소피스트케이티드': np.float32(0.0489)},
#    '아우터_색상_브라운',
#    '아우터_소매기장_긴팔'],
#   [np.int64(665095),
#    {'스트리트': np.float32(0.5693),
#     '리조트': np.float32(0.1219),
#     '페미닌': np.float32(0.094)},
#    '아우터_기장_노말',
#    '아우터_색상_화이트',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_7부소매',
#    '아우터_넥라인_노카라',
#    '아우터_핏_노멀'],
#   [np.int64(925635),
#    {'스트리트': np.float32(0.6744),
#     '모던': np.float32(0.1003),
#     '페미닌': np.float32(0.0817)},
#    '아우터_기장_하프',
#    '아우터_색상_카키',
#    '아우터_카테고리_점퍼',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_노카라',
#    '아우터_핏_오버사이즈'],
#   [np.int64(605389),
#    {'스트리트': np.float32(0.6717),
#     '페미닌': np.float32(0.0556),
#     '로맨틱': np.float32(0.0489)},
#    '아우터_기장_노말',
#    '아우터_카테고리_재킷',
#    '아우터_핏_노멀'],
#   [np.int64(435108),
#    {'스트리트': np.float32(0.6853),
#     '리조트': np.float32(0.0888),
#     '페미닌': np.float32(0.0414)},
#    '아우터_기장_노말',
#    '아우터_색상_카키',
#    '아우터_카테고리_점퍼',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_루즈'],
#   [np.int64(1005223),
#    {'스트리트': np.float32(0.6078),
#     '리조트': np.float32(0.0966),
#     '페미닌': np.float32(0.0658)},
#    '아우터_기장_노말',
#    '아우터_색상_베이지',
#    '아우터_카테고리_가디건',
#    '아우터_소매기장_민소매'],
#   [np.int64(153293),
#    {'스트리트': np.float32(0.5397),
#     '클래식': np.float32(0.1165),
#     '컨트리': np.float32(0.0907)},
#    '아우터_기장_하프',
#    '아우터_색상_블랙',
#    '아우터_카테고리_베스트',
#    '아우터_소매기장_민소매',
#    '아우터_핏_노멀'],
#   [np.int64(819372),
#    {'스트리트': np.float32(0.5095),
#     '스포티': np.float32(0.1813),
#     '로맨틱': np.float32(0.0923)},
#    '아우터_기장_하프',
#    '아우터_색상_핑크',
#    '아우터_카테고리_가디건',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_브이넥',
#    '아우터_핏_루즈'],
#   [np.int64(613978),
#    {'스트리트': np.float32(0.7051),
#     '리조트': np.float32(0.0526),
#     '소피스트케이티드': np.float32(0.0417)},
#    '아우터_기장_롱',
#    '아우터_색상_베이지',
#    '아우터_카테고리_가디건',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_루즈'],
#   [np.int64(1684),
#    {'스트리트': np.float32(0.9309),
#     '로맨틱': np.float32(0.0173),
#     '페미닌': np.float32(0.0137)},
#    '아우터_기장_노말',
#    '아우터_색상_베이지',
#    '아우터_카테고리_코트',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_루즈'],
#   [np.int64(953141),
#    {'스트리트': np.float32(0.7232),
#     '로맨틱': np.float32(0.0497),
#     '페미닌': np.float32(0.045)},
#    '아우터_기장_롱',
#    '아우터_색상_그레이',
#    '아우터_카테고리_코트',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_노멀'],
#   [np.int64(1173062),
#    {'스트리트': np.float32(0.6379),
#     '페미닌': np.float32(0.0614),
#     '로맨틱': np.float32(0.0562)},
#    '아우터_색상_카키',
#    '아우터_소매기장_긴팔'],
#   [np.int64(1107378),
#    {'스트리트': np.float32(0.7289),
#     '페미닌': np.float32(0.0542),
#     '모던': np.float32(0.0412)},
#    '아우터_기장_하프',
#    '아우터_색상_블랙',
#    '아우터_카테고리_점퍼',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_노카라',
#    '아우터_핏_노멀'],
#   [np.int64(894989),
#    {'스트리트': np.float32(0.7947),
#     '리조트': np.float32(0.0435),
#     '로맨틱': np.float32(0.0423)},
#    '아우터_기장_하프',
#    '아우터_색상_베이지',
#    '아우터_카테고리_가디건',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_브이넥',
#    '아우터_핏_루즈'],
#   [np.int64(1054030),
#    {'스트리트': np.float32(0.6615),
#     '클래식': np.float32(0.0596),
#     '리조트': np.float32(0.0546)},
#    '아우터_기장_하프',
#    '아우터_색상_베이지',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_노멀'],
#   [np.int64(1286060),
#    {'스트리트': np.float32(0.7781),
#     '페미닌': np.float32(0.0401),
#     '젠더리스': np.float32(0.0351)},
#    '아우터_기장_하프',
#    '아우터_카테고리_베스트',
#    '아우터_핏_노멀'],
#   [np.int64(705888),
#    {'스트리트': np.float32(0.4458),
#     '컨트리': np.float32(0.1123),
#     '리조트': np.float32(0.1008)},
#    '아우터_색상_베이지',
#    '아우터_소매기장_반팔'],
#   [np.int64(353077),
#    {'스트리트': np.float32(0.6273),
#     '로맨틱': np.float32(0.0772),
#     '페미닌': np.float32(0.0519)},
#    '아우터_기장_하프',
#    '아우터_색상_화이트',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_반팔',
#    '아우터_핏_노멀'],
#   [np.int64(43229),
#    {'스트리트': np.float32(0.5953),
#     '페미닌': np.float32(0.0691),
#     '클래식': np.float32(0.0633)},
#    '아우터_기장_하프',
#    '아우터_색상_그레이',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_루즈'],
#   [np.int64(347382),
#    {'스트리트': np.float32(0.5103),
#     '로맨틱': np.float32(0.0908),
#     '모던': np.float32(0.0879)},
#    '아우터_기장_하프',
#    '아우터_색상_그레이',
#    '아우터_카테고리_가디건',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_노카라',
#    '아우터_핏_노멀'],
#   [np.int64(904555),
#    {'스트리트': np.float32(0.6128),
#     '로맨틱': np.float32(0.0702),
#     '페미닌': np.float32(0.0622)},
#    '아우터_기장_노말',
#    '아우터_색상_화이트',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_7부소매',
#    '아우터_핏_노멀'],
#   [np.int64(199772),
#    {'스트리트': np.float32(0.6795),
#     '리조트': np.float32(0.0744),
#     '컨트리': np.float32(0.0619)},
#    '아우터_기장_노말',
#    '아우터_카테고리_재킷',
#    '아우터_넥라인_브이넥',
#    '아우터_핏_타이트'],
#   [np.int64(1057540),
#    {'스트리트': np.float32(0.5754),
#     '스포티': np.float32(0.2858),
#     '로맨틱': np.float32(0.0411)},
#    '아우터_기장_하프',
#    '아우터_색상_실버',
#    '아우터_카테고리_패딩',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_터틀넥',
#    '아우터_핏_루즈'],
#   [np.int64(1141231),
#    {'스트리트': np.float32(0.8003),
#     '리조트': np.float32(0.0374),
#     '클래식': np.float32(0.0359)},
#    '아우터_기장_하프',
#    '아우터_색상_베이지',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_반팔',
#    '아우터_핏_노멀'],
#   [np.int64(314398),
#    {'스트리트': np.float32(0.7013),
#     '로맨틱': np.float32(0.0525),
#     '클래식': np.float32(0.046)},
#    '아우터_기장_하프',
#    '아우터_색상_베이지',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_라운드넥',
#    '아우터_핏_노멀'],
#   [np.int64(998651),
#    {'스트리트': np.float32(0.788),
#     '페미닌': np.float32(0.0446),
#     '소피스트케이티드': np.float32(0.0272)},
#    '아우터_카테고리_가디건',
#    '아우터_넥라인_브이넥',
#    '아우터_핏_노멀'],
#   [np.int64(41267),
#    {'스트리트': np.float32(0.6733),
#     '로맨틱': np.float32(0.0779),
#     '리조트': np.float32(0.0512)},
#    '아우터_기장_롱',
#    '아우터_색상_블랙',
#    '아우터_카테고리_가디건',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_노멀'],
#   [np.int64(828493),
#    {'스트리트': np.float32(0.6271),
#     '클래식': np.float32(0.065),
#     '페미닌': np.float32(0.0601)},
#    '아우터_기장_노말',
#    '아우터_카테고리_재킷',
#    '아우터_핏_루즈'],
#   [np.int64(322042),
#    {'스트리트': np.float32(0.2649),
#     '리조트': np.float32(0.1716),
#     '페미닌': np.float32(0.1368)},
#    '아우터_색상_베이지',
#    '아우터_소매기장_민소매'],
#   [np.int64(870816),
#    {'스트리트': np.float32(0.6615),
#     '클래식': np.float32(0.0596),
#     '리조트': np.float32(0.0546)},
#    '아우터_기장_하프',
#    '아우터_색상_베이지',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_노멀'],
#   [np.int64(788047),
#    {'스트리트': np.float32(0.5771),
#     '페미닌': np.float32(0.1612),
#     '소피스트케이티드': np.float32(0.1275)},
#    '아우터_기장_맥시',
#    '아우터_색상_골드',
#    '아우터_카테고리_가디건',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_루즈'],
#   [np.int64(1000075),
#    {'스트리트': np.float32(0.5923),
#     '페미닌': np.float32(0.077),
#     '리조트': np.float32(0.0591)},
#    '아우터_기장_롱',
#    '아우터_색상_카키',
#    '아우터_카테고리_가디건',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_노카라',
#    '아우터_핏_루즈'],
#   [np.int64(1061385),
#    {'스트리트': np.float32(0.4874),
#     '모던': np.float32(0.1207),
#     '페미닌': np.float32(0.1083)},
#    '아우터_기장_하프',
#    '아우터_색상_베이지',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_노카라',
#    '아우터_핏_오버사이즈'],
#   [np.int64(964957),
#    {'스트리트': np.float32(0.5434),
#     '페미닌': np.float32(0.1314),
#     '클래식': np.float32(0.0549)},
#    '아우터_기장_노말',
#    '아우터_색상_베이지',
#    '아우터_카테고리_짚업',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_후드',
#    '아우터_핏_루즈'],
#   [np.int64(769528),
#    {'스트리트': np.float32(0.5354),
#     '페미닌': np.float32(0.0954),
#     '리조트': np.float32(0.0736)},
#    '아우터_기장_하프',
#    '아우터_카테고리_재킷',
#    '아우터_핏_루즈'],
#   [np.int64(149126),
#    {'스트리트': np.float32(0.6302),
#     '페미닌': np.float32(0.094),
#     '로맨틱': np.float32(0.052)},
#    '아우터_기장_하프',
#    '아우터_색상_블랙',
#    '아우터_카테고리_점퍼',
#    '아우터_소매기장_긴팔',
#    '아우터_넥라인_후드',
#    '아우터_핏_루즈'],
#   [np.int64(492805),
#    {'스트리트': np.float32(0.7425),
#     '페미닌': np.float32(0.048),
#     '로맨틱': np.float32(0.0377)},
#    '아우터_기장_노말',
#    '아우터_색상_베이지',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_긴팔',
#    '아우터_핏_노멀'],
#   [np.int64(805434),
#    {'스트리트': np.float32(0.7077),
#     '컨트리': np.float32(0.0993),
#     '리조트': np.float32(0.0697)},
#    '아우터_기장_노말',
#    '아우터_색상_오렌지',
#    '아우터_카테고리_베스트',
#    '아우터_소매기장_민소매',
#    '아우터_넥라인_브이넥',
#    '아우터_핏_노멀'],
#   [np.int64(1297962),
#    {'스트리트': np.float32(0.6771),
#     '클래식': np.float32(0.0729),
#     '페미닌': np.float32(0.069)},
#    '아우터_기장_노말',
#    '아우터_색상_베이지',
#    '아우터_카테고리_재킷',
#    '아우터_소매기장_반팔',
#    '아우터_넥라인_브이넥',
#    '아우터_핏_루즈'],
#   [np.int64(1221344),
#    {'스트리트': np.float32(0.4974),
#     '페미닌': np.float32(0.0929),
#     '리조트': np.float32(0.0926)},
#    '아우터_기장_롱',
#    '아우터_색상_베이지',
#    '아우터_카테고리_베스트',
#    '아우터_소매기장_민소매',
#    '아우터_넥라인_노카라',
#    '아우터_핏_루즈']],
#  '상의': [[np.int64(1216062),
#    {'스트리트': np.float32(0.6033),
#     '페미닌': np.float32(0.0803),
#     '로맨틱': np.float32(0.0581)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(1202131),
#    {'스트리트': np.float32(0.5728),
#     '페미닌': np.float32(0.0841),
#     '로맨틱': np.float32(0.0673)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(871706),
#    {'스트리트': np.float32(0.6085),
#     '페미닌': np.float32(0.075),
#     '로맨틱': np.float32(0.0614)},
#    '상의_색상_블랙',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(741110),
#    {'스트리트': np.float32(0.6939),
#     '로맨틱': np.float32(0.0499),
#     '페미닌': np.float32(0.0455)},
#    '상의_색상_베이지',
#    '상의_카테고리_셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(505625),
#    {'스트리트': np.float32(0.6273),
#     '페미닌': np.float32(0.0809),
#     '로맨틱': np.float32(0.0542)},
#    '상의_색상_블랙',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(406557),
#    {'스트리트': np.float32(0.5449),
#     '페미닌': np.float32(0.1032),
#     '클래식': np.float32(0.0976)},
#    '상의_색상_그레이',
#    '상의_카테고리_셔츠',
#    '상의_옷깃_셔츠칼라',
#    '상의_소매기장_7부소매',
#    '상의_소재_우븐',
#    '상의_핏_오버사이즈'],
#   [np.int64(874986),
#    {'스트리트': np.float32(0.5698),
#     '페미닌': np.float32(0.1485),
#     '소피스트케이티드': np.float32(0.0532)},
#    '상의_색상_블랙',
#    '상의_카테고리_탑',
#    '상의_소매기장_민소매',
#    '상의_소재_스판덱스',
#    '상의_핏_타이트'],
#   [np.int64(687472),
#    {'스트리트': np.float32(0.6819),
#     '페미닌': np.float32(0.0726),
#     '로맨틱': np.float32(0.0634)},
#    '상의_색상_와인',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(1062492),
#    {'스트리트': np.float32(0.6682),
#     '로맨틱': np.float32(0.092),
#     '컨트리': np.float32(0.0513)},
#    '상의_색상_화이트',
#    '상의_카테고리_탑',
#    '상의_소매기장_없음',
#    '상의_소재_실크',
#    '상의_핏_타이트'],
#   [np.int64(874966),
#    {'스트리트': np.float32(0.5915),
#     '페미닌': np.float32(0.0799),
#     '로맨틱': np.float32(0.0641)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(765219),
#    {'스트리트': np.float32(0.6838),
#     '리조트': np.float32(0.0529),
#     '페미닌': np.float32(0.0478)},
#    '상의_색상_화이트',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(1091376),
#    {'스트리트': np.float32(0.5915),
#     '페미닌': np.float32(0.0799),
#     '로맨틱': np.float32(0.0641)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(1050805),
#    {'스트리트': np.float32(0.5976),
#     '페미닌': np.float32(0.079),
#     '클래식': np.float32(0.0585)},
#    '상의_색상_네이비',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(856474),
#    {'스트리트': np.float32(0.5692),
#     '페미닌': np.float32(0.0903),
#     '로맨틱': np.float32(0.0872)},
#    '상의_색상_레드',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(1144042),
#    {'스트리트': np.float32(0.3473),
#     '클래식': np.float32(0.1147),
#     '페미닌': np.float32(0.1062)},
#    '상의_색상_골드',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(982022),
#    {'스트리트': np.float32(0.5989),
#     '페미닌': np.float32(0.078),
#     '리조트': np.float32(0.0621)},
#    '상의_카테고리_티셔츠',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(813352),
#    {'스트리트': np.float32(0.5889),
#     '페미닌': np.float32(0.0766),
#     '로맨틱': np.float32(0.0597)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(91322),
#    {'스트리트': np.float32(0.4687),
#     '페미닌': np.float32(0.0876),
#     '로맨틱': np.float32(0.084)},
#    '상의_색상_화이트',
#    '상의_카테고리_탑',
#    '상의_소매기장_민소매',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(183539),
#    {'스트리트': np.float32(0.6914),
#     '리조트': np.float32(0.0548),
#     '페미닌': np.float32(0.0529)},
#    '상의_카테고리_니트웨어',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(1129354),
#    {'스트리트': np.float32(0.6657),
#     '로맨틱': np.float32(0.1215),
#     '페미닌': np.float32(0.0461)},
#    '상의_색상_블랙',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_없음',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(346111),
#    {'스트리트': np.float32(0.5889),
#     '페미닌': np.float32(0.0766),
#     '로맨틱': np.float32(0.0597)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(360257),
#    {'스트리트': np.float32(0.567),
#     '페미닌': np.float32(0.0856),
#     '소피스트케이티드': np.float32(0.0665)},
#    '상의_색상_화이트',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(32894),
#    {'스트리트': np.float32(0.6573),
#     '로맨틱': np.float32(0.0801),
#     '페미닌': np.float32(0.0527)},
#    '상의_카테고리_니트웨어',
#    '상의_소재_니트',
#    '상의_핏_루즈'],
#   [np.int64(512576),
#    {'스트리트': np.float32(0.5291),
#     '페미닌': np.float32(0.1728),
#     '리조트': np.float32(0.0615)},
#    '상의_색상_민트',
#    '상의_카테고리_후드티',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(503800),
#    {'스트리트': np.float32(0.6617),
#     '페미닌': np.float32(0.0766),
#     '로맨틱': np.float32(0.0594)},
#    '상의_색상_브라운',
#    '상의_소매기장_민소매'],
#   [np.int64(267942),
#    {'스트리트': np.float32(0.6058),
#     '페미닌': np.float32(0.0636),
#     '모던': np.float32(0.0627)},
#    '상의_색상_그레이',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(816082),
#    {'스트리트': np.float32(0.5691),
#     '페미닌': np.float32(0.0755),
#     '스포티': np.float32(0.0597)},
#    '상의_색상_핑크',
#    '상의_카테고리_탑',
#    '상의_소매기장_민소매',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(617856),
#    {'스트리트': np.float32(0.6559),
#     '모던': np.float32(0.0606),
#     '소피스트케이티드': np.float32(0.0502)},
#    '상의_색상_레드',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_7부소매',
#    '상의_소재_울/캐시미어',
#    '상의_핏_루즈'],
#   [np.int64(876278),
#    {'스트리트': np.float32(0.639),
#     '페미닌': np.float32(0.0712),
#     '로맨틱': np.float32(0.0569)},
#    '상의_색상_화이트',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_반팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(998731),
#    {'스트리트': np.float32(0.6085),
#     '페미닌': np.float32(0.075),
#     '로맨틱': np.float32(0.0614)},
#    '상의_색상_블랙',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(1521),
#    {'스트리트': np.float32(0.572),
#     '로맨틱': np.float32(0.0691),
#     '페미닌': np.float32(0.0588)},
#    '상의_색상_핑크',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(155016),
#    {'스트리트': np.float32(0.5671),
#     '페미닌': np.float32(0.089),
#     '로맨틱': np.float32(0.0595)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(717398),
#    {'스트리트': np.float32(0.5839),
#     '페미닌': np.float32(0.0753),
#     '리조트': np.float32(0.0631)},
#    '상의_색상_베이지',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(605389),
#    {'스트리트': np.float32(0.6155),
#     '리조트': np.float32(0.0725),
#     '로맨틱': np.float32(0.0578)},
#    '상의_색상_블루',
#    '상의_소매기장_긴팔'],
#   [np.int64(1167218),
#    {'스트리트': np.float32(0.5541),
#     '로맨틱': np.float32(0.0934),
#     '페미닌': np.float32(0.0749)},
#    '상의_색상_스카이블루',
#    '상의_카테고리_탑',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(846122),
#    {'스트리트': np.float32(0.6085),
#     '페미닌': np.float32(0.075),
#     '로맨틱': np.float32(0.0614)},
#    '상의_색상_블랙',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(602638),
#    {'스트리트': np.float32(0.6326),
#     '페미닌': np.float32(0.0725),
#     '로맨틱': np.float32(0.0678)},
#    '상의_색상_화이트',
#    '상의_카테고리_블라우스',
#    '상의_옷깃_차이나칼라',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(890683),
#    {'스트리트': np.float32(0.6033),
#     '페미닌': np.float32(0.0803),
#     '로맨틱': np.float32(0.0581)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(435108),
#    {'스트리트': np.float32(0.5989),
#     '페미닌': np.float32(0.078),
#     '리조트': np.float32(0.0621)},
#    '상의_카테고리_티셔츠',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(919475),
#    {'스트리트': np.float32(0.7107),
#     '클래식': np.float32(0.0561),
#     '리조트': np.float32(0.0556)},
#    '상의_색상_와인',
#    '상의_카테고리_블라우스',
#    '상의_옷깃_셔츠칼라',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(902820),
#    {'스트리트': np.float32(0.7356),
#     '소피스트케이티드': np.float32(0.0667),
#     '페미닌': np.float32(0.058)},
#    '상의_색상_라벤더',
#    '상의_카테고리_블라우스',
#    '상의_옷깃_피터팬칼라',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(153293),
#    {'스트리트': np.float32(0.4245),
#     '페미닌': np.float32(0.1255),
#     '로맨틱': np.float32(0.1107)},
#    '상의_카테고리_티셔츠',
#    '상의_소재_저지',
#    '상의_핏_오버사이즈'],
#   [np.int64(939167),
#    {'스트리트': np.float32(0.6632),
#     '페미닌': np.float32(0.1006),
#     '리조트': np.float32(0.0677)},
#    '상의_색상_베이지',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_7부소매',
#    '상의_소재_저지',
#    '상의_소재_레이스',
#    '상의_핏_루즈'],
#   [np.int64(267773),
#    {'스트리트': np.float32(0.413),
#     '페미닌': np.float32(0.14),
#     '로맨틱': np.float32(0.1065)},
#    '상의_색상_그린',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(498182),
#    {'스트리트': np.float32(0.6397),
#     '페미닌': np.float32(0.0649),
#     '리조트': np.float32(0.0581)},
#    '상의_색상_베이지',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(686442),
#    {'스트리트': np.float32(0.5924),
#     '리조트': np.float32(0.0728),
#     '로맨틱': np.float32(0.0507)},
#    '상의_색상_브라운',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_반팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(1289162),
#    {'스트리트': np.float32(0.2624),
#     '스포티': np.float32(0.1245),
#     '모던': np.float32(0.1057)},
#    '상의_색상_스카이블루',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_7부소매',
#    '상의_소재_실크',
#    '상의_핏_노멀'],
#   [np.int64(613978),
#    {'스트리트': np.float32(0.6758),
#     '페미닌': np.float32(0.0557),
#     '로맨틱': np.float32(0.0526)},
#    '상의_카테고리_탑',
#    '상의_소재_저지',
#    '상의_핏_타이트'],
#   [np.int64(431145),
#    {'스트리트': np.float32(0.6024),
#     '페미닌': np.float32(0.0995),
#     '소피스트케이티드': np.float32(0.0756)},
#    '상의_색상_와인',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_울/캐시미어',
#    '상의_핏_루즈'],
#   [np.int64(727025),
#    {'스트리트': np.float32(0.6165),
#     '페미닌': np.float32(0.0841),
#     '리조트': np.float32(0.0498)},
#    '상의_색상_카키',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_7부소매',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(953141),
#    {'스트리트': np.float32(0.5601),
#     '페미닌': np.float32(0.0812),
#     '소피스트케이티드': np.float32(0.0562)},
#    '상의_카테고리_블라우스',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(268454),
#    {'스트리트': np.float32(0.6087),
#     '페미닌': np.float32(0.0743),
#     '로맨틱': np.float32(0.0612)},
#    '상의_색상_화이트',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_7부소매',
#    '상의_소재_우븐'],
#   [np.int64(736620),
#    {'스트리트': np.float32(0.6397),
#     '페미닌': np.float32(0.0649),
#     '리조트': np.float32(0.0581)},
#    '상의_색상_베이지',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(597173),
#    {'스트리트': np.float32(0.6898),
#     '로맨틱': np.float32(0.0708),
#     '페미닌': np.float32(0.0431)},
#    '상의_색상_네이비',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_반팔',
#    '상의_소재_실크',
#    '상의_핏_노멀'],
#   [np.int64(329991),
#    {'스트리트': np.float32(0.705),
#     '클래식': np.float32(0.1195),
#     '페미닌': np.float32(0.0546)},
#    '상의_색상_베이지',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_반팔',
#    '상의_소재_니트',
#    '상의_소재_울/캐시미어',
#    '상의_핏_타이트'],
#   [np.int64(394189),
#    {'스트리트': np.float32(0.4925),
#     '페미닌': np.float32(0.1203),
#     '로맨틱': np.float32(0.0862)},
#    '상의_색상_스카이블루',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(411754),
#    {'스트리트': np.float32(0.5711),
#     '로맨틱': np.float32(0.0759),
#     '페미닌': np.float32(0.0721)},
#    '상의_색상_브라운',
#    '상의_카테고리_셔츠',
#    '상의_옷깃_셔츠칼라',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(1169213),
#    {'스트리트': np.float32(0.587),
#     '로맨틱': np.float32(0.0665),
#     '페미닌': np.float32(0.063)},
#    '상의_색상_그레이',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(49058),
#    {'스트리트': np.float32(0.7377),
#     '로맨틱': np.float32(0.0555),
#     '모던': np.float32(0.0414)},
#    '상의_색상_네이비',
#    '상의_카테고리_셔츠',
#    '상의_옷깃_셔츠칼라',
#    '상의_소매기장_7부소매',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(1169233),
#    {'스트리트': np.float32(0.6196),
#     '페미닌': np.float32(0.0769),
#     '로맨틱': np.float32(0.0559)},
#    '상의_색상_네이비',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(1173062),
#    {'스트리트': np.float32(0.6458),
#     '로맨틱': np.float32(0.1259),
#     '페미닌': np.float32(0.0703)},
#    '상의_색상_옐로우',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_없음',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(1107378),
#    {'스트리트': np.float32(0.6792),
#     '페미닌': np.float32(0.056),
#     '리조트': np.float32(0.0503)},
#    '상의_색상_그레이',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(899340),
#    {'스트리트': np.float32(0.6959),
#     '로맨틱': np.float32(0.0622),
#     '페미닌': np.float32(0.0557)},
#    '상의_색상_베이지',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_루즈'],
#   [np.int64(884830),
#    {'스트리트': np.float32(0.6882),
#     '페미닌': np.float32(0.0558),
#     '모던': np.float32(0.0525)},
#    '상의_색상_블랙',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_타이트'],
#   [np.int64(305108),
#    {'스트리트': np.float32(0.4055),
#     '페미닌': np.float32(0.0957),
#     '소피스트케이티드': np.float32(0.0932)},
#    '상의_색상_카키',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(1102961),
#    {'스트리트': np.float32(0.4915),
#     '페미닌': np.float32(0.0834),
#     '리조트': np.float32(0.0803)},
#    '상의_색상_브라운',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(938387),
#    {'스트리트': np.float32(0.7384),
#     '페미닌': np.float32(0.0476),
#     '리조트': np.float32(0.0441)},
#    '상의_색상_베이지',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_타이트'],
#   [np.int64(1152234),
#    {'스트리트': np.float32(0.5839),
#     '페미닌': np.float32(0.0753),
#     '리조트': np.float32(0.0631)},
#    '상의_색상_베이지',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(1166488),
#    {'스트리트': np.float32(0.6437),
#     '클래식': np.float32(0.065),
#     '페미닌': np.float32(0.0548)},
#    '상의_색상_화이트',
#    '상의_카테고리_셔츠',
#    '상의_옷깃_셔츠칼라',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(217038),
#    {'스트리트': np.float32(0.7041),
#     '페미닌': np.float32(0.0569),
#     '클래식': np.float32(0.043)},
#    '상의_색상_베이지',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_반팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(960617),
#    {'스트리트': np.float32(0.666),
#     '페미닌': np.float32(0.0569),
#     '로맨틱': np.float32(0.0523)},
#    '상의_색상_화이트',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_울/캐시미어',
#    '상의_핏_루즈'],
#   [np.int64(1187768),
#    {'스트리트': np.float32(0.5761),
#     '페미닌': np.float32(0.0807),
#     '로맨틱': np.float32(0.0601)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(1100646),
#    {'스트리트': np.float32(0.5818),
#     '페미닌': np.float32(0.0911),
#     '로맨틱': np.float32(0.0717)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_오버사이즈'],
#   [np.int64(707696),
#    {'스트리트': np.float32(0.5966),
#     '로맨틱': np.float32(0.0804),
#     '페미닌': np.float32(0.0684)},
#    '상의_색상_화이트',
#    '상의_카테고리_탑',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(598401),
#    {'스트리트': np.float32(0.6297),
#     '모던': np.float32(0.0573),
#     '페미닌': np.float32(0.0536)},
#    '상의_색상_블랙',
#    '상의_카테고리_탑',
#    '상의_소매기장_7부소매',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(665208),
#    {'스트리트': np.float32(0.4915),
#     '페미닌': np.float32(0.0834),
#     '리조트': np.float32(0.0803)},
#    '상의_색상_브라운',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(769938),
#    {'스트리트': np.float32(0.4905),
#     '페미닌': np.float32(0.0957),
#     '로맨틱': np.float32(0.0914)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_니트',
#    '상의_핏_오버사이즈'],
#   [np.int64(1237181),
#    {'스트리트': np.float32(0.6554),
#     '페미닌': np.float32(0.0717),
#     '로맨틱': np.float32(0.0595)},
#    '상의_색상_화이트',
#    '상의_소매기장_7부소매'],
#   [np.int64(1259829),
#    {'스트리트': np.float32(0.6338),
#     '로맨틱': np.float32(0.0786),
#     '페미닌': np.float32(0.0746)},
#    '상의_색상_베이지',
#    '상의_카테고리_탑',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(1341201),
#    {'스트리트': np.float32(0.5902),
#     '페미닌': np.float32(0.1035),
#     '로맨틱': np.float32(0.0805)},
#    '상의_색상_스카이블루',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_7부소매',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(874826),
#    {'스트리트': np.float32(0.6722),
#     '페미닌': np.float32(0.0575),
#     '로맨틱': np.float32(0.0373)},
#    '상의_색상_핑크',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_긴팔',
#    '상의_소재_시폰',
#    '상의_핏_노멀'],
#   [np.int64(233908),
#    {'스트리트': np.float32(0.9492),
#     '페미닌': np.float32(0.0143),
#     '클래식': np.float32(0.0108)},
#    '상의_색상_베이지',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_반팔',
#    '상의_소재_스판덱스',
#    '상의_핏_타이트'],
#   [np.int64(523134),
#    {'스트리트': np.float32(0.6033),
#     '페미닌': np.float32(0.0803),
#     '로맨틱': np.float32(0.0581)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(1163508),
#    {'스트리트': np.float32(0.6892),
#     '페미닌': np.float32(0.0618),
#     '로맨틱': np.float32(0.059)},
#    '상의_색상_블랙',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_루즈'],
#   [np.int64(488899),
#    {'스트리트': np.float32(0.6838),
#     '리조트': np.float32(0.0529),
#     '페미닌': np.float32(0.0478)},
#    '상의_색상_화이트',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(161142),
#    {'스트리트': np.float32(0.5359),
#     '페미닌': np.float32(0.1123),
#     '로맨틱': np.float32(0.0952)},
#    '상의_색상_레드',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(665660),
#    {'스트리트': np.float32(0.6676),
#     '리조트': np.float32(0.0579),
#     '페미닌': np.float32(0.0514)},
#    '상의_색상_베이지',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(982112),
#    {'스트리트': np.float32(0.5044),
#     '페미닌': np.float32(0.0961),
#     '컨트리': np.float32(0.0878)},
#    '상의_색상_블루',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(687882),
#    {'스트리트': np.float32(0.7776),
#     '리조트': np.float32(0.0335),
#     '스포티': np.float32(0.0327)},
#    '상의_색상_옐로우',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(1194858),
#    {'스트리트': np.float32(0.5792),
#     '페미닌': np.float32(0.0684),
#     '클래식': np.float32(0.067)},
#    '상의_색상_핑크',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(315725),
#    {'스트리트': np.float32(0.5728),
#     '페미닌': np.float32(0.0841),
#     '로맨틱': np.float32(0.0673)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(1021849),
#    {'스트리트': np.float32(0.5458),
#     '페미닌': np.float32(0.0935),
#     '로맨틱': np.float32(0.0905)},
#    '상의_색상_옐로우',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(146872),
#    {'스트리트': np.float32(0.7688),
#     '페미닌': np.float32(0.0427),
#     '모던': np.float32(0.0333)},
#    '상의_색상_화이트',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_긴팔',
#    '상의_소재_실크',
#    '상의_핏_노멀'],
#   [np.int64(1126240),
#    {'스트리트': np.float32(0.7227),
#     '클래식': np.float32(0.0525),
#     '리조트': np.float32(0.0435)},
#    '상의_색상_브라운',
#    '상의_카테고리_블라우스',
#    '상의_옷깃_셔츠칼라',
#    '상의_소매기장_7부소매',
#    '상의_소재_우븐'],
#   [np.int64(541557),
#    {'스트리트': np.float32(0.5651),
#     '페미닌': np.float32(0.0745),
#     '로맨틱': np.float32(0.0676)},
#    '상의_색상_베이지',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(260784),
#    {'스트리트': np.float32(0.6607),
#     '페미닌': np.float32(0.0669),
#     '리조트': np.float32(0.0389)},
#    '상의_색상_화이트',
#    '상의_카테고리_블라우스',
#    '상의_옷깃_테일러드칼라',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(850003),
#    {'스트리트': np.float32(0.4889),
#     '페미닌': np.float32(0.1139),
#     '소피스트케이티드': np.float32(0.073)},
#    '상의_색상_스카이블루',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(868645),
#    {'스트리트': np.float32(0.6099),
#     '페미닌': np.float32(0.0785),
#     '로맨틱': np.float32(0.054)},
#    '상의_색상_화이트',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_오버사이즈'],
#   [np.int64(857308),
#    {'스트리트': np.float32(0.4272),
#     '로맨틱': np.float32(0.1151),
#     '페미닌': np.float32(0.0702)},
#    '상의_색상_스카이블루',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_반팔',
#    '상의_소재_실크',
#    '상의_핏_루즈'],
#   [np.int64(856856),
#    {'스트리트': np.float32(0.7547),
#     '클래식': np.float32(0.0682),
#     '로맨틱': np.float32(0.0452)},
#    '상의_색상_카키',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_소재_니트',
#    '상의_핏_루즈'],
#   [np.int64(967052),
#    {'스트리트': np.float32(0.6847),
#     '페미닌': np.float32(0.0547),
#     '로맨틱': np.float32(0.039)},
#    '상의_색상_베이지',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(1017769),
#    {'스트리트': np.float32(0.6938),
#     '페미닌': np.float32(0.0529),
#     '모던': np.float32(0.0418)},
#    '상의_색상_핑크',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_긴팔',
#    '상의_소재_실크',
#    '상의_핏_노멀'],
#   [np.int64(43229),
#    {'스트리트': np.float32(0.6758),
#     '페미닌': np.float32(0.0557),
#     '로맨틱': np.float32(0.0526)},
#    '상의_카테고리_탑',
#    '상의_소재_저지',
#    '상의_핏_타이트'],
#   [np.int64(794733),
#    {'스트리트': np.float32(0.6318),
#     '페미닌': np.float32(0.0704),
#     '리조트': np.float32(0.0636)},
#    '상의_색상_블루',
#    '상의_소매기장_반팔'],
#   [np.int64(1135164),
#    {'스트리트': np.float32(0.5904),
#     '페미닌': np.float32(0.0951),
#     '클래식': np.float32(0.0491)},
#    '상의_색상_블랙',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(618746),
#    {'스트리트': np.float32(0.6631),
#     '페미닌': np.float32(0.0604),
#     '로맨틱': np.float32(0.0558)},
#    '상의_색상_레드',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(1299673),
#    {'스트리트': np.float32(0.6079),
#     '페미닌': np.float32(0.1193),
#     '로맨틱': np.float32(0.0572)},
#    '상의_색상_블랙',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_민소매',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(568789),
#    {'스트리트': np.float32(0.5989),
#     '페미닌': np.float32(0.078),
#     '리조트': np.float32(0.0621)},
#    '상의_카테고리_티셔츠',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(504555),
#    {'스트리트': np.float32(0.6281),
#     '로맨틱': np.float32(0.078),
#     '페미닌': np.float32(0.0653)},
#    '상의_색상_옐로우',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(347382),
#    {'스트리트': np.float32(0.6524),
#     '페미닌': np.float32(0.0552),
#     '리조트': np.float32(0.0549)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_없음',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(1175572),
#    {'스트리트': np.float32(0.5856),
#     '로맨틱': np.float32(0.0596),
#     '페미닌': np.float32(0.0561)},
#    '상의_색상_핑크',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_7부소매',
#    '상의_소재_시폰',
#    '상의_핏_노멀'],
#   [np.int64(1007834),
#    {'스트리트': np.float32(0.5728),
#     '페미닌': np.float32(0.0841),
#     '로맨틱': np.float32(0.0673)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(475136),
#    {'스트리트': np.float32(0.4627),
#     '리조트': np.float32(0.1597),
#     '컨트리': np.float32(0.0945)},
#    '상의_카테고리_셔츠',
#    '상의_옷깃_테일러드칼라',
#    '상의_소재_실크',
#    '상의_핏_노멀'],
#   [np.int64(199772),
#    {'스트리트': np.float32(0.6332),
#     '페미닌': np.float32(0.079),
#     '로맨틱': np.float32(0.0521)},
#    '상의_색상_네이비',
#    '상의_소매기장_긴팔'],
#   [np.int64(1191105),
#    {'스트리트': np.float32(0.6033),
#     '페미닌': np.float32(0.0803),
#     '로맨틱': np.float32(0.0581)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(540084),
#    {'스트리트': np.float32(0.4068),
#     '로맨틱': np.float32(0.0971),
#     '페미닌': np.float32(0.0829)},
#    '상의_색상_민트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(1162565),
#    {'스트리트': np.float32(0.606),
#     '리조트': np.float32(0.1038),
#     '로맨틱': np.float32(0.0549)},
#    '상의_색상_와인',
#    '상의_카테고리_셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(10055),
#    {'스트리트': np.float32(0.7175),
#     '컨트리': np.float32(0.0381),
#     '페미닌': np.float32(0.0369)},
#    '상의_색상_블랙',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_핏_타이트'],
#   [np.int64(1123861),
#    {'스트리트': np.float32(0.7512),
#     '컨트리': np.float32(0.0453),
#     '로맨틱': np.float32(0.0411)},
#    '상의_색상_베이지',
#    '상의_카테고리_블라우스',
#    '상의_옷깃_밴드칼라',
#    '상의_소매기장_긴팔',
#    '상의_소재_시폰',
#    '상의_핏_노멀'],
#   [np.int64(854800),
#    {'스트리트': np.float32(0.4272),
#     '로맨틱': np.float32(0.1151),
#     '페미닌': np.float32(0.0702)},
#    '상의_색상_스카이블루',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_반팔',
#    '상의_소재_실크',
#    '상의_핏_루즈'],
#   [np.int64(794322),
#    {'스트리트': np.float32(0.5287),
#     '페미닌': np.float32(0.1862),
#     '모던': np.float32(0.0628)},
#    '상의_색상_핑크',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_캡',
#    '상의_소재_우븐',
#    '상의_핏_타이트'],
#   [np.int64(504032),
#    {'스트리트': np.float32(0.5677),
#     '로맨틱': np.float32(0.0827),
#     '페미닌': np.float32(0.0794)},
#    '상의_색상_브라운',
#    '상의_카테고리_블라우스',
#    '상의_옷깃_보우칼라',
#    '상의_소매기장_긴팔',
#    '상의_소재_시폰',
#    '상의_핏_루즈'],
#   [np.int64(1037532),
#    {'스트리트': np.float32(0.5487),
#     '로맨틱': np.float32(0.1069),
#     '페미닌': np.float32(0.0933)},
#    '상의_색상_화이트',
#    '상의_카테고리_탑',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(1057540),
#    {'스트리트': np.float32(0.592),
#     '페미닌': np.float32(0.0714),
#     '리조트': np.float32(0.0568)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_없음',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(978845),
#    {'스트리트': np.float32(0.5886),
#     '페미닌': np.float32(0.1075),
#     '리조트': np.float32(0.0557)},
#    '상의_색상_블루',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(112019),
#    {'스트리트': np.float32(0.6618),
#     '모던': np.float32(0.0656),
#     '리조트': np.float32(0.0636)},
#    '상의_색상_스카이블루',
#    '상의_카테고리_탑',
#    '상의_소매기장_민소매',
#    '상의_소재_니트',
#    '상의_핏_타이트'],
#   [np.int64(157563),
#    {'스트리트': np.float32(0.614),
#     '페미닌': np.float32(0.079),
#     '로맨틱': np.float32(0.0549)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_노멀'],
#   [np.int64(723624),
#    {'스트리트': np.float32(0.908),
#     '소피스트케이티드': np.float32(0.0165),
#     '리조트': np.float32(0.0154)},
#    '상의_색상_브라운',
#    '상의_카테고리_블라우스',
#    '상의_옷깃_밴드칼라',
#    '상의_소매기장_긴팔',
#    '상의_소재_스웨이드',
#    '상의_핏_루즈'],
#   [np.int64(498345),
#    {'스트리트': np.float32(0.601),
#     '페미닌': np.float32(0.1096),
#     '로맨틱': np.float32(0.0857)},
#    '상의_색상_옐로우',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(1091726),
#    {'스트리트': np.float32(0.5728),
#     '페미닌': np.float32(0.0841),
#     '로맨틱': np.float32(0.0673)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(524972),
#    {'스트리트': np.float32(0.7961),
#     '페미닌': np.float32(0.0493),
#     '모던': np.float32(0.041)},
#    '상의_색상_옐로우',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_메시',
#    '상의_핏_루즈'],
#   [np.int64(299032),
#    {'스트리트': np.float32(0.598),
#     '페미닌': np.float32(0.0987),
#     '리조트': np.float32(0.0518)},
#    '상의_색상_화이트',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(618516),
#    {'스트리트': np.float32(0.7426),
#     '리조트': np.float32(0.049),
#     '페미닌': np.float32(0.0375)},
#    '상의_색상_민트',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(817331),
#    {'스트리트': np.float32(0.5761),
#     '페미닌': np.float32(0.0807),
#     '로맨틱': np.float32(0.0601)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(1141231),
#    {'스트리트': np.float32(0.6631),
#     '모던': np.float32(0.065),
#     '페미닌': np.float32(0.0602)},
#    '상의_색상_화이트',
#    '상의_카테고리_탑',
#    '상의_소매기장_없음',
#    '상의_소재_니트',
#    '상의_핏_타이트'],
#   [np.int64(314398),
#    {'스트리트': np.float32(0.6372),
#     '페미닌': np.float32(0.0623),
#     '로맨틱': np.float32(0.059)},
#    '상의_색상_화이트',
#    '상의_소매기장_긴팔'],
#   [np.int64(998651),
#    {'스트리트': np.float32(0.6659),
#     '페미닌': np.float32(0.0644),
#     '로맨틱': np.float32(0.0509)},
#    '상의_색상_베이지',
#    '상의_소매기장_긴팔'],
#   [np.int64(159310),
#    {'스트리트': np.float32(0.6554),
#     '페미닌': np.float32(0.0717),
#     '로맨틱': np.float32(0.0595)},
#    '상의_색상_화이트',
#    '상의_소매기장_7부소매'],
#   [np.int64(750461),
#    {'스트리트': np.float32(0.6507),
#     '페미닌': np.float32(0.0663),
#     '로맨틱': np.float32(0.0492)},
#    '상의_색상_화이트',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_긴팔',
#    '상의_소재_시폰',
#    '상의_핏_노멀'],
#   [np.int64(1325561),
#    {'스트리트': np.float32(0.7972),
#     '리조트': np.float32(0.0545),
#     '페미닌': np.float32(0.0311)},
#    '상의_색상_네이비',
#    '상의_카테고리_탑',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_타이트'],
#   [np.int64(1176292),
#    {'스트리트': np.float32(0.5621),
#     '로맨틱': np.float32(0.0809),
#     '페미닌': np.float32(0.0754)},
#    '상의_색상_레드',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(742162),
#    {'스트리트': np.float32(0.5761),
#     '페미닌': np.float32(0.0807),
#     '로맨틱': np.float32(0.0601)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(1234695),
#    {'스트리트': np.float32(0.5889),
#     '페미닌': np.float32(0.0766),
#     '로맨틱': np.float32(0.0597)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(1293677),
#    {'스트리트': np.float32(0.6829),
#     '로맨틱': np.float32(0.0841),
#     '페미닌': np.float32(0.0485)},
#    '상의_색상_베이지',
#    '상의_카테고리_탑',
#    '상의_소매기장_민소매',
#    '상의_소재_린넨',
#    '상의_핏_루즈'],
#   [np.int64(1106578),
#    {'스트리트': np.float32(0.5866),
#     '페미닌': np.float32(0.1244),
#     '로맨틱': np.float32(0.0659)},
#    '상의_색상_그린',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(41267),
#    {'스트리트': np.float32(0.645),
#     '페미닌': np.float32(0.0625),
#     '모던': np.float32(0.056)},
#    '상의_색상_화이트',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_민소매',
#    '상의_소재_니트',
#    '상의_핏_타이트'],
#   [np.int64(1145672),
#    {'스트리트': np.float32(0.6485),
#     '페미닌': np.float32(0.0802),
#     '로맨틱': np.float32(0.0672)},
#    '상의_색상_오렌지',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(411308),
#    {'스트리트': np.float32(0.6804),
#     '리조트': np.float32(0.0581),
#     '클래식': np.float32(0.0458)},
#    '상의_색상_오렌지',
#    '상의_카테고리_셔츠',
#    '상의_옷깃_셔츠칼라',
#    '상의_소매기장_7부소매',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(828493),
#    {'스트리트': np.float32(0.522),
#     '페미닌': np.float32(0.1168),
#     '로맨틱': np.float32(0.1024)},
#    '상의_색상_레드',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_핏_노멀'],
#   [np.int64(256399),
#    {'스트리트': np.float32(0.6613),
#     '로맨틱': np.float32(0.0907),
#     '페미닌': np.float32(0.0565)},
#    '상의_색상_그레이',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(1251295),
#    {'스트리트': np.float32(0.3371),
#     '클래식': np.float32(0.1509),
#     '리조트': np.float32(0.133)},
#    '상의_색상_그레이',
#    '상의_카테고리_셔츠',
#    '상의_옷깃_밴드칼라',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(583599),
#    {'스트리트': np.float32(0.6507),
#     '클래식': np.float32(0.0703),
#     '페미닌': np.float32(0.061)},
#    '상의_색상_블랙',
#    '상의_카테고리_탑',
#    '상의_소매기장_긴팔',
#    '상의_소재_울/캐시미어',
#    '상의_핏_루즈'],
#   [np.int64(970738),
#    {'스트리트': np.float32(0.6311),
#     '페미닌': np.float32(0.0835),
#     '로맨틱': np.float32(0.0717)},
#    '상의_색상_그린',
#    '상의_카테고리_블라우스',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(814318),
#    {'스트리트': np.float32(0.5837),
#     '페미닌': np.float32(0.0891),
#     '컨트리': np.float32(0.0566)},
#    '상의_색상_라벤더',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_7부소매',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(788047),
#    {'스트리트': np.float32(0.6777),
#     '페미닌': np.float32(0.0842),
#     '로맨틱': np.float32(0.046)},
#    '상의_카테고리_티셔츠',
#    '상의_핏_노멀'],
#   [np.int64(618957),
#    {'스트리트': np.float32(0.6251),
#     '페미닌': np.float32(0.0908),
#     '로맨틱': np.float32(0.0783)},
#    '상의_색상_블랙',
#    '상의_카테고리_블라우스',
#    '상의_옷깃_차이나칼라',
#    '상의_소매기장_긴팔',
#    '상의_소재_시폰',
#    '상의_핏_루즈'],
#   [np.int64(521929),
#    {'스트리트': np.float32(0.5447),
#     '스포티': np.float32(0.0759),
#     '젠더리스': np.float32(0.0619)},
#    '상의_색상_라벤더',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_타이트'],
#   [np.int64(966670),
#    {'스트리트': np.float32(0.6959),
#     '로맨틱': np.float32(0.0622),
#     '페미닌': np.float32(0.0557)},
#    '상의_색상_베이지',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_루즈'],
#   [np.int64(172625),
#    {'스트리트': np.float32(0.6698),
#     '로맨틱': np.float32(0.0612),
#     '클래식': np.float32(0.0432)},
#    '상의_색상_네이비',
#    '상의_카테고리_블라우스',
#    '상의_옷깃_셔츠칼라',
#    '상의_소매기장_반팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(1061385),
#    {'스트리트': np.float32(0.4931),
#     '컨트리': np.float32(0.1075),
#     '리조트': np.float32(0.1029)},
#    '상의_색상_화이트',
#    '상의_카테고리_탑',
#    '상의_소매기장_없음',
#    '상의_소재_플리스'],
#   [np.int64(596673),
#    {'스트리트': np.float32(0.6182),
#     '로맨틱': np.float32(0.0792),
#     '페미닌': np.float32(0.0704)},
#    '상의_색상_블랙',
#    '상의_카테고리_탑',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(1005633),
#    {'스트리트': np.float32(0.5457),
#     '페미닌': np.float32(0.1817),
#     '로맨틱': np.float32(0.0871)},
#    '상의_색상_옐로우',
#    '상의_카테고리_후드티',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(819482),
#    {'스트리트': np.float32(0.6838),
#     '리조트': np.float32(0.0529),
#     '페미닌': np.float32(0.0478)},
#    '상의_색상_화이트',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(964957),
#    {'스트리트': np.float32(0.592),
#     '페미닌': np.float32(0.0714),
#     '리조트': np.float32(0.0568)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_없음',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(769528),
#    {'스트리트': np.float32(0.6642),
#     '페미닌': np.float32(0.0678),
#     '리조트': np.float32(0.0539)},
#    '상의_카테고리_티셔츠',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(1209326),
#    {'스트리트': np.float32(0.541),
#     '페미닌': np.float32(0.1266),
#     '로맨틱': np.float32(0.0763)},
#    '상의_색상_옐로우',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(684647),
#    {'스트리트': np.float32(0.5636),
#     '페미닌': np.float32(0.086),
#     '로맨틱': np.float32(0.0752)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_오버사이즈'],
#   [np.int64(664064),
#    {'스트리트': np.float32(0.5941),
#     '페미닌': np.float32(0.0889),
#     '모던': np.float32(0.062)},
#    '상의_색상_블랙',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(1183449),
#    {'스트리트': np.float32(0.5359),
#     '페미닌': np.float32(0.1123),
#     '로맨틱': np.float32(0.0952)},
#    '상의_색상_레드',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(149126),
#    {'스트리트': np.float32(0.6857),
#     '페미닌': np.float32(0.0508),
#     '로맨틱': np.float32(0.0507)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_없음',
#    '상의_소재_저지'],
#   [np.int64(1079965),
#    {'스트리트': np.float32(0.5424),
#     '페미닌': np.float32(0.0924),
#     '리조트': np.float32(0.0696)},
#    '상의_색상_와인',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_7부소매',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(802079),
#    {'스트리트': np.float32(0.7757),
#     '페미닌': np.float32(0.0398),
#     '로맨틱': np.float32(0.0359)},
#    '상의_색상_블랙',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(1260881),
#    {'스트리트': np.float32(0.558),
#     '로맨틱': np.float32(0.1148),
#     '페미닌': np.float32(0.0772)},
#    '상의_색상_화이트',
#    '상의_카테고리_탑',
#    '상의_소매기장_긴팔',
#    '상의_소재_저지',
#    '상의_핏_루즈'],
#   [np.int64(752133),
#    {'스트리트': np.float32(0.7816),
#     '페미닌': np.float32(0.035),
#     '모던': np.float32(0.0317)},
#    '상의_색상_핑크',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_긴팔',
#    '상의_소재_울/캐시미어',
#    '상의_핏_노멀'],
#   [np.int64(1297962),
#    {'스트리트': np.float32(0.6744),
#     '페미닌': np.float32(0.0668),
#     '리조트': np.float32(0.0484)},
#    '상의_색상_화이트',
#    '상의_소매기장_없음'],
#   [np.int64(1267699),
#    {'스트리트': np.float32(0.6033),
#     '페미닌': np.float32(0.0803),
#     '로맨틱': np.float32(0.0581)},
#    '상의_색상_화이트',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(1132912),
#    {'스트리트': np.float32(0.6854),
#     '페미닌': np.float32(0.0572),
#     '리조트': np.float32(0.0463)},
#    '상의_색상_오렌지',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_긴팔',
#    '상의_소재_우븐',
#    '상의_핏_루즈'],
#   [np.int64(300567),
#    {'스트리트': np.float32(0.7108),
#     '페미닌': np.float32(0.0561),
#     '로맨틱': np.float32(0.0519)},
#    '상의_색상_블랙',
#    '상의_카테고리_니트웨어',
#    '상의_소매기장_민소매',
#    '상의_소재_니트',
#    '상의_핏_노멀'],
#   [np.int64(1305430),
#    {'스트리트': np.float32(0.6273),
#     '페미닌': np.float32(0.0809),
#     '로맨틱': np.float32(0.0542)},
#    '상의_색상_블랙',
#    '상의_카테고리_티셔츠',
#    '상의_소매기장_반팔',
#    '상의_소재_저지',
#    '상의_핏_노멀'],
#   [np.int64(273501),
#    {'스트리트': np.float32(0.6668),
#     '리조트': np.float32(0.0702),
#     '페미닌': np.float32(0.0565)},
#    '상의_색상_블랙',
#    '상의_카테고리_셔츠',
#    '상의_옷깃_셔츠칼라',
#    '상의_소매기장_7부소매',
#    '상의_소재_우븐',
#    '상의_핏_노멀']],
#  '원피스': [[np.int64(1202131),
#    {'스트리트': np.float32(0.6083),
#     '페미닌': np.float32(0.0668),
#     '로맨틱': np.float32(0.0615)},
#    '원피스_기장_미니',
#    '원피스_색상_블랙',
#    '원피스_카테고리_드레스',
#    '원피스_소매기장_민소매',
#    '원피스_소재_우븐',
#    '원피스_핏_노멀'],
#   [np.int64(1223964),
#    {'스트리트': np.float32(0.6839),
#     '페미닌': np.float32(0.0556),
#     '클래식': np.float32(0.052)},
#    '원피스_기장_미디',
#    '원피스_색상_그레이',
#    '원피스_카테고리_드레스',
#    '원피스_소매기장_긴팔',
#    '원피스_소재_우븐',
#    '원피스_핏_루즈'],
#   [np.int64(998731),
#    {'리조트': np.float32(0.309),
#     '로맨틱': np.float32(0.2558),
#     '스트리트': np.float32(0.1434)},
#    '원피스_기장_미니',
#    '원피스_색상_브라운',
#    '원피스_카테고리_드레스',
#    '원피스_소매기장_민소매',
#    '원피스_소재_스웨이드',
#    '원피스_핏_노멀'],
#   [np.int64(268454),
#    {'스트리트': np.float32(0.6015),
#     '클래식': np.float32(0.1341),
#     '리조트': np.float32(0.0807)},
#    '원피스_기장_발목',
#    '원피스_색상_스카이블루',
#    '원피스_카테고리_점프수트',
#    '원피스_소매기장_민소매',
#    '원피스_소재_데님',
#    '원피스_핏_루즈'],
#   [np.int64(705888),
#    {'스트리트': np.float32(0.613),
#     '컨트리': np.float32(0.0888),
#     '모던': np.float32(0.067)},
#    '원피스_기장_미니',
#    '원피스_카테고리_드레스',
#    '원피스_옷깃_테일러드칼라',
#    '원피스_소재_우븐',
#    '원피스_핏_타이트'],
#   [np.int64(568789),
#    {'스트리트': np.float32(0.5548),
#     '페미닌': np.float32(0.0928),
#     '로맨틱': np.float32(0.0656)},
#    '원피스_색상_네이비',
#    '원피스_소매기장_긴팔'],
#   [np.int64(475136),
#    {'스트리트': np.float32(0.8144),
#     '페미닌': np.float32(0.0567),
#     '소피스트케이티드': np.float32(0.0457)},
#    '원피스_기장_발목',
#    '원피스_색상_베이지',
#    '원피스_카테고리_드레스',
#    '원피스_소매기장_민소매',
#    '원피스_소재_실크',
#    '원피스_핏_노멀'],
#   [np.int64(904555),
#    {'스트리트': np.float32(0.6835),
#     '클래식': np.float32(0.0493),
#     '컨트리': np.float32(0.045)},
#    '원피스_기장_미니',
#    '원피스_색상_네이비',
#    '원피스_카테고리_드레스',
#    '원피스_소매기장_민소매',
#    '원피스_소재_우븐',
#    '원피스_핏_타이트'],
#   [np.int64(1191105),
#    {'스트리트': np.float32(0.6438),
#     '로맨틱': np.float32(0.0828),
#     '페미닌': np.float32(0.0627)},
#    '원피스_기장_미디',
#    '원피스_색상_핑크',
#    '원피스_카테고리_드레스',
#    '원피스_소매기장_민소매',
#    '원피스_소재_우븐',
#    '원피스_핏_루즈'],
#   [np.int64(322042),
#    {'스트리트': np.float32(0.7283),
#     '로맨틱': np.float32(0.0488),
#     '페미닌': np.float32(0.0471)},
#    '원피스_기장_미디',
#    '원피스_카테고리_드레스',
#    '원피스_소재_우븐',
#    '원피스_핏_루즈'],
#   [np.int64(1221344),
#    {'스트리트': np.float32(0.6318),
#     '페미닌': np.float32(0.058),
#     '로맨틱': np.float32(0.0539)},
#    '원피스_기장_니렝스',
#    '원피스_색상_핑크',
#    '원피스_카테고리_드레스',
#    '원피스_소매기장_반팔',
#    '원피스_소재_우븐',
#    '원피스_핏_노멀']],
#  '하의': [[np.int64(1216062),
#    {'스트리트': np.float32(0.6615),
#     '모던': np.float32(0.0856),
#     '리조트': np.float32(0.0504)},
#    '하의_기장_니렝스',
#    '하의_색상_옐로우',
#    '하의_카테고리_스커트',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(871706),
#    {'스트리트': np.float32(0.6706),
#     '페미닌': np.float32(0.0513),
#     '리조트': np.float32(0.0486)},
#    '하의_기장_발목',
#    '하의_색상_베이지',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(741110),
#    {'스트리트': np.float32(0.6662),
#     '페미닌': np.float32(0.0522),
#     '클래식': np.float32(0.0503)},
#    '하의_기장_미니',
#    '하의_색상_베이지',
#    '하의_카테고리_스커트',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(505625),
#    {'스트리트': np.float32(0.694),
#     '페미닌': np.float32(0.0459),
#     '소피스트케이티드': np.float32(0.0355)},
#    '하의_기장_미디',
#    '하의_색상_민트',
#    '하의_카테고리_스커트',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(406557),
#    {'스트리트': np.float32(0.63),
#     '페미닌': np.float32(0.0715),
#     '로맨틱': np.float32(0.06)},
#    '하의_기장_발목',
#    '하의_색상_블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_스키니'],
#   [np.int64(874986),
#    {'스트리트': np.float32(0.5943),
# ...
#    '하의_기장_발목',
#    '하의_색상_블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_루즈'],
#   [np.int64(260784),
#    {'스트리트': np.float32(0.6438),
#     '페미닌': np.float32(0.0683),
#     '로맨틱': np.float32(0.0561)},
#    '하의_색상_베이지',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐'],
#   [np.int64(850003),
#    {'스트리트': np.float32(0.6307),
#     '페미닌': np.float32(0.0611),
#     '로맨틱': np.float32(0.054)},
#    '하의_기장_발목',
#    '하의_색상_화이트',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(868645),
#    {'스트리트': np.float32(0.6375),
#     '페미닌': np.float32(0.0718),
#     '로맨틱': np.float32(0.0499)},
#    '하의_기장_발목',
#    '하의_색상_스카이블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_스키니'],
#   [np.int64(857308),
#    {'스트리트': np.float32(0.6088),
#     '페미닌': np.float32(0.0725),
#     '리조트': np.float32(0.0552)},
#    '하의_기장_발목',
#    '하의_색상_블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(856856),
#    {'스트리트': np.float32(0.7061),
#     '페미닌': np.float32(0.0535),
#     '클래식': np.float32(0.0506)},
#    '하의_기장_발목',
#    '하의_색상_베이지',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_루즈'],
#   [np.int64(967052),
#    {'스트리트': np.float32(0.6147),
#     '페미닌': np.float32(0.0668),
#     '로맨틱': np.float32(0.0554)},
#    '하의_기장_발목',
#    '하의_색상_네이비',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(1017769),
#    {'스트리트': np.float32(0.6192),
#     '페미닌': np.float32(0.0643),
#     '리조트': np.float32(0.0588)},
#    '하의_기장_맥시',
#    '하의_색상_블랙',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_와이드'],
#   [np.int64(43229),
#    {'스트리트': np.float32(0.6262),
#     '페미닌': np.float32(0.0669),
#     '소피스트케이티드': np.float32(0.0524)},
#    '하의_기장_미니',
#    '하의_카테고리_팬츠',
#    '하의_소재_린넨',
#    '하의_핏_와이드'],
#   [np.int64(794733),
#    {'스트리트': np.float32(0.44),
#     '페미닌': np.float32(0.1002),
#     '로맨틱': np.float32(0.0982)},
#    '하의_기장_미디',
#    '하의_색상_화이트',
#    '하의_카테고리_스커트',
#    '하의_소재_우븐',
#    '하의_핏_와이드'],
#   [np.int64(1135164),
#    {'스트리트': np.float32(0.6878),
#     '리조트': np.float32(0.0471),
#     '페미닌': np.float32(0.047)},
#    '하의_기장_발목',
#    '하의_색상_카키',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(618746),
#    {'스트리트': np.float32(0.3419),
#     '리조트': np.float32(0.176),
#     '페미닌': np.float32(0.109)},
#    '하의_카테고리_청바지'],
#   [np.int64(1299673),
#    {'스트리트': np.float32(0.5613),
#     '페미닌': np.float32(0.0896),
#     '로맨틱': np.float32(0.0622)},
#    '하의_기장_미니',
#    '하의_색상_스카이블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(568789),
#    {'스트리트': np.float32(0.6114),
#     '로맨틱': np.float32(0.0615),
#     '페미닌': np.float32(0.0604)},
#    '하의_기장_발목',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_스키니'],
#   [np.int64(504555),
#    {'스트리트': np.float32(0.6767),
#     '페미닌': np.float32(0.0562),
#     '로맨틱': np.float32(0.0453)},
#    '하의_기장_미니',
#    '하의_색상_블랙',
#    '하의_카테고리_스커트',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(1175572),
#    {'스트리트': np.float32(0.4077),
#     '페미닌': np.float32(0.1491),
#     '소피스트케이티드': np.float32(0.1192)},
#    '하의_기장_발목',
#    '하의_색상_스카이블루',
#    '하의_카테고리_청바지',
#    '하의_소재_린넨',
#    '하의_핏_노멀'],
#   [np.int64(1007834),
#    {'스트리트': np.float32(0.6194),
#     '페미닌': np.float32(0.0696),
#     '로맨틱': np.float32(0.0571)},
#    '하의_기장_발목',
#    '하의_색상_블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_와이드'],
#   [np.int64(540084),
#    {'스트리트': np.float32(0.6136),
#     '페미닌': np.float32(0.0674),
#     '로맨틱': np.float32(0.0536)},
#    '하의_기장_발목',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(1162565),
#    {'스트리트': np.float32(0.4547),
#     '클래식': np.float32(0.107),
#     '페미닌': np.float32(0.0873)},
#    '하의_기장_미니',
#    '하의_색상_브라운',
#    '하의_카테고리_스커트',
#    '하의_소재_코듀로이',
#    '하의_핏_노멀'],
#   [np.int64(10055),
#    {'스트리트': np.float32(0.5954),
#     '페미닌': np.float32(0.0783),
#     '로맨틱': np.float32(0.0627)},
#    '하의_기장_발목',
#    '하의_색상_네이비',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_스키니'],
#   [np.int64(1123861),
#    {'스트리트': np.float32(0.63),
#     '페미닌': np.float32(0.0715),
#     '로맨틱': np.float32(0.06)},
#    '하의_기장_발목',
#    '하의_색상_블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_스키니'],
#   [np.int64(854800),
#    {'스트리트': np.float32(0.5984),
#     '페미닌': np.float32(0.0799),
#     '로맨틱': np.float32(0.0695)},
#    '하의_색상_화이트'],
#   [np.int64(794322),
#    {'스트리트': np.float32(0.425),
#     '페미닌': np.float32(0.1744),
#     '로맨틱': np.float32(0.1068)},
#    '하의_기장_미디',
#    '하의_색상_블루',
#    '하의_카테고리_스커트',
#    '하의_소재_우븐',
#    '하의_핏_와이드'],
#   [np.int64(504032),
#    {'스트리트': np.float32(0.44),
#     '페미닌': np.float32(0.1002),
#     '로맨틱': np.float32(0.0982)},
#    '하의_기장_미디',
#    '하의_색상_화이트',
#    '하의_카테고리_스커트',
#    '하의_소재_우븐',
#    '하의_핏_와이드'],
#   [np.int64(1037532),
#    {'스트리트': np.float32(0.6147),
#     '페미닌': np.float32(0.0668),
#     '로맨틱': np.float32(0.0554)},
#    '하의_기장_발목',
#    '하의_색상_네이비',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(1057540),
#    {'스트리트': np.float32(0.6147),
#     '페미닌': np.float32(0.0668),
#     '로맨틱': np.float32(0.0554)},
#    '하의_기장_발목',
#    '하의_색상_네이비',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(978845),
#    {'스트리트': np.float32(0.6398),
#     '리조트': np.float32(0.0645),
#     '페미닌': np.float32(0.0555)},
#    '하의_기장_발목',
#    '하의_색상_블랙',
#    '하의_카테고리_팬츠',
#    '하의_소재_니트',
#    '하의_핏_노멀'],
#   [np.int64(112019),
#    {'스트리트': np.float32(0.6206),
#     '모던': np.float32(0.0775),
#     '페미닌': np.float32(0.0672)},
#    '하의_기장_니렝스',
#    '하의_색상_스카이블루',
#    '하의_카테고리_스커트',
#    '하의_소재_니트',
#    '하의_핏_스키니'],
#   [np.int64(157563),
#    {'스트리트': np.float32(0.6401),
#     '페미닌': np.float32(0.0558),
#     '로맨틱': np.float32(0.0554)},
#    '하의_기장_미디',
#    '하의_색상_블랙',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(723624),
#    {'스트리트': np.float32(0.5736),
#     '소피스트케이티드': np.float32(0.0723),
#     '모던': np.float32(0.0649)},
#    '하의_기장_미니',
#    '하의_색상_그레이',
#    '하의_카테고리_스커트',
#    '하의_소재_트위드',
#    '하의_핏_노멀'],
#   [np.int64(498345),
#    {'스트리트': np.float32(0.6113),
#     '페미닌': np.float32(0.0653),
#     '로맨틱': np.float32(0.0582)},
#    '하의_기장_발목',
#    '하의_색상_스카이블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(1091726),
#    {'스트리트': np.float32(0.6469),
#     '페미닌': np.float32(0.0585),
#     '로맨틱': np.float32(0.0526)},
#    '하의_기장_발목',
#    '하의_색상_블랙',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_와이드'],
#   [np.int64(524972),
#    {'스트리트': np.float32(0.5613),
#     '페미닌': np.float32(0.0896),
#     '로맨틱': np.float32(0.0622)},
#    '하의_기장_미니',
#    '하의_색상_스카이블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(299032),
#    {'스트리트': np.float32(0.576),
#     '로맨틱': np.float32(0.0626),
#     '리조트': np.float32(0.059)},
#    '하의_기장_미디',
#    '하의_색상_핑크',
#    '하의_카테고리_스커트',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(618516),
#    {'스트리트': np.float32(0.7007),
#     '페미닌': np.float32(0.0529),
#     '로맨틱': np.float32(0.0425)},
#    '하의_기장_발목',
#    '하의_색상_블랙',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(817331),
#    {'로맨틱': np.float32(0.3803),
#     '스트리트': np.float32(0.2786),
#     '페미닌': np.float32(0.1032)},
#    '하의_기장_니렝스',
#    '하의_색상_블루',
#    '하의_카테고리_스커트',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(1141231),
#    {'스트리트': np.float32(0.619),
#     '페미닌': np.float32(0.1151),
#     '로맨틱': np.float32(0.0364)},
#    '하의_기장_미니',
#    '하의_색상_베이지',
#    '하의_카테고리_스커트',
#    '하의_소재_니트',
#    '하의_핏_노멀'],
#   [np.int64(314398),
#    {'스트리트': np.float32(0.6134),
#     '페미닌': np.float32(0.075),
#     '로맨틱': np.float32(0.0579)},
#    '하의_색상_블랙'],
#   [np.int64(998651),
#    {'스트리트': np.float32(0.5908),
#     '페미닌': np.float32(0.0877),
#     '모던': np.float32(0.0866)},
#    '하의_기장_미니',
#    '하의_색상_블랙',
#    '하의_카테고리_스커트',
#    '하의_소재_가죽',
#    '하의_핏_노멀'],
#   [np.int64(159310),
#    {'스트리트': np.float32(0.6033),
#     '로맨틱': np.float32(0.0912),
#     '리조트': np.float32(0.0879)},
#    '하의_기장_미디',
#    '하의_색상_그레이',
#    '하의_카테고리_팬츠',
#    '하의_소재_린넨',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(750461),
#    {'스트리트': np.float32(0.6304),
#     '페미닌': np.float32(0.0692),
#     '리조트': np.float32(0.0524)},
#    '하의_기장_발목',
#    '하의_색상_스카이블루',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_와이드'],
#   [np.int64(1325561),
#    {'스트리트': np.float32(0.5806),
#     '페미닌': np.float32(0.0839),
#     '로맨틱': np.float32(0.0769)},
#    '하의_색상_베이지'],
#   [np.int64(1176292),
#    {'스트리트': np.float32(0.693),
#     '페미닌': np.float32(0.0491),
#     '로맨틱': np.float32(0.0489)},
#    '하의_기장_미니',
#    '하의_색상_스카이블루',
#    '하의_카테고리_스커트',
#    '하의_소재_데님',
#    '하의_핏_스키니'],
#   [np.int64(742162),
#    {'스트리트': np.float32(0.651),
#     '페미닌': np.float32(0.0707),
#     '클래식': np.float32(0.0703)},
#    '하의_기장_발목',
#    '하의_색상_카키',
#    '하의_카테고리_팬츠',
#    '하의_소재_울/캐시미어',
#    '하의_핏_노멀'],
#   [np.int64(1234695),
#    {'스트리트': np.float32(0.6077),
#     '로맨틱': np.float32(0.0963),
#     '페미닌': np.float32(0.0758)},
#    '하의_기장_미니',
#    '하의_색상_블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_루즈'],
#   [np.int64(1293677),
#    {'스트리트': np.float32(0.5311),
#     '클래식': np.float32(0.0823),
#     '페미닌': np.float32(0.0771)},
#    '하의_기장_미니',
#    '하의_색상_브라운',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_와이드'],
#   [np.int64(1106578),
#    {'스트리트': np.float32(0.6544),
#     '페미닌': np.float32(0.059),
#     '리조트': np.float32(0.0513)},
#    '하의_기장_발목',
#    '하의_색상_블랙',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(41267),
#    {'스트리트': np.float32(0.5613),
#     '페미닌': np.float32(0.0896),
#     '로맨틱': np.float32(0.0622)},
#    '하의_기장_미니',
#    '하의_색상_스카이블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(1145672),
#    {'스트리트': np.float32(0.6077),
#     '로맨틱': np.float32(0.0963),
#     '페미닌': np.float32(0.0758)},
#    '하의_기장_미니',
#    '하의_색상_블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_루즈'],
#   [np.int64(411308),
#    {'스트리트': np.float32(0.6147),
#     '페미닌': np.float32(0.0668),
#     '로맨틱': np.float32(0.0554)},
#    '하의_기장_발목',
#    '하의_색상_네이비',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(828493),
#    {'스트리트': np.float32(0.6544),
#     '페미닌': np.float32(0.0588),
#     '로맨틱': np.float32(0.0587)},
#    '하의_기장_미니',
#    '하의_색상_베이지',
#    '하의_카테고리_스커트'],
#   [np.int64(256399),
#    {'스트리트': np.float32(0.6561),
#     '로맨틱': np.float32(0.0555),
#     '모던': np.float32(0.0442)},
#    '하의_기장_발목',
#    '하의_카테고리_팬츠',
#    '하의_소재_스판덱스',
#    '하의_핏_스키니'],
#   [np.int64(1251295),
#    {'스트리트': np.float32(0.5806),
#     '페미닌': np.float32(0.0839),
#     '로맨틱': np.float32(0.0769)},
#    '하의_색상_베이지'],
#   [np.int64(583599),
#    {'스트리트': np.float32(0.6615),
#     '페미닌': np.float32(0.0549),
#     '클래식': np.float32(0.0512)},
#    '하의_기장_발목',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_루즈'],
#   [np.int64(870816),
#    {'스트리트': np.float32(0.5473),
#     '로맨틱': np.float32(0.0927),
#     '페미닌': np.float32(0.0731)},
#    '하의_기장_미디',
#    '하의_색상_베이지',
#    '하의_카테고리_스커트',
#    '하의_소재_시폰',
#    '하의_핏_루즈'],
#   [np.int64(970738),
#    {'스트리트': np.float32(0.5972),
#     '페미닌': np.float32(0.0807),
#     '로맨틱': np.float32(0.064)},
#    '하의_기장_미니',
#    '하의_색상_화이트',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(814318),
#    {'스트리트': np.float32(0.63),
#     '페미닌': np.float32(0.0715),
#     '로맨틱': np.float32(0.06)},
#    '하의_기장_발목',
#    '하의_색상_블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_스키니'],
#   [np.int64(788047),
#    {'스트리트': np.float32(0.5613),
#     '페미닌': np.float32(0.0896),
#     '로맨틱': np.float32(0.0622)},
#    '하의_기장_미니',
#    '하의_색상_스카이블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(618957),
#    {'스트리트': np.float32(0.6228),
#     '페미닌': np.float32(0.0676),
#     '로맨틱': np.float32(0.0539)},
#    '하의_기장_미니',
#    '하의_카테고리_스커트',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(521929),
#    {'스트리트': np.float32(0.8321),
#     '클래식': np.float32(0.0446),
#     '리조트': np.float32(0.039)},
#    '하의_기장_맥시',
#    '하의_색상_라벤더',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_와이드'],
#   [np.int64(966670),
#    {'스트리트': np.float32(0.6088),
#     '페미닌': np.float32(0.0725),
#     '리조트': np.float32(0.0552)},
#    '하의_기장_발목',
#    '하의_색상_블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(1000075),
#    {'스트리트': np.float32(0.7007),
#     '페미닌': np.float32(0.0529),
#     '로맨틱': np.float32(0.0425)},
#    '하의_기장_발목',
#    '하의_색상_블랙',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(172625),
#    {'스트리트': np.float32(0.583),
#     '페미닌': np.float32(0.0963),
#     '로맨틱': np.float32(0.0905)},
#    '하의_색상_화이트',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐'],
#   [np.int64(1061385),
#    {'스트리트': np.float32(0.6205),
#     '페미닌': np.float32(0.0619),
#     '로맨틱': np.float32(0.056)},
#    '하의_기장_발목',
#    '하의_색상_블랙',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_스키니'],
#   [np.int64(596673),
#    {'스트리트': np.float32(0.6615),
#     '페미닌': np.float32(0.0549),
#     '클래식': np.float32(0.0512)},
#    '하의_기장_발목',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_루즈'],
#   [np.int64(1005633),
#    {'스트리트': np.float32(0.6654),
#     '페미닌': np.float32(0.0595),
#     '로맨틱': np.float32(0.0539)},
#    '하의_기장_발목',
#    '하의_색상_블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_루즈'],
#   [np.int64(819482),
#    {'스트리트': np.float32(0.8394),
#     '리조트': np.float32(0.0239),
#     '페미닌': np.float32(0.0191)},
#    '하의_기장_미디',
#    '하의_색상_카키',
#    '하의_카테고리_스커트',
#    '하의_소재_니트',
#    '하의_핏_노멀'],
#   [np.int64(964957),
#    {'스트리트': np.float32(0.6088),
#     '페미닌': np.float32(0.0725),
#     '리조트': np.float32(0.0552)},
#    '하의_기장_발목',
#    '하의_색상_블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(769528),
#    {'스트리트': np.float32(0.5362),
#     '페미닌': np.float32(0.088),
#     '클래식': np.float32(0.0703)},
#    '하의_기장_미디',
#    '하의_카테고리_스커트',
#    '하의_소재_저지',
#    '하의_핏_노멀'],
#   [np.int64(1209326),
#    {'스트리트': np.float32(0.6147),
#     '페미닌': np.float32(0.0668),
#     '로맨틱': np.float32(0.0554)},
#    '하의_기장_발목',
#    '하의_색상_네이비',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(684647),
#    {'스트리트': np.float32(0.5854),
#     '페미닌': np.float32(0.1016),
#     '로맨틱': np.float32(0.08)},
#    '하의_기장_미니',
#    '하의_색상_화이트',
#    '하의_카테고리_팬츠',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(664064),
#    {'스트리트': np.float32(0.6578),
#     '클래식': np.float32(0.0639),
#     '리조트': np.float32(0.0561)},
#    '하의_기장_발목',
#    '하의_색상_핑크',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_와이드'],
#   [np.int64(1183449),
#    {'스트리트': np.float32(0.7007),
#     '페미닌': np.float32(0.0529),
#     '로맨틱': np.float32(0.0425)},
#    '하의_기장_발목',
#    '하의_색상_블랙',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(149126),
#    {'스트리트': np.float32(0.5806),
#     '페미닌': np.float32(0.0839),
#     '로맨틱': np.float32(0.0769)},
#    '하의_색상_베이지'],
#   [np.int64(492805),
#    {'스트리트': np.float32(0.6495),
#     '클래식': np.float32(0.0553),
#     '리조트': np.float32(0.0532)},
#    '하의_기장_발목',
#    '하의_색상_베이지',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_와이드'],
#   [np.int64(805434),
#    {'스트리트': np.float32(0.6113),
#     '페미닌': np.float32(0.0653),
#     '로맨틱': np.float32(0.0582)},
#    '하의_기장_발목',
#    '하의_색상_스카이블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(1079965),
#    {'스트리트': np.float32(0.659),
#     '페미닌': np.float32(0.0623),
#     '리조트': np.float32(0.0505)},
#    '하의_기장_발목',
#    '하의_색상_블랙',
#    '하의_카테고리_팬츠',
#    '하의_핏_노멀'],
#   [np.int64(802079),
#    {'스트리트': np.float32(0.7249),
#     '로맨틱': np.float32(0.045),
#     '페미닌': np.float32(0.0445)},
#    '하의_기장_미디',
#    '하의_색상_블랙',
#    '하의_카테고리_스커트',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(1260881),
#    {'스트리트': np.float32(0.6898),
#     '페미닌': np.float32(0.0617),
#     '클래식': np.float32(0.0455)},
#    '하의_기장_발목',
#    '하의_색상_블랙',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_루즈'],
#   [np.int64(752133),
#    {'스트리트': np.float32(0.6134),
#     '페미닌': np.float32(0.075),
#     '로맨틱': np.float32(0.0579)},
#    '하의_색상_블랙'],
#   [np.int64(1297962),
#    {'스트리트': np.float32(0.6117),
#     '페미닌': np.float32(0.0808),
#     '로맨틱': np.float32(0.0651)},
#    '하의_기장_미니',
#    '하의_색상_블루',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(1267699),
#    {'스트리트': np.float32(0.6321),
#     '로맨틱': np.float32(0.0739),
#     '페미닌': np.float32(0.0529)},
#    '하의_기장_발목',
#    '하의_카테고리_청바지',
#    '하의_소재_데님',
#    '하의_핏_벨보텀'],
#   [np.int64(1132912),
#    {'스트리트': np.float32(0.5726),
#     '페미닌': np.float32(0.0894),
#     '로맨틱': np.float32(0.0632)},
#    '하의_기장_발목',
#    '하의_색상_블랙',
#    '하의_카테고리_조거팬츠',
#    '하의_소재_우븐',
#    '하의_핏_노멀'],
#   [np.int64(300567),
#    {'스트리트': np.float32(0.7095),
#     '리조트': np.float32(0.062),
#     '페미닌': np.float32(0.0414)},
#    '하의_기장_발목',
#    '하의_카테고리_스커트',
#    '하의_소재_니트',
#    '하의_핏_노멀'],
#   [np.int64(1305430),
#    {'스트리트': np.float32(0.5365),
#     '페미닌': np.float32(0.1031),
#     '로맨틱': np.float32(0.0839)},
#    '하의_기장_미니',
#    '하의_색상_스카이블루',
#    '하의_카테고리_스커트',
#    '하의_소재_데님',
#    '하의_핏_노멀'],
#   [np.int64(273501),
#    {'스트리트': np.float32(0.6578),
#     '클래식': np.float32(0.0639),
#     '리조트': np.float32(0.0561)},
#    '하의_기장_발목',
#    '하의_색상_핑크',
#    '하의_카테고리_팬츠',
#    '하의_소재_우븐',
#    '하의_핏_와이드']]}

# %%
input = {'아우터':[user_clothes['아우터'][0]]}
df_recommendations_d = recommend_clothes_parallel_sorted(input, color_dict, feature_dict, user_clothes)
input = {'아우터':[user_clothes['아우터'][1]]}
df_recommendations_d2 = recommend_clothes_parallel_sorted(input, color_dict, feature_dict, user_clothes)
# Out:
# Processing recommendations: 100%|██████████| 1/1 [00:00<00:00, 113.75it/s]
# Processing recommendations: 100%|██████████| 1/1 [00:00<00:00, 120.90it/s]

# %%
df_recommendations_d
# Out:
#    input_ID input_cat                                     recommendation
# 0   1062492       아우터  {'상의': {'상의_1062492': 2.8871147605178837, '상의_...

# %%
import numpy as np

def flatten_scores(score_dict):
    """
    전체 점수를 하나의 dict로 평탄화: {item_id: score}
    """
    flat = {}
    for category in score_dict:
        flat.update(score_dict[category])
    return flat

def standardize_all_items(score_dict):
    """
    카테고리 무시하고 전체 아이템에 대해 표준 정규화
    """
    flat = flatten_scores(score_dict)
    values = np.array(list(flat.values()))
    mean = values.mean()
    std = values.std()
    if std == 0:
        std = 1e-8
    standardized_flat = {k: (v - mean) / std for k, v in flat.items()}
    return standardized_flat

def merge_scores_global_standardization(score_dict1, score_dict2, weight1=0.5, weight2=0.5):
    """
    두 데이터 모두에서 공통된 아이템만 정규화 후 합산
    """
    norm1 = standardize_all_items(score_dict1)
    norm2 = standardize_all_items(score_dict2)

    common_keys = set(norm1.keys()).intersection(norm2.keys())
    merged = {
        key: weight1 * norm1[key] + weight2 * norm2[key]
        for key in common_keys
    }

    return merged

# %%
result = merge_scores_global_standardization(df_recommendations_d['recommendation'].loc[0], result_tpo)

# %%
result

# %%
def count_total_items(score_dict):
    """
    모든 카테고리의 아이템 개수를 합산하여 반환
    """
    return sum(len(items) for items in score_dict.values())

# %%
print(count_total_items(df_recommendations_d['recommendation'].loc[0]))
print(count_total_items(result_tpo))
print(len(result))

# %%
def sort_items_by_score(score_dict, descending=True):
    """
    점수 기준으로 정렬된 (아이템ID, 점수) 튜플 리스트를 반환
    """
    return sorted(score_dict.items(), key=lambda x: x[1], reverse=descending)

sorted_result = sort_items_by_score(result)

# %%
from collections import defaultdict
import numpy as np

def get_top_items_by_category(sorted_result):
    """
    주어진 (아이템ID, 점수) 리스트에서 카테고리(상의, 하의 등)별 최고 점수 아이템 ID들을 추출.
    동점인 경우 모두 포함하여 반환.

    Args:
        sorted_result (List[Tuple[str, float]]): 예: [('상의_123', 1.2), ('하의_456', 2.3), ...]

    Returns:
        Dict[str, List[str]]: 각 카테고리별 최고 점수 아이템 ID 목록
    """
    # 카테고리별로 아이템 분류
    grouped = defaultdict(list)
    for item_id, score in sorted_result:
        category = item_id.split('_')[0]
        grouped[category].append((item_id, score))

    # 각 카테고리별 최고 점수 아이템 찾기
    top_items_by_category = {}
    for category, items in grouped.items():
        max_score = max(score for _, score in items)
        top_items = [item_id for item_id, score in items if score == max_score]
        top_items_by_category[category] = top_items

    return top_items_by_category

# %%
def run_recommendation(selected_tpo, selected_clothing):
    # ✅ 선택된 옷 종류 추출
    clothing_type = selected_clothing[2].split('_')[0]

    # ✅ input 딕셔너리 구성
    input_dict = {clothing_type: [selected_clothing]}

    # 추천 점수 계산
    score_f = recommend_clothes_parallel_sorted(input_dict, color_dict, feature_dict, user_clothes)
    result_tpo = calculate_tpo_scores(user_clothes, tpo_score_table, selected_tpo)
    result = merge_scores_global_standardization(score_f['recommendation'].loc[0], result_tpo)
    sorted_result = sort_items_by_score(result)
    top_items_by_category = get_top_items_by_category(sorted_result)

    # ✅ 필터링 기준 정의
    category_filter_map = {
        "아우터": {"상의", "하의", "원피스"},
        "상의": {"아우터", "하의"},
        "하의": {"아우터", "상의"},
        "원피스": {"아우터"},
    }

    allowed_categories = category_filter_map.get(clothing_type, set())
    filtered_result = {
        cat: items for cat, items in top_items_by_category.items() if cat in allowed_categories
    }

    return filtered_result

# %%
selected_tpo = '데일리'
selected_clothing = user_clothes['상의'][1]

result = run_recommendation(selected_tpo, selected_clothing)
print(result)

# %%
user_clothes['상의'][0]
# Out:
# [np.int64(1216062),
#  {'스트리트': np.float32(0.6033),
#   '페미닌': np.float32(0.0803),
#   '로맨틱': np.float32(0.0581)},
#  '상의_색상_화이트',
#  '상의_카테고리_티셔츠',
#  '상의_소매기장_반팔',
#  '상의_소재_저지',
#  '상의_핏_노멀']

# %%
selected_clothing = user_clothes['상의'][1]
